# %% [markdown]
# # Extract Connections List and Device tag lists

# %%
import pymupdf  # import PyMuPDF

if not hasattr(pymupdf.Page, "find_tables"):
    raise RuntimeError("This PyMuPDF version does not support the table feature")

# %%
doc = pymupdf.open("pdfs/sample.pdf")
page = doc[29]

# %% [markdown]
# # Visualization functions
# should go into common debug lib

# %%
def show_as_image(item, title=""):
    """Display item as pixmap."""
    DPI = 300  # use this resolution
    import numpy as np
    import matplotlib.pyplot as plt

    # %matplotlib inline
    pix = item.get_pixmap(dpi=DPI)
    img = np.ndarray([pix.h, pix.w, 3], dtype=np.uint8, buffer=pix.samples_mv)
    plt.figure(dpi=DPI)  # set the figure's DPI
    plt.title(title)  # set title of image
    _ = plt.imshow(img, extent=(0, pix.w * 72 / DPI, pix.h * 72 / DPI, 0))


def show_table_overview(page, tables):
    for i, tab in enumerate(tables):  # iterate over all tables
        for cell in tab.header.cells:
            if cell is not None:
                page.draw_rect(cell, color=pymupdf.pdfcolor["red"], width=2)
        for r, row in enumerate(tab.rows):
            for c, cell in enumerate(row.cells):
                if cell is not None:
                    page.draw_rect(cell, color=(0, 0, 1), width=1)  # blue
        page.draw_rect(tab.bbox, color=pymupdf.pdfcolor["green"])
        print(
            f"Table {i} column names: {tab.header.names}, external: {tab.header.external}"
        )
    show_as_image(page, f"Table & Header BBoxes")


def show_text_overview(page, text):
    for block in text:
        x0, y0, x1, y1, text, _, _, _ = block
        rect = pymupdf.Rect(x0, y0, x1, y1)
        page.draw_rect(rect, color=(1, 0, 0), width=1)  # red rectangle
    show_as_image(page, f"Table & Header BBoxes")


def print_table_overview(tables):
    for i, tab in enumerate(tables):  # iterate over all tables
        print(f"Table {i} column names: {tab.header.names}")

# %% [markdown]
# # Core logic code
# call `extract` with `page`s list and `TableType`.
# It will return single dataframe with a header.
# It will PRINT! error and ignore data from the erroneous page (TODO)
# It will NOT catch error if incorrect page type is provided

# %%
import pandas as pd
import numpy as np

# In pt
PAPER_A3 = (1191.05, 842.39)


def detect_overlaps(text_blocks):
    overlaps = []

    for i, (x0_i, y0_i, x1_i, y1_i, text_i, _, _, _) in enumerate(text_blocks):
        for j, (x0_j, y0_j, x1_j, y1_j, text_j, _, _, _) in enumerate(text_blocks):
            if i >= j:
                continue  # avoid double-checking same pair
            # check for intersection
            if not (x1_i <= x0_j or x1_j <= x0_i or y1_i <= y0_j or y1_j <= y0_i):
                overlaps.append(
                    (text_i, text_j, (x0_i, y0_i, x1_i, y1_i), (x0_j, y0_j, x1_j, y1_j))
                )

    return overlaps


# TODO just for now (then try to fix errorxs)
def detect_row_overlaps(table, overlaps):
    """
    Given a table and a list of overlapping text tuples,
    determine which table rows are affected.
    """
    affected_rows = []

    for text1, text2, rect1, rect2 in overlaps:
        # Iterate through table cells
        # print()
        # print(rect1)
        # print(rect2)
        for r, row in enumerate(table.rows):
            rect = pymupdf.Rect(row.bbox)
            # print(f" {r} {row.bbox}")
            if rect.intersects(pymupdf.Rect(rect1)) or rect.intersects(
                pymupdf.Rect(rect2)
            ):
                # print("!!!")
                affected_rows.append(r)
            # for c, cell in enumerate(row.cells):
            #     if cell is None:
            #         continue
            #     rect = pymupdf.Rect(cell)
            #     # Check if either overlap rect intersects the cell rect
            #     if rect.intersects(pymupdf.Rect(rect1)) or rect.intersects(pymupdf.Rect(rect2)):
            #         if r not in affected_rows:
            #             affected_rows = []
            #         affected_rows.append(())

    return affected_rows


def demote_header(df, header=None):
    if header is None:
        header = [""] * len(df.columns)
    header_row = pd.DataFrame([df.columns], columns=header)
    df2 = pd.DataFrame(df.values, columns=header)
    return pd.concat([header_row, df2], ignore_index=True)


def promote_header(df):
    return pd.DataFrame(df.values[1:], columns=df.values[0])


def forward_fill(df, column, replacement="="):
    saved = None
    new_values = []
    for val in df[column]:
        if val != replacement:
            saved = val
            new_values.append(val)
        else:
            if saved is None:
                raise ValueError(
                    f"Forward fill table column {column} has {replacement} before any value was specified"
                )
            new_values.append(saved)
    df[column] = new_values
    return df


def getClipRect(w, h, x0, y0, w0, h0):
    return pymupdf.Rect(
        x0 / PAPER_A3[0] * w,
        y0 / PAPER_A3[1] * h,
        w0 / PAPER_A3[0] * w,
        h0 / PAPER_A3[1] * h,
    )


def extract(pages, what):
    print(f"Extracting '{what}' from {len(pages)} pages...")
    if len(pages) == 0:
        return None
    #
    f = options.get(what, None)
    assert f is not None, f"Specified table type '{what}' does not have a processor"
    # concat the rest
    tables = []
    for p in pages:
        print(f"Extracting '{what}' from page #{p.number + 1}")
        try:
            t = f(p)
            if t is not None:
                tables.append(t)
            else:
                print(f"Could not extract '{what}' from page #{p.number + 1}: got None")
        except ValueError as ve:
            print(f"ValueError extracting '{what}' from page #{p.number + 1}: {ve}")
        except Exception as e:
            print(
                f"Unexpected error extracting '{what}' from page #{p.number + 1}: {e}"
            )
    #
    if len(tables) == 0:
        return None
    df = pd.concat(tables, ignore_index=True)
    assert df.shape[1] == tables[0].shape[1], f"Table headers do not match"
    # translate table header (for now just to english)
    if what in header_map:
        new_columns = header_map[what]
        if len(new_columns) == df.shape[1]:
            df.columns = new_columns
        else:
            print(
                f"Internationalization error: table shape mismatch: {len(new_columns)} vs {df.shape[1]}"
            )

    return df


def extract_connection_list(page):
    tables = list(page.find_tables())
    if len(tables) < 2:
        raise ValueError("No required tables found on the page")

    # TODO selection logic
    t1 = tables[1]
    t2 = tables[2] if len(tables) > 2 else None

    if t1 is None:
        return None

    # Preserve header - to_pandas breaks empty fields
    header = list(t1.header.names)
    df1 = t1.to_pandas()

    # Single table case
    if t2 is None:
        return df1

    # Two tables case - combine them
    if t1.col_count != t2.col_count:
        raise ValueError(
            f"Column count mismatch between tables: {t1.col_count} vs {t2.col_count}"
        )

    header_row = pd.DataFrame([t2.header.names], columns=header)
    df2 = pd.DataFrame(t2.to_pandas().values, columns=header)

    return pd.concat([df1, header_row, df2], ignore_index=True)


def extract_device_tag_list_de(page):
    w = page.rect.width
    h = page.rect.height
    if w <= h:
        raise ValueError(f"Album orientation expected, found: width={w}, height={h}.")

    # TODO cliprect check
    tables = list(page.find_tables(clip=getClipRect(w, h, 33, 132, 1170, 780)))
    if not tables:
        raise ValueError("No tables found in the specified clip area on the page")
    return tables[0].to_pandas()


def extract_device_tag_list(page):
    tables = list(page.find_tables())
    if not tables:
        raise ValueError("No tables found on the page")
    # TODO selection logic
    t = tables[1]
    df = t.to_pandas()
    #
    return pd.DataFrame(df.values[1:], columns=df.values[0])  # use 1st row as header


def extract_cable_overview(page):
    w = page.rect.width
    h = page.rect.height
    if w <= h:
        raise ValueError(f"Album orientation expected, found: width={w}, height={h}.")

    tables = list(page.find_tables(clip=getClipRect(w, h, 33, 33, 1170, 780)))
    if not tables:
        raise ValueError("No tables found on the page")
    df = tables[0].to_pandas()

    # use 1st row as header
    df = pd.DataFrame(df.values[1:], columns=df.values[0])

    # drop empty/None cols
    df = df.drop(columns=[col for col in df.columns if col is None or col == ""])

    # disjoin "from to" column
    col_to_drop = df.columns[1]
    split_cols = df[col_to_drop].str.split(" ", expand=True)
    if split_cols.shape[1] != 2:
        raise ValueError(
            f"Expected at most 2 columns after split, got {split_cols.shape[1]}, meaning some name had spaces in it!"
        )
    df[["from", "to"]] = split_cols
    df = df.drop(columns=[col_to_drop])
    #
    return df


def extract_cable_plan(page):
    w = page.rect.width
    h = page.rect.height
    if w <= h:
        raise ValueError(f"Album orientation expected, found: width={w}, height={h}.")
    #
    # Will not work for German!
    # extract connections
    tables_left = list(page.find_tables(clip=getClipRect(w, h, 10, 98, 400, 780)))
    if not tables_left:
        raise ValueError("No required tables found on the page")
    df_left = tables_left[0].to_pandas()
    tables_right = list(page.find_tables(clip=getClipRect(w, h, 790, 98, 1185, 780)))
    if not tables_right:
        raise ValueError("No required tables found on the page")
    df_right = tables_right[0].to_pandas()
    df = pd.concat([df_left, df_right], axis=1)
    #
    # extract current device
    # 80 for English; 136 German!
    text = page.get_text("text", clip=getClipRect(w, h, 114, 29, 400, 47))
    df["Cabel"] = text
    if len(text) == 0:
        raise ValueError("Failed to detect Cabel Tag")
    # other TODO unstable
    # tables_main = page.find_tables(strategy="text", clip=getClipRect(w, h, 33, 132, 1170, 203))
    # 120 for English; 230 German!
    tables_typ = list(
        page.find_tables(strategy="text", clip=getClipRect(w, h, 441, 120, 750, 780))
    )
    typ = None
    if tables_typ:
        typ_header = list(
            tables_typ[0].header.names
        )  # Preserve header - to_pandas breaks it
        typ = tables_typ[0].to_pandas()
        typ.columns = typ_header  # restore original names (.to_pandas breaks it)
        typ = demote_header(typ, ["Source conductor", "Target conductor"])
        typ = typ.iloc[::2].reset_index(drop=True)  # remove empty rows
    else:
        # fallback
        text_typ = page.get_text("text", clip=getClipRect(w, h, 441, 120, 750, 780))
        rows = [line for line in text_typ.split("\n") if line.strip()]  # flat list
        rows = [
            rows[i : i + 2] for i in range(0, len(rows), 2)
        ]  # Group every 2 items into a row
        typ = pd.DataFrame(rows, columns=["Source conductor", "Target conductor"])
    df = pd.concat([df, typ], axis=1)

    # fix

    # print_table_overview(tables)
    # print_table_overview(tables_typ)
    return df


def extract_topology(page):
    w = page.rect.width
    h = page.rect.height
    if w <= h:
        raise ValueError(f"Album orientation expected, found: width={w}, height={h}.")

    tables = list(page.find_tables(clip=getClipRect(w, h, 33, 75, 1170, 780)))
    # print_table_overview(tables)
    if not tables:
        raise ValueError("No required tables found on the page")

    return tables[0].to_pandas()


def extract_wires_part_list(page):
    w = page.rect.width
    h = page.rect.height
    if w <= h:
        raise ValueError(f"Album orientation expected, found: width={w}, height={h}.")

    tables = list(page.find_tables(clip=getClipRect(w, h, 33, 70, 1170, 780)))
    # print_table_overview(tables)
    if not tables:
        raise ValueError("No required tables found on the page")

    df = tables[0].to_pandas()
    return pd.DataFrame(df.values[1:], columns=df.values[0])  # use 1st row as header


def extract_cable_diagram(page):
    w = page.rect.width
    h = page.rect.height
    if w <= h:
        raise ValueError(f"Album orientation expected, found: width={w}, height={h}.")
    #
    tables = list(page.find_tables(clip=getClipRect(w, h, 33, 70, 1170, 780)))
    if not tables:
        raise ValueError("No required tables found on the page")
    # No way I can separate tables by coods - need to detect here
    df = tables[0].to_pandas()
    df = df.replace({None: np.nan})
    i = 0
    tables = []
    while i < len(df):
        # Detect start of a block: two rows with col2 & col3 missing
        if df.iloc[i, 1:3].isna().all() and df.iloc[i + 1, 1:3].isna().all():
            cable_name = df.iloc[i, 0].split(" ")[-1]  # Here cable name is located
            i += 2
            # Ignore all info as duplicated and hard to extract

            header = df.iloc[i].tolist()
            i += 1

            # Gather table rows until next info block or end
            rows = []
            while i < len(df) and not (
                df.iloc[i, 1:3].isna().all()
                and i + 1 < len(df)
                and df.iloc[i + 1, 1:3].isna().all()
            ):
                rows.append(df.iloc[i].tolist())
                i += 1

            table = pd.DataFrame(rows, columns=header)
            table["Cable"] = cable_name
            tables.append(table)
        else:
            i += 1

    return pd.concat(tables, ignore_index=True)


def extract_terminal_diagram(page):
    w = page.rect.width
    h = page.rect.height
    if w <= h:
        raise ValueError(f"Album orientation expected, found: width={w}, height={h}.")
    # Left side Cables
    tables = list(page.find_tables(clip=getClipRect(w, h, 20, 33, 410, 237)))
    if not tables:
        raise ValueError("No required tables found on the page: left cable info")
    header = list(tables[0].header.names)  # preserve header as to_pandas breaks it
    df = tables[0].to_pandas()
    df.columns = header  # restore original names (.to_pandas breaks it)
    df_l_cables = demote_header(df)
    # Left side Cable Connections
    tables = list(page.find_tables(clip=getClipRect(w, h, 20, 237, 410, 780)))
    if not tables:
        raise ValueError("No required tables found on the page: left color info")
    df_l_conn = tables[0].to_pandas()
    # Connections
    tables = list(page.find_tables(clip=getClipRect(w, h, 410, 33, 780, 780)))
    if not tables:
        raise ValueError("No required tables found on the page: connection info")
    overlaps = detect_overlaps(
        page.get_text("words", clip=getClipRect(w, h, 410, 33, 780, 780))
    )
    overlapping_rows = []
    if overlaps:
        overlapping_rows = detect_row_overlaps(tables[0], overlaps)
    df_center = tables[0].to_pandas()
    # Right side Cables
    tables = list(page.find_tables(clip=getClipRect(w, h, 780, 33, 1170, 237)))
    if not tables:
        raise ValueError("No required tables found on the page: right cable info")
    header = list(tables[0].header.names)  # preserve header as to_pandas breaks it
    df = tables[0].to_pandas()
    df.columns = header  # restore original names (.to_pandas breaks it)
    df_r_cables = demote_header(df)
    # Right side Cable Connections
    tables = list(page.find_tables(clip=getClipRect(w, h, 780, 237, 1170, 780)))
    if not tables:
        raise ValueError("No required tables found on the page: left color info")
    df_r_conn = tables[0].to_pandas()

    # here I have to do preprocessing to make a single df
    strip_info = df_center.columns[0]
    strip_name = strip_info.splitlines()[1]

    df = promote_header(df_center)

    # For now I will just delete overlapping rows
    if overlapping_rows:
        print("OVERLAP DETECTED! ERROR HANDLING IS NOT DONE YET! FOR NOW JUST IGNORED!")
        # -2 as promote_header & index counts from 1 in detect_row_overlaps
        adjusted_rows = [i - 2 for i in overlapping_rows]
        df = df.drop(index=adjusted_rows).reset_index(drop=True)
        df_l_conn = df_l_conn.drop(index=adjusted_rows).reset_index(drop=True)
        df_r_conn = df_r_conn.drop(index=adjusted_rows).reset_index(drop=True)

    #
    def transform_dataframe(df_cables, df_conn):
        rows = []
        number_cols = [col for col in df_conn.columns if col.isdigit()]
        non_number_cols = [col for col in df_conn.columns if col not in number_cols]
        columns = ["Cable", "Color"] + non_number_cols
        # for each connection
        for _, row in df_conn.iterrows():
            non_number_values = row[non_number_cols].tolist()
            cable_info_list = []
            color_list = []
            for col in number_cols:
                color = row[col]
                if pd.notna(color) and color.strip() != "":
                    # assume it is convertible to int as we did isdigit
                    cable_index = int(col) - 1
                    # TODO might be wrong as cable tag might have spaces (?)
                    cable_info = df_cables.iloc[cable_index, 1].split(" ")[0]
                    # Extract a TAG from cable_info
                    cable_info_list.append(cable_info)
                    color_list.append(color)
            rows.append(
                ["; ".join(cable_info_list), "; ".join(color_list)] + non_number_values
            )
        return pd.DataFrame(rows, columns=columns)

    # Check if the number of rows in the transformed dataframes matches the number of rows in df
    left_transformed = transform_dataframe(df_l_cables, df_l_conn)
    right_transformed = transform_dataframe(df_r_cables, df_r_conn)
    if left_transformed.shape[0] != df.shape[0]:
        raise ValueError(
            f"Left cable assignment ({left_transformed.shape[0]}) does not match connections ({df.shape[0]})"
        )
    if right_transformed.shape[0] != df.shape[0]:
        raise ValueError(
            f"Right cable assignment ({right_transformed.shape[0]}) does not match connections ({df.shape[0]})"
        )

    # Prepend left_transformed, append right_transformed
    df = pd.concat(
        [
            left_transformed.reset_index(drop=True),
            df.reset_index(drop=True),
            right_transformed.reset_index(drop=True),
        ],
        axis=1,
    )

    # clean empty rows
    df = df.where(df != "").dropna(how="all")
    # insert strip name as 1st column
    df.insert(0, "Strip", strip_name)

    return df


from enum import Enum


class TableType(Enum):
    CONNECTION_LIST = "connection list"
    DEVICE_TAG_LIST = "device tag list"
    DEVICE_LIST_DE = "artikelstückliste"
    CABLE_OVERVIEW = "Cable overview | Kabelübersicht"
    CABLE_PLAN = "Cable plan | Kabelplan"
    TOPOLOGY = "Topology: Routed cables / connections"
    WIRES_PART_LIST = "Wires parts list"
    TERMINAL_DIAGRAM = "Terminal diagram | Klemmenplan"
    CABLE_DIAGRAM = "Cable diagram"


options = {
    TableType.CONNECTION_LIST: extract_connection_list,
    TableType.DEVICE_TAG_LIST: extract_device_tag_list,
    TableType.DEVICE_LIST_DE: extract_device_tag_list_de,
    TableType.CABLE_OVERVIEW: extract_cable_overview,
    TableType.CABLE_PLAN: extract_cable_plan,
    TableType.TOPOLOGY: extract_topology,
    TableType.WIRES_PART_LIST: extract_wires_part_list,
    TableType.TERMINAL_DIAGRAM: extract_terminal_diagram,
    TableType.CABLE_DIAGRAM: extract_cable_diagram,
}

header_map = {
    TableType.CABLE_OVERVIEW: [
        "Cable designation",
        "Cable type",
        "Conductors",
        "ø",
        "Length",
        "Function text",
        "From",
        "To",
    ],
}

# %% [markdown]
# # Examples

# %%
from table_extractor import TableExtractor


table_extractor = TableExtractor()

# %%
from page_processor import PageType

table_extractor.extract(doc[152:153], PageType.CABLE_PLAN_DE)
# Out:
# Extracting 'PageType.CABLE_PLAN_DE' from 1 pages...
# Extracting 'PageType.CABLE_PLAN_DE' from page #153
#   ocation designation         Source      Function text source Stopper  \
# 0      Station "Work"  +B2.X1-XZ1:23  Drive, "Grinding, right"
# 1      Station "Work"  +B2.X1-XZ1:24                         =
# 2      Station "Work"  +B2.X1-XZ1:25                         =
# 3      Station "Work"  +B2.X1-XZ1:26                         =
# 4      Station "Work"  +B2.X1-XZ1:28                         =
# 5      Station "Work"  +B2.X1-XZ1:29                         =
# 6      Station "Work"  +B2.X1-XZ1:27                         =
# 7      Station "Work"  +B2.X1-XZ1:30                         =
#
#   L1\n[mm] Part number Part number L2\n[mm] Stopper      Function text target  \
# 0    10 mm                            10 mm          Drive, "Grinding, right"
# 1    10 mm                            10 mm                                 =
# 2    10 mm                            10 mm                                 =
# 3    10 mm                            10 mm                                 =
# 4
# 5
# 6                                                    Drive, "Grinding, right"
# 7                                                                           =
#
#            Target Location designation         Cabel Source conductor  \
# 0  =TM2+B2-MA1:U1       Station "Work"  +B2.X1-WZ5\n                1
# 1  =TM2+B2-MA1:V1       Station "Work"  +B2.X1-WZ5\n                2
# 2  =TM2+B2-MA1:W1       Station "Work"  +B2.X1-WZ5\n                3
# 3  =TM2+B2-MA1:PE       Station "Work"  +B2.X1-WZ5\n             GNYE
# 4  =TM2+B2-MA1:11       Station "Work"  +B2.X1-WZ5\n                5
# 5  =TM2+B2-MA1:12       Station "Work"  +B2.X1-WZ5\n                6
# 6  +B2.X1-WZ5:SH1       Station "Work"  +B2.X1-WZ5\n              SH1
# 7   +B2.X1-WZ5:SH       Station "Work"  +B2.X1-WZ5\n               SH
#
#   Target conductor
# 0                1
# 1                2
# 2                3
# 3             GNYE
# 4                5
# 5                6
# 6              SH1
# 7               SH

# %%
extract(doc[72:76], TableType.CABLE_DIAGRAM)
# Out:
# Extracting 'TableType.CABLE_DIAGRAM' from 4 pages...
# Extracting 'TableType.CABLE_DIAGRAM' from page #73
# Extracting 'TableType.CABLE_DIAGRAM' from page #74
# Extracting 'TableType.CABLE_DIAGRAM' from page #75
# Extracting 'TableType.CABLE_DIAGRAM' from page #76
#                Function text      Page / column Target designation from  \
# 0   24 V device power supply  =GAB1+A2&EFS1/1.1                 +A2-XD1
# 1                          =  =GAB1+A2&EFS1/1.1                 +A2-XD1
# 2                          =  =GAB1+A2&EFS1/1.1                 +A2-XD1
# 3                          =  =GAB1+A2&EFS1/1.1                 +A2-XD1
# 4                          =  =GAB1+A2&EFS1/1.1                 +A2-XD1
# ..                       ...                ...                     ...
# 59                         =   =TM1+A1&EFS1/1.9                 +A1-XG1
# 60
# 61   Start "Grinding, right"   =TM2+A1&EFS1/1.9                 +A1-XG1
# 62                         =   =TM2+A1&EFS1/1.9                 +A1-XG1
# 63
#
#    Connection\npoint Conductor Target designation to Connection\npoint  \
# 0                  4        BU               +A1-XD3                 4
# 1                  1        BN               +A1-XD3                 1
# 2                  2        BK               +A1-XD3                 2
# 3                  3        GY               +A1-XD3                 3
# 4                  5      GNYE               +A1-XD3                 5
# ..               ...       ...                   ...               ...
# 59                26        BU               +A2-XG5                50
# 60                        GNYE
# 61                29        BN               +A2-XG5                55
# 62                30        BU               +A2-XG5                56
# 63                        GNYE
#
#         Page / column             Function text    Cable
# 0   =GAB1+A2&EFS1/1.1  24 V device power supply  +A2-WD1
# 1   =GAB1+A2&EFS1/1.1                         =  +A2-WD1
# 2   =GAB1+A2&EFS1/1.1                         =  +A2-WD1
# 3   =GAB1+A2&EFS1/1.1                         =  +A2-WD1
# 4   =GAB1+A2&EFS1/1.1                         =  +A2-WD1
# ..                ...                       ...      ...
# 59   =TM1+A1&EFS1/1.9                         =  +A2-WG2
# 60                                               +A2-WG2
# 61   =TM2+A1&EFS1/1.9   Start "Grinding, right"  +A2-WG3
# 62   =TM2+A1&EFS1/1.9                         =  +A2-WG3
# 63                                               +A2-WG3
#
# [64 rows x 10 columns]

# %%
extract(doc[58:66], TableType.TERMINAL_DIAGRAM)
# extract(doc[169:170], TableType.TERMINAL_DIAGRAM)
# Out:
# Extracting 'TableType.TERMINAL_DIAGRAM' from 1 pages...
# Extracting 'TableType.TERMINAL_DIAGRAM' from page #170
# OVERLAP DETECTED! ERROR HANDLING IS NOT DONE YET! FOR NOW JUST IGNORED!
#         Strip       Cable Color                Function text  \
# 0  +B2.Y1-XD1  +B2.Y1-WD1    BK  Power supply valve terminal
# 1  +B2.Y1-XD1  +B2.Y1-WD1  GNYE                            =
# 2  +B2.Y1-XD1         NaN   NaN                          NaN
#
#   Target designation Connection point Terminal designation Jumpers  \
# 0            +A2-XD7               16                    1     NaN
# 1            +A2-XD7               19                    4     NaN
# 2                NaN              NaN                    5     NaN
#
#   PLC connection point Target designation Connection point       Cable Color  \
# 0                  NaN        +B2.Y1-XDB1              1:1  +B2.Y1-WD3    BK
# 1                  NaN        +B2.Y1-XDB1            PE:PE  +B2.Y1-WD3  GNYE
# 2                  NaN      =K2+B2.Y1-XD1               PE         NaN   NaN
#
#         Page / column
# 0  =K2+B2.Y1&EFS1/3.3
# 1  =K2+B2.Y1&EFS1/3.3
# 2  =K2+B2.Y1&EFS1/3.2

# %%
df = extract(doc[40:44], TableType.WIRES_PART_LIST)
df
# Out:
# Extracting 'TableType.WIRES_PART_LIST' from 4 pages...
# Extracting 'TableType.WIRES_PART_LIST' from page #41
# Extracting 'TableType.WIRES_PART_LIST' from page #42
# Extracting 'TableType.WIRES_PART_LIST' from page #43
# Extracting 'TableType.WIRES_PART_LIST' from page #44
#             Source             Target   Part number Cross-section Color  \
# 0        +A1-XD1:1      =GAA+A1-FC1:1  LAPP.4150701             6    BK
# 1    =GAA+A1-FC1:1       =EA+A1-FB1:1  LAPP.4150709             6    OG
# 2     =EA+A1-FB1:1       =EA+A1-FB3:1  LAPP.4150709             6    OG
# 3    =GAA+A1-FC1:2      =GAA+A1-FC2:1  LAPP.4150601             4    BK
# 4    =GAA+A1-FC2:1  =GAB1+A1-FC1:1/L1  LAPP.4150601             4    BK
# ..             ...                ...           ...           ...   ...
# 223
# 224
# 225
# 226
# 227
#
#       Length Bundle Bundle groups Conductor\nend source Conductor\nend target  \
# 0     2,31 m      7                           Stripping            End sleeve
# 1    0,534 m      5                          End sleeve            End sleeve
# 2    0,369 m      5                          End sleeve            End sleeve
# 3    1,066 m      6                          End sleeve            End sleeve
# 4    1,499 m      6                          End sleeve            End sleeve
# ..       ...    ...           ...                   ...                   ...
# 223
# 224
# 225
# 226
# 227
#
#     Routing direction\nsource Routing direction\ntarget  \
# 0        Move up, to the left      Move up, to the left
# 1        Move up, to the left     Move up, to the right
# 2       Move up, to the right      Move up, to the left
# 3      Move down, to the left      Move up, to the left
# 4        Move up, to the left      Move up, to the left
# ..                        ...                       ...
# 223
# 224
# 225
# 226
# 227
#
#                                          Routing track
# 0    +A1-U12;+A1-U5;+A1-U11;+A1-U9;+A1-U10;+A1-TA1;...
# 1                                               +A1-U7
# 2                                               +A1-U7
# 3                                 +A1-U8;+A1-U5;+A1-U7
# 4                  +A1-U7;+A1-U5;+A1-U8;+A1-U9;+A1-U10
# ..                                                 ...
# 223
# 224
# 225
# 226
# 227
#
# [228 rows x 13 columns]

# %%
df = extract(doc[40:44], TableType.WIRES_PART_LIST)
df
# Out:
# Extracting 'TableType.WIRES_PART_LIST' from 4 pages...
# Extracting 'TableType.WIRES_PART_LIST' from page #41
# Extracting 'TableType.WIRES_PART_LIST' from page #42
# Extracting 'TableType.WIRES_PART_LIST' from page #43
# Extracting 'TableType.WIRES_PART_LIST' from page #44
#             Source             Target   Part number Cross-section Color  \
# 0        +A1-XD1:1      =GAA+A1-FC1:1  LAPP.4150701             6    BK
# 1    =GAA+A1-FC1:1       =EA+A1-FB1:1  LAPP.4150709             6    OG
# 2     =EA+A1-FB1:1       =EA+A1-FB3:1  LAPP.4150709             6    OG
# 3    =GAA+A1-FC1:2      =GAA+A1-FC2:1  LAPP.4150601             4    BK
# 4    =GAA+A1-FC2:1  =GAB1+A1-FC1:1/L1  LAPP.4150601             4    BK
# ..             ...                ...           ...           ...   ...
# 223
# 224
# 225
# 226
# 227
#
#       Length Bundle Bundle groups Conductor\nend source Conductor\nend target  \
# 0     2,31 m      7                           Stripping            End sleeve
# 1    0,534 m      5                          End sleeve            End sleeve
# 2    0,369 m      5                          End sleeve            End sleeve
# 3    1,066 m      6                          End sleeve            End sleeve
# 4    1,499 m      6                          End sleeve            End sleeve
# ..       ...    ...           ...                   ...                   ...
# 223
# 224
# 225
# 226
# 227
#
#     Routing direction\nsource Routing direction\ntarget  \
# 0        Move up, to the left      Move up, to the left
# 1        Move up, to the left     Move up, to the right
# 2       Move up, to the right      Move up, to the left
# 3      Move down, to the left      Move up, to the left
# 4        Move up, to the left      Move up, to the left
# ..                        ...                       ...
# 223
# 224
# 225
# 226
# 227
#
#                                          Routing track
# 0    +A1-U12;+A1-U5;+A1-U11;+A1-U9;+A1-U10;+A1-TA1;...
# 1                                               +A1-U7
# 2                                               +A1-U7
# 3                                 +A1-U8;+A1-U5;+A1-U7
# 4                  +A1-U7;+A1-U5;+A1-U8;+A1-U9;+A1-U10
# ..                                                 ...
# 223
# 224
# 225
# 226
# 227
#
# [228 rows x 13 columns]

# %%
df = extract(doc[55:56], TableType.CABLE_OVERVIEW)
df
# Out:
# Extracting 'TableType.CABLE_OVERVIEW' from 1 pages...
# Extracting 'TableType.CABLE_OVERVIEW' from page #56
#   Cable designation Cable type Conductors     ø Length      Function text  \
# 0           +A1-WD1      NYY-O         2X     6  2,472       Power supply
# 1
# 2           +A1-WD2                    3G   1,5  2,385  Enclosure light 1
# 3              None       None       None  None   None               None
#
#       From          To
# 0  +A1-WE2     +A2-WE2
# 1  +A1-WE1     +A2-WE1
# 2  +A1-XD2  =EA+A1-EA1
# 3     None        None

# %%
df = extract(doc[21:23], TableType.TOPOLOGY)
df
# Out:
# Extracting 'TableType.TOPOLOGY' from 2 pages...
# Extracting 'TableType.TOPOLOGY' from page #22
# Extracting 'TableType.TOPOLOGY' from page #23
#    Designation    Part number              Type number Length [m]  \
# 0      +A1-WD1   EPL.2x6CABLE                    NYY-O       2,47
# 1      +A2-WD1  LAPP.00100664      ÖLFLEX® CLASSIC 100       2,24
# 2      +A2-WD2  LAPP.00100654      ÖLFLEX® CLASSIC 100       2,24
# 3      +A2-WD3   LAPP.0010064      ÖLFLEX® CLASSIC 100       2,24
# 4      +A2-WD4   LAPP.0010064      ÖLFLEX® CLASSIC 100       2,24
# 5      +A2-WG1   LAPP.0010036      ÖLFLEX® CLASSIC 100       2,24
# 6      +A2-WG2  LAPP.00100224      ÖLFLEX® CLASSIC 100       2,24
# 7      +A2-WG3  LAPP.00100224      ÖLFLEX® CLASSIC 100       2,24
# 8      +B1-WG2  LAPP.00101264      ÖLFLEX® CLASSIC 100       4,02
# 9   +B1.X1-WD1   LAPP.0011028              ÖLFLEX® 140       3,40
# 10  +B1.X1-WD2   LAPP.0014159    ÖLFLEX® CLASSIC 100 H       1,78
# 11  +B1.X1-WG2  LAPP.22260257       AB-C3-2,0PUR-M12FS       0,66
# 12  +B1.X1-WZ1   LAPP.0036026        ÖLFLEX® SERVO 700       0,66
# 13     +B2-WG1  LAPP.00101264      ÖLFLEX® CLASSIC 100       2,16
# 14  +B2.X1-WD1   LAPP.0011028              ÖLFLEX® 140       1,86
# 15  +B2.X1-WD2   LAPP.0014159    ÖLFLEX® CLASSIC 100 H       1,92
# 16  +B2.X1-WG2  LAPP.22260257       AB-C3-2,0PUR-M12FS       0,34
# 17  +B2.X1-WG3  LAPP.22260257       AB-C3-2,0PUR-M12FS       0,34
# 18  +B2.X1-WG4  LAPP.22260257       AB-C3-2,0PUR-M12FS       0,34
# 19  +B2.X1-WZ1   LAPP.0036026        ÖLFLEX® SERVO 700       0,34
# 20  +B2.X1-WZ2   LAPP.0036061  ÖLFLEX® ROBUST FD 756 C       2,17
# 21  +B2.X1-WZ3   LAPP.0036061  ÖLFLEX® ROBUST FD 756 C       0,34
# 22  +B2.X1-WZ5   LAPP.0036061  ÖLFLEX® ROBUST FD 756 C       0,34
# 23  +B2.Y1-WD1  LAPP.00100234      ÖLFLEX® CLASSIC 100       2,88
# 24     +B3-WG1  LAPP.00101264      ÖLFLEX® CLASSIC 100       2,02
# 25     +B3-WG2  LAPP.00101264      ÖLFLEX® CLASSIC 100       2,02
# 26  +B3.X1-WD1   LAPP.0011028              ÖLFLEX® 140       1,77
# 27  +B3.X1-WD2   LAPP.0014159    ÖLFLEX® CLASSIC 100 H       3,35
# 28  +B3.X1-WG1  LAPP.22260257       AB-C3-2,0PUR-M12FS       0,29
# 29  +B3.X1-WZ1   LAPP.0036026        ÖLFLEX® SERVO 700       0,29
# 30     +C2-WD1  LAPP.00100224      ÖLFLEX® CLASSIC 100       7,36
# 31     +C2-WG1  LAPP.00101264      ÖLFLEX® CLASSIC 100       7,32
# 32        14-ø                                               4,62
# 33        16-ø                                               4,62
# 34        22-ø                                               2,75
# 35        24-ø                                               2,75
# 36        26-ø                                               2,75
# 37        28-ø                                               2,75
#
#              Source Source connection length [m]  \
# 0   +A1-WE2;+A1-WE1                        0,038
# 1           +A2-XD1                        0,047
# 2           +A2-XD1                        0,047
# 3           +A2-XD5                        0,047
# 4           +A2-XD5                        0,047
# 5           +A1-XG1                        0,047
# 6           +A1-XG1                        0,047
# 7           +A1-XG1                        0,047
# 8         =F+B1-SG1                        0,051
# 9        +B1.X1-XD1                        0,047
# 10          +A1-XD4                        0,047
# 11       +B1.X1-XZ1                        0,047
# 12       +B1.X1-XZ1                        0,047
# 13        =F+B2-SG1                        0,051
# 14       +B2.X1-XD1                        0,047
# 15          +A1-XD4                        0,047
# 16       +B2.X1-XZ1                        0,047
# 17       +B2.X1-XZ1                        0,047
# 18       +B2.X1-XZ1                        0,047
# 19       +B2.X1-XZ1                        0,047
# 20       +B2.X1-XZ1                        0,091
# 21       +B2.X1-XZ1                        0,047
# 22       +B2.X1-XZ1                        0,047
# 23       +B2.Y1-XD1                        0,047
# 24          +A2-XG4                        0,047
# 25          +A2-XG4                        0,047
# 26       +B3.X1-XD1                        0,047
# 27          +A1-XD4                        0,047
# 28       +B3.X1-XZ1                        0,047
# 29       +B3.X1-XZ1                        0,047
# 30          +C2-XD1                        0,047
# 31        =F+C2-SG1                        0,051
# 32      =MM1+B1-XM1                        0,000
# 33      =MM1+B1-XM2                        0,000
# 34      =MM2+B2-RN1                        0,000
# 35      =MM2+B2-RN2                        0,000
# 36      =MM3+B2-RN1                        0,000
# 37      =MM3+B2-RN2                        0,000
#
#                                         Routing track           Target  \
# 0                           +A1-U2;+-U85;+-U87;+A2-U2  +A2-WE2;+A2-WE1
# 1             +-U133;+A1-U2;+-U85;+-U87;+A2-U2;+-U140          +A1-XD3
# 2             +-U133;+A1-U2;+-U85;+-U87;+A2-U2;+-U140          +A1-XD3
# 3             +-U132;+A1-U2;+-U85;+-U87;+A2-U2;+-U143          +A1-XD2
# 4             +-U132;+A1-U2;+-U85;+-U87;+A2-U2;+-U143          +A1-XD2
# 5             +-U135;+A1-U2;+-U85;+-U87;+A2-U2;+-U141          +A2-XG1
# 6             +-U135;+A1-U2;+-U85;+-U87;+A2-U2;+-U142          +A2-XG5
# 7             +-U135;+A1-U2;+-U85;+-U87;+A2-U2;+-U142          +A2-XG5
# 8   +-U144;+A2-U2;+-U87;+-U85;+-U82;+B1.X1-U101;+-...          +A2-XG4
# 9               +-U145;+A2-U2;+-U87;+-U85;+-U82;+-U94          +A2-XD7
# 10                          +-U134;+A1-U2;+-U82;+-U93       +B1.X1-XZ1
# 11                           +-U93;+B1.X1-U101;+-U150      =GL1+B1-BG1
# 12                           +-U93;+B1.X1-U101;+-U151      =GL1+B1-MA1
# 13          +-U144;+A2-U2;+-U87;+-U84;+B2-U101;+-U158          +A2-XG4
# 14                    +-U145;+A2-U2;+-U87;+-U84;+-U96          +A2-XD7
# 15                    +-U134;+A1-U2;+-U85;+-U84;+-U95       +B2.X1-XZ1
# 16                              +-U95;+B2-U101;+-U159      =GL2+B2-BG1
# 17                              +-U95;+B2-U101;+-U165      =TM1+B2-BG1
# 18                              +-U95;+B2-U101;+-U167      =TM2+B2-BG1
# 19                              +-U95;+B2-U101;+-U160      =GL2+B2-MA1
# 20                    +-U95;+-U84;+-U85;+A1-U2;+-U136      =TM1+A1-TA1
# 21                              +-U95;+B2-U101;+-U166      =TM1+B2-MA1
# 22                              +-U95;+B2-U101;+-U168      =TM2+B2-MA1
# 23                    +-U145;+A2-U2;+-U87;+-U83;+-U97          +A2-XD7
# 24             +-U144;+A2-U2;+-U90;+B3.X1-U101;+-U169        =F+B3-SG1
# 25             +-U144;+A2-U2;+-U90;+B3.X1-U101;+-U170        =F+B3-SG2
# 26                         +-U145;+A2-U2;+-U90;+-U129          +A2-XD7
# 27             +-U134;+A1-U2;+-U85;+-U87;+-U90;+-U128       +B3.X1-XZ1
# 28                          +-U128;+B3.X1-U101;+-U171      =GL3+B3-BG1
# 29                          +-U128;+B3.X1-U101;+-U172      =GL3+B3-MA1
# 30                          +-U145;+A2-U2;+-U89;+-U91          +A2-XD7
# 31                          +-U146;+A2-U2;+-U89;+-U92         +A2-XGA1
# 32        +-U156;+B1.X1-U101;+-U82;+-U85;+-U83;+-U122   =MM1+B2.Y1-XM1
# 33        +-U157;+B1.X1-U101;+-U82;+-U85;+-U83;+-U123   =MM1+B2.Y1-XM2
# 34                 +-U161;+B2-U101;+-U84;+-U83;+-U124   =MM2+B2.Y1-XM1
# 35                 +-U162;+B2-U101;+-U84;+-U83;+-U125   =MM2+B2.Y1-XM2
# 36                 +-U163;+B2-U101;+-U84;+-U83;+-U126   =MM3+B2.Y1-XM1
# 37                 +-U164;+B2-U101;+-U84;+-U83;+-U127   =MM3+B2.Y1-XM2
#
#    Target connection length [m]
# 0                         0,284
# 1                         0,047
# 2                         0,047
# 3                         0,047
# 4                         0,047
# 5                         0,047
# 6                         0,047
# 7                         0,047
# 8                         0,047
# 9                         0,047
# 10                        0,091
# 11
# 12
# 13                        0,047
# 14                        0,047
# 15                        0,091
# 16
# 17
# 18
# 19
# 20                        0,303
# 21
# 22
# 23                        0,047
# 24                        0,051
# 25                        0,051
# 26                        0,047
# 27                        0,091
# 28
# 29
# 30                        0,047
# 31
# 32                        0,052
# 33                        0,052
# 34                        0,040
# 35                        0,040
# 36                        0,040
# 37                        0,040

# %%
doc_de2 = pymupdf.open("pdfs/machine_building_de.pdf")
df = extract(doc_de2[88:90], TableType.CABLE_OVERVIEW)
df
# extract_cable_overview(doc_de2[88])
# Out:
# Extracting 'TableType.CABLE_OVERVIEW' from 2 pages...
# Extracting 'TableType.CABLE_OVERVIEW' from page #89
# Table 0 column names: ['', '', None, None, None, None, None, None]
# Extracting 'TableType.CABLE_OVERVIEW' from page #90
# Table 0 column names: ['', '', None, None, None, None, None, None]
#     Cable designation                       Cable type Conductors     ø  \
# 0       =GAA+UC1-WXD1                             YAKY          3   1,5
# 1       =GQA+UC1-WDB1              ÖLFLEX® CLASSIC 110          3   1,5
# 2       =GQA+BB1-WGA1       SAC-3P-M12MR-M12FR/.../...          3  0,34
# 3        =K1+UC1-WGB1          Ethernet Flexible Kabel          4    22
# 4        =K2+BB1-WDB1              ÖLFLEX® CLASSIC 110          2     1
# 5        =K2+BB1-WDB2              ÖLFLEX® CLASSIC 110          2     1
# 6        =K2+BB1-WGB1          Ethernet Flexible Kabel          4    22
# 7        =K2+BB1-WGB2          Ethernet Flexible Kabel          4    22
# 8         =F+UC1-WGB1          Ethernet Flexible Kabel          4    22
# 9       =FQJ+UC1-WGA1  C-M12F05-05X034PV10,0-MA-100184          5  0,34
# 10      =FQJ+UC1-WGA2              ÖLFLEX® CLASSIC 110          7     1
# 11
# 12      =FQJ+UC1-WGA3  C-M23F19-19XDIFPU10,0-MA-092901         19   0,5
# 13      =GLB+UC1-WDB1           ÖLFLEX® CLASSIC 100 CY         4G   2,5
# 14      =GLB+UC1-WGA1           ÖLFLEX® CLASSIC 110 CY          2  0,75
# 15      =GLB+UC1-WGA2              ÖLFLEX® CLASSIC 110          4     1
# 16      =GLB+UC1-WGB1          Ethernet Flexible Kabel          4    22
# 17      =GLB+BB1-WGA1       SAC-3P-M12MR-M12FR/.../...          3  0,34
# 18      =GLB+BB1-WGA2       SAC-3P-M12MR-M12FR/.../...          3  0,34
# 19      =GLC+UC1-WDB1           ÖLFLEX® CLASSIC 100 CY         4G   2,5
# 20      =GLC+UC1-WGA1           ÖLFLEX® CLASSIC 110 CY          2  0,75
# 21      =GLC+UC1-WGA2              ÖLFLEX® CLASSIC 110          4     1
# 22      =GLC+UC1-WGB1          Ethernet Flexible Kabel          4    22
# 23      =GLC+BB1-WGA1       SAC-3P-M12MR-M12FR/.../...          3  0,34
# 24      =GLC+BB1-WGA2       SAC-3P-M12MR-M12FR/.../...          3  0,34
# 25      =GLC+BB1-WGA3       SAC-3P-M12MR-M12FR/.../...          3  0,34
# 26      =GLC+BB1-WGA4       SAC-3P-M12MR-M12FR/.../...          3  0,34
# 27      =KEC+UC1-WDB1              ÖLFLEX® CLASSIC 110          5   2,5
# 28  =KEC+BB1.RA1-WGA1              ÖLFLEX® CLASSIC 110         25   0,5
# 29
# 30      =PHA+UC1-WGB1          Ethernet Flexible Kabel          4    22
# 31  =PHA+BB1.RA1-WGB1          Ethernet Flexible Kabel          4    22
#
#    Length                         Function text                From  \
# 0       3              Schaltschrankbeleuchtung       =GAA+UC1-XDA3
# 1      10                       Hauptventil ein       =GQA+UC1-XDA1
# 2       5                          Luftdruck ok       =GQA+BB1-BPA1
# 3   0.712                                            =K1+UC1-KE1-X1
# 4      10                                              =K2+UC1-XDA1
# 5      10                                               =K2+BB1-KE1
# 6       5                                           =K1+UC1-KEC1-X6
# 7       4                                            =K2+BB1-KE1-X5
# 8    0.76                                            =K1+UC1-KE1-X2
# 9      10                                             =FQJ+UC1-XGA1
# 10     10  Eingang in Sicherheitszone anfordern       =FQJ+UC1-XGA2
# 11                                               =FQJ+BB1.UCA3-SJB2
# 12     10                Türüberwachungsausgang       =FQJ+UC1-XGA3
# 13     10      Stromversorgung (Kettenförderer)       =GLB+UC1-TAC1
# 14     10                                     =       =GLB+UC1-TAC1
# 15     10     Not-Halt, Kettenförderer, Kanal 1          =F+UC1-KE2
# 16   1.78                                           =K1+UC1-KEC1-X5
# 17      5                Startposition erreicht         =K2+BB1-KE1
# 18      5                  Endposition erreicht         =K2+BB1-KE1
# 19     10          Stromversorgung (Rollenbahn)       =GLC+UC1-TAC1
# 20     10                                     =       =GLC+UC1-TAC1
# 21     10         Not-Halt, Rollenbahn, Kanal 1          =F+UC1-KE2
# 22  0.734                                          =GLB+UC1-TAC1-X2
# 23      5             Vorstoppzylinder betätigt         =K2+BB1-KE2
# 24      5              Stopperzylinder betätigt         =K2+BB1-KE2
# 25      5                Klemmzylinder betätigt         =K2+BB1-KE2
# 26      5                    In Position packen         =K2+BB1-KE2
# 27     10                       Supply AC 400 V       =KEC+UC1-XDA1
# 28     10                      Sicherheitskreis       =KEC+BB1-XGB2
# 29                                                =KEC+BB1.RA1-WEC1
# 30  2.135                                           =K1+UC1-KEC1-X8
# 31      7                                           =K1+UC1-KEC1-X7
#
#                       To
# 0          =GAA+UC1-EAA1
# 1       =GQA+BB1-QM1-MB1
# 2            =K2+BB1-KE1
# 3        =K1+UC1-KEC1-X1
# 4            =K2+BB1-KE1
# 5            =K2+BB1-KE2
# 6         =K2+BB1-KE1-X4
# 7         =K2+BB1-KE2-X4
# 8     =F+UC1-KE1-KEC1-X1
# 9          =FQJ+BB1-BYB1
# 10    =FQJ+BB1.UCA3-SJB1
# 11                  None
# 12          =FQJ+BB1-BG1
# 13         =GLB+BB1-MAA1
# 14         =GLB+BB1-MAA1
# 15    =GLB+BB1.UCA1-SGC1
# 16      =GLB+UC1-TAC1-X1
# 17         =GLB+BB1-BGA1
# 18         =GLB+BB1-BGA2
# 19         =GLC+BB1-MAA1
# 20         =GLC+BB1-MAA1
# 21    =GLC+BB1.UCA2-SGC1
# 22      =GLC+UC1-TAC1-X1
# 23         =GLC+BB1-BGA1
# 24         =GLC+BB1-BGA2
# 25         =GLC+BB1-BGA3
# 26         =GLC+BB1-BGA4
# 27     =KEC+BB1.RA1-KEB1
# 28     =KEC+BB1.RA1-KEB1
# 29                  None
# 30      =PHA+UC1-PHA1-X1
# 31  =KEC+BB1.RA1-KEB1-X1

# %%
df = extract(doc[52:55], TableType.DEVICE_TAG_LIST)
df
# Out:
# Extracting 'TableType.DEVICE_TAG_LIST' from 3 pages...
# Extracting 'TableType.DEVICE_TAG_LIST' from page #53
# Extracting 'TableType.DEVICE_TAG_LIST' from page #54
# Extracting 'TableType.DEVICE_TAG_LIST' from page #55
#      Device tag Quantity                                        Designation  \
# 0        +A1-U3        1                       Baying enclosure system VX25
# 1        +A1-U4        1  TS Cable duct for mounting plate, WHD: 60x2000...
# 2        +A1-U5        1  TS Cable duct for mounting plate, WHD: 60x2000...
# 3        +A1-U6        1  TS Cable duct for mounting plate, WHD: 60x2000...
# 4        +A1-U7        1  TS Cable duct for mounting plate, WHD: 30x2000...
# ..          ...      ...                                                ...
# 58  =TM2+A1-FC1        1               CIRCUIT-BREAKER SCREW CONNECTION 16A
# 59  =TM2+A1-TA1        1                     Vector oriented drive inverter
# 60  =GL3+A1-FC1        1                 CIRCUIT-BREAKER SPRING-L. CONN. 4A
# 61  =GL3+A1-QA1        1
# 62  =GL3+A1-QA2        1
#
#                                 Type number Manufacturer  \
# 0                                VX.8886000          RIT
# 1                                TS.8800752          RIT
# 2                                TS.8800752          RIT
# 3                                TS.8800752          RIT
# 4                                TS.8800750          RIT
# ..                                      ...          ...
# 58                            3RV2011-4AA10          SIE
# 59                       MC07B0015-5A3-4-00          SEW
# 60                            3RV2011-1EA25          SIE
# 61  3RH2911-1FA22-0MA0 + 3RH2911-1FA22-0MA0          SIE
# 62  3RH2911-1FA22-0MA0 + 3RH2911-1FA22-0MA0          SIE
#
#                Part number
# 0              RIT.8886000
# 1              RIT.8800752
# 2              RIT.8800752
# 3              RIT.8800752
# 4              RIT.8800750
# ..                     ...
# 58       SIE.3RV2011-4AA10
# 59  SEW.MC07B0015-5A3-4-00
# 60       SIE.3RV2011-1EA25
# 61     3RT2015-1BB41+1FA22
# 62     3RT2015-1BB41+1FA22
#
# [63 rows x 6 columns]

# %%
df = extract(doc[29:40], TableType.CONNECTION_LIST)
df
# Out:
# Extracting 'TableType.CONNECTION_LIST' from 11 pages...
# Extracting 'TableType.CONNECTION_LIST' from page #30
# Extracting 'TableType.CONNECTION_LIST' from page #31
# Extracting 'TableType.CONNECTION_LIST' from page #32
# Extracting 'TableType.CONNECTION_LIST' from page #33
# Extracting 'TableType.CONNECTION_LIST' from page #34
# Extracting 'TableType.CONNECTION_LIST' from page #35
# Extracting 'TableType.CONNECTION_LIST' from page #36
# Extracting 'TableType.CONNECTION_LIST' from page #37
# Extracting 'TableType.CONNECTION_LIST' from page #38
# Extracting 'TableType.CONNECTION_LIST' from page #39
# Extracting 'TableType.CONNECTION_LIST' from page #40
#     Connection       Target 1             Target 2 Color Cross-section
# 0                   +A1-XD1:1        =GAA+A1-FC1:1    BK             6
# 1               =GAA+A1-FC1:1         =EA+A1-FB1:1    OG             6
# 2                =EA+A1-FB1:1         =EA+A1-FB3:1    OG             6
# 3               =GAA+A1-FC1:2        =GAA+A1-FC2:1    BK             4
# 4               =GAA+A1-FC2:1    =GAB1+A1-FC1:1/L1    BK             4
# ..         ...            ...                  ...   ...           ...
# 594              +B3.X1-XZ1:9  =K1+B3.X1-KE1:3:2.1    GY          0,75
# 595             +B3.X1-XZ1:10  =K1+B3.X1-KE1:3:2.2    GY          0,75
# 596             +B3.X1-XZ1:11  =K1+B3.X1-KE1:3:2.3    GY          0,75
# 597                 +C2-XD1:1   =S2+C2-PH1:X1:X1.1    GY           1,5
# 598                 +C2-XD1:2   =S2+C2-PH1:X1:X1.2    BU           1,5
#
# [599 rows x 5 columns]

# %% [markdown]
# Now german

# %%
doc_de = pymupdf.open("pdfs/energy_de.pdf")

df = extract(doc_de[279:290], TableType.DEVICE_LIST_DE)
df
# Out:
# Extracting 'TableType.DEVICE_LIST_DE' from 11 pages...
# Extracting 'TableType.DEVICE_LIST_DE' from page #280
# Extracting 'TableType.DEVICE_LIST_DE' from page #281
# Extracting 'TableType.DEVICE_LIST_DE' from page #282
# Extracting 'TableType.DEVICE_LIST_DE' from page #283
# Extracting 'TableType.DEVICE_LIST_DE' from page #284
# Extracting 'TableType.DEVICE_LIST_DE' from page #285
# Extracting 'TableType.DEVICE_LIST_DE' from page #286
# Extracting 'TableType.DEVICE_LIST_DE' from page #287
# Extracting 'TableType.DEVICE_LIST_DE' from page #288
# Extracting 'TableType.DEVICE_LIST_DE' from page #289
# Extracting 'TableType.DEVICE_LIST_DE' from page #290
#     Referenzindikator ERP-Nummer   Betrag  \
# 0                WBB1                10 m
# 1                WBB2                10 m
# 2                WBB3                10 m
# 3                WBB4                 1 m
# 4                WBB5                 1 m
# ..                ...        ...      ...
# 300      =B2.HD1-SSJ1             1\n1\n1
# 301      =B2.HD1-XDA1   EES00003        1
# 302      =B2.KL1-QBB1                1\n3
# 303      =B2.KL2-QBB1                1\n3
# 304      =B2.KL3-QBB1                   1
#
#                                            Bezeichnung  \
# 0    Mittelspannungskabel N2XSY 6/10kV 1x35/16 (rm)...
# 1    Mittelspannungskabel N2XSY 6/10kV 1x35/16 (rm)...
# 2    Mittelspannungskabel N2XSY 6/10kV 1x35/16 (rm)...
# 3    Mittelspannungskabel N2XSY 6/10kV 1x35/16 (rm)...
# 4    Mittelspannungskabel N2XSY 6/10kV 1x35/16 (rm)...
# ..                                                 ...
# 300  Knebelschalter, O-I, schwarz, weiss\nSchildträ...
# 301                                          Endhalter
# 302  SV NH-Sicherungs-Lastschaltleiste, Gr. 1, 250 ...
# 303  SV NH-Sicherungs-Lastschaltleiste, Gr. 1, 250 ...
# 304  SV NH-Sicherungs-Lastschaltleiste, Gr. 1, 250 ...
#
#                                              Typnummer  \
# 0                       N2XSY 6/10kV, 12/20kV, 18/30kV
# 1                       N2XSY 6/10kV, 12/20kV, 18/30kV
# 2                       N2XSY 6/10kV, 12/20kV, 18/30kV
# 3                       N2XSY 6/10kV, 12/20kV, 18/30kV
# 4                       N2XSY 6/10kV, 12/20kV, 18/30kV
# ..                                                 ...
# 300  3SU1100-2BF60-1BA0\n3SU1900-0AS10-0AA0\n3SU190...
# 301                                         CLIPFIX 35
# 302                                SV.9677100\n3NA7132
# 303                                SV.9677100\n3NA7132
# 304                                         SV.9677100
#
#                     Hersteller  \
# 0                    Helukabel
# 1                    Helukabel
# 2                    Helukabel
# 3                    Helukabel
# 4                    Helukabel
# ..                         ...
# 300  Siemens\nSiemens\nSiemens
# 301            Phoenix Contact
# 302            Rittal\nSiemens
# 303            Rittal\nSiemens
# 304                     Rittal
#
#                                          Bestellnummer
# 0                                                32400
# 1                                                32400
# 2                                                32400
# 3                                                32400
# 4                                                32400
# ..                                                 ...
# 300  3SU1100-2BF60-1BA0\n3SU1900-0AS10-0AA0\n3SU190...
# 301                                            3022218
# 302                                   9677100\n3NA7132
# 303                                   9677100\n3NA7132
# 304                                            9677100
#
# [305 rows x 7 columns]

# %%
doc_de2 = pymupdf.open("pdfs/machine_building_de.pdf")

df = extract(doc_de2[137:144], TableType.DEVICE_LIST_DE)
df
# Out:
# Extracting 'TableType.DEVICE_LIST_DE' from 7 pages...
# Extracting 'TableType.DEVICE_LIST_DE' from page #138
# Extracting 'TableType.DEVICE_LIST_DE' from page #139
# Extracting 'TableType.DEVICE_LIST_DE' from page #140
# Extracting 'TableType.DEVICE_LIST_DE' from page #141
# Extracting 'TableType.DEVICE_LIST_DE' from page #142
# Extracting 'TableType.DEVICE_LIST_DE' from page #143
# Extracting 'TableType.DEVICE_LIST_DE' from page #144
#      Referenzindikator ERP-Nummer   Betrag  \
# 0              +UC1-U1                   1
# 1              +UC1-U2                   1
# 2              +UC1-U3                   1
# 3              +UC1-U8             0.699 m
# 4              +UC1-U9             0.699 m
# ..                 ...        ...      ...
# 167  =KEC+BB1.RA1-WGA1                10 m
# 168      =PHA+UC1-PHA1                   1
# 169   =PHA+UC1-PHA1-X1                   1
# 170      =PHA+UC1-WGB1             2.135 m
# 171  =PHA+BB1.RA1-WGB1                 7 m
#
#                                Bezeichnung              Typnummer  \
# 0                Anreih-Schranksystem VX25             VX.8806000
# 1    Seitenwand, verschraubbar, Stahlblech             VX.8106245
# 2    Seitenwand, verschraubbar, Stahlblech             VX.8106245
# 3                               Kabelkanal             TS.8800753
# 4                               Kabelkanal             TS.8800753
# ..                                     ...                    ...
# 167         Anschluss- und Steuerleitungen    ÖLFLEX® CLASSIC 110
# 168              SIMATIC HMI TP900 COMFORT     6AV2124-0JC01-0AX0
# 169                    RJ45-Steckverbinder  CUC-IND-C1ZNI-S/R4IE8
# 170                     TP Flexibles Kabel             6XV1870-2B
# 171                     TP Flexibles Kabel             6XV1870-2B
#
#           Hersteller       Bestellnummer
# 0             Rittal             8806000
# 1             Rittal             8106245
# 2             Rittal             8106245
# 3             Rittal             8800753
# 4             Rittal             8800753
# ..               ...                 ...
# 167       Lapp Group             1119025
# 168          Siemens  6AV2124-0JC01-0AX0
# 169  Phoenix Contact             1421607
# 170          Siemens          6XV1870-2B
# 171          Siemens          6XV1870-2B
#
# [172 rows x 7 columns]

# %% [markdown]
# # Then I want to create some Internal Representation

# %%
import uuid
import json as js
import re
import pandas as pd
from typing import List, Dict, Optional, Any, Union, Tuple
from abc import ABC
from configs import LevelConfig, AspectsConfig
from tag import Tag
from dataclasses import dataclass


@dataclass
class Attribute:
    def __init__(self, name: str, value: Union[str, dict[str, str], int]) -> None:
        self.name: str = name
        self.value: Union[str, dict[str, str], int] = value

    def __repr__(self) -> str:
        return f"Attribute(name={self.name}, value={self.value})"


# class Prefix(Attribute):
#     def __init__(self, name: str, value: str) -> None:
#         super().__init__(name, value)

# class Special(Attribute):
#     def __init__(self, name: str, value: str) -> None:
#         super().__init__(name, value)


# class Aspect:
#     def __init__(self, prefix: str, priority: int, role: str) -> None:
#         self.prefix: str = prefix
#         self.priority: int = priority
#         self.role: str = role


class XTarget:
    def __init__(
        self, tag_str: str = "", attributes: Optional[List[Attribute]] = None
    ) -> None:
        self.tag: Tag = Tag(tag_str)
        self.attributes: List[Attribute] = attributes or []

    def add_attribute(self, attribute: Attribute) -> None:
        self.attributes.append(attribute)

    def get_attribute(self, attr_type: type, name: str) -> Optional[Attribute]:
        for attribute in self.attributes:
            if isinstance(attribute, attr_type) and attribute.name == name:
                return attribute
        return None

    def remove_attribute(self, attr: Attribute) -> None:
        self.attributes = [
            attribute for attribute in self.attributes if attribute is not attr
        ]

    def get_name(self, configs: AspectsConfig) -> str:
        tag_parts = self.tag.get_tag_parts(configs)
        if not tag_parts:
            return ""
        ordered_seps = configs.separators()
        ordered_seps = [sep for sep in ordered_seps if sep in tag_parts]
        new_tag_str = "".join([f"{sep}{tag_parts[sep]}" for sep in ordered_seps])
        return new_tag_str

    def get_unique_id(self) -> str:
        # Everytime we process the pdf -> generate the same ID for the same tag
        import hashlib

        return hashlib.md5(self.tag.tag_str.encode()).hexdigest()

    def __repr__(self) -> str:
        return f"Object(tag={self.tag}, attributes={self.attributes})"


class Connection(XTarget):
    def __init__(
        self,
        von: Optional["XTarget"] = None,
        bis: Optional["XTarget"] = None,
        tag_str="",
        attributes: Optional[List[Attribute]] = None,
    ) -> None:
        super().__init__(tag_str, attributes)
        self.von: Optional["XTarget"] = von
        self.bis: Optional["XTarget"] = bis

    def __repr__(self) -> str:
        return "Connection(von={}, bis={}, tag={}, attributes={})".format(
            self.von.__repr__(), self.bis.__repr__(), self.tag.tag_str, self.attributes
        )

    def get_name(self, configs: AspectsConfig) -> str:
        return 'Connection(von="{}", bis="{}", tag="{}", attributes={})'.format(
            self.von.get_name(configs) if self.von else "None",
            self.bis.get_name(configs) if self.bis else "None",
            self.tag.tag_str,
            self.attributes,
        )


class Manager:
    def __init__(self, configs: AspectsConfig) -> None:
        self.empty_object: XTarget = XTarget("")
        self.objects: List[XTarget] = [self.empty_object]
        self.connections: List[Connection] = []
        self.configs: AspectsConfig = configs
        self.obj_map: Dict[str, XTarget] = {}
        self.setup_configs()

    def setup_configs(self) -> None:
        # recompute lookup table
        if self.objects is not None:
            self.obj_map = {obj.get_name(self.configs): obj for obj in self.objects}

    def get_tag_list(self) -> List[str]:
        return sorted(self.obj_map.keys())

    def build_tree(self) -> Dict[str, Any]:
        # form tree of objects by aspects. Level of the tree is aspect priority
        tree: Dict[str, Any] = {}

        def insert_node(tree: Dict[str, Any], obj: XTarget) -> None:
            node: Dict[str, Any] = tree
            tag_parts = obj.tag.get_tag_parts(self.configs)

            for separator in self.configs.separators():
                if separator in tag_parts:
                    node = node.setdefault(separator, {})
                    node = node.setdefault(tag_parts[separator], {})
            node.setdefault("_objects", []).append(obj)

        for obj in self.objects:
            insert_node(tree, obj)
        return tree

    def object_from_tag(self, tag_str: str) -> XTarget:
        obj_name = XTarget(tag_str).get_name(self.configs)
        if obj_name in self.obj_map:
            return self.obj_map[obj_name]

        # if not - add to lookup and to objects
        obj: XTarget = XTarget(tag_str)

        # Store
        self.obj_map[obj_name] = obj
        self.objects.append(obj)
        return obj

    def read_objects(self, df: pd.DataFrame, tag_column: Optional[str] = None) -> None:
        # pick the column
        if tag_column is None:
            tag_column = df.columns[0]

        for _, row in df.iterrows():
            tag_str: str = str(row[tag_column]) if pd.notna(row[tag_column]) else ""
            if not tag_str.strip():
                continue

            obj: XTarget = self.object_from_tag(tag_str)

            # Add all other columns as regular Attributes
            for col in df.columns:
                if col == tag_column:
                    continue
                value: Any = row[col]
                if pd.notna(value) and str(value).strip() != "":
                    # Flatten attribute if contains '\n'
                    values: List[str] = str(value).split("\n")
                    joined_value: str = " <br/> ".join(
                        v.strip() for v in values if v.strip() != ""
                    )
                    if joined_value:
                        obj.add_attribute(Attribute(col, joined_value))

    def read_connections(
        self,
        df: pd.DataFrame,
        von_column: Optional[str] = None,
        bis_column: Optional[str] = None,
        this_column: Optional[str] = None,
    ) -> None:
        connections: List[Connection] = []

        # Default to first column if not provided
        if von_column is None:
            von_column = df.columns[1]
        if bis_column is None:
            bis_column = df.columns[2]
        if this_column is None:
            this_column = df.columns[0]

        for _, row in df.iterrows():
            von: Optional[XTarget] = None
            bis: Optional[XTarget] = None

            von_name: Optional[str] = (
                row[von_column] if pd.notna(row[von_column]) else None
            )
            bis_name: Optional[str] = (
                row[bis_column] if pd.notna(row[bis_column]) else None
            )
            this_name: Optional[str] = (
                row[this_column] if pd.notna(row[this_column]) else None
            )

            if von_name and von_name.strip():
                von = self.object_from_tag(von_name)
                von.add_attribute(
                    Attribute("link", f"to {bis_name} through {this_name}")
                )
            else:
                von = self.empty_object

            if bis_name and bis_name.strip():
                bis = self.object_from_tag(bis_name)
                bis.add_attribute(
                    Attribute("link", f"to {von_name} through {this_name}")
                )
            else:
                bis = self.empty_object

            # Collect any additional attributes from other columns
            attributes: List[Attribute] = []
            for col in df.columns:
                if col in (von_column, bis_column, this_column):
                    continue
                val: Any = row[col]
                if pd.notna(val) and str(val).strip() != "":
                    attributes.append(Attribute(col, str(val)))

            conn: Connection = Connection(
                von=von, bis=bis, tag_str=this_name or "", attributes=attributes
            )
            connections.append(conn)

        self.connections = connections

    def print_stats(self) -> None:
        print(f"Has {len(self.objects)} objects")

        for o in self.objects:
            print(f"Object: {o}")

        print(f"Has {len(self.connections)} connections")

        for c in self.connections:
            print(f"Connection: {c.get_name(self.configs)}")

# %%
# Create configs using the new architecture
from configs import AspectsConfig, LevelConfig
from typing import OrderedDict

configs = AspectsConfig(
    OrderedDict(
        {
            "=": LevelConfig(Order=1, Separator="=", Aspect="function"),
            "+": LevelConfig(Order=2, Separator="+", Aspect="location"),
            "-": LevelConfig(Order=3, Separator="-", Aspect="div"),
        }
    )
)

print("Configs separators:", list(configs.separators()))
print("Configs aspects:", configs.aspects())
# Out:
# Configs separators: ['=', '+', '-']
# Configs aspects: ['function', 'location', 'div']

# %%
# Update to use Manager for reading objects
mngr = Manager(configs)
mngr.read_objects(df)

print(f"Extracted {len(mngr.objects)} objects")

for o in mngr.objects:
    name = o.get_name(configs)
    if name:  # Skip empty objects
        print(name)
# Out:
# No valid separators found in tag string: *
# Failed to parse tag string: * with config: AspectsConfig(levels=OrderedDict({'=': LevelConfig(Order=1, Separator='=', Aspect='function'), '+': LevelConfig(Order=2, Separator='+', Aspect='location'), '-': LevelConfig(Order=3, Separator='-', Aspect='div')}))
# No valid separators found in tag string: *
# Failed to parse tag string: * with config: AspectsConfig(levels=OrderedDict({'=': LevelConfig(Order=1, Separator='=', Aspect='function'), '+': LevelConfig(Order=2, Separator='+', Aspect='location'), '-': LevelConfig(Order=3, Separator='-', Aspect='div')}))
# No valid separators found in tag string: *
# Failed to parse tag string: * with config: AspectsConfig(levels=OrderedDict({'=': LevelConfig(Order=1, Separator='=', Aspect='function'), '+': LevelConfig(Order=2, Separator='+', Aspect='location'), '-': LevelConfig(Order=3, Separator='-', Aspect='div')}))
# No valid separators found in tag string: *
# Failed to parse tag string: * with config: AspectsConfig(levels=OrderedDict({'=': LevelConfig(Order=1, Separator='=', Aspect='function'), '+': LevelConfig(Order=2, Separator='+', Aspect='location'), '-': LevelConfig(Order=3, Separator='-', Aspect='div')}))
# Extracted 1 objects

# %%
# Update to use Manager for reading connections
mngr = Manager(configs)
df = extract(doc[29:40], TableType.CONNECTION_LIST)

display(df)
mngr.read_connections(df)

print(f"Extracted {len(mngr.connections)} connections")

for c in mngr.connections:
    print(c.get_name(configs))
# Out:
# Extracting 'TableType.CONNECTION_LIST' from 11 pages...
# Extracting 'TableType.CONNECTION_LIST' from page #30
# Extracting 'TableType.CONNECTION_LIST' from page #31
# Extracting 'TableType.CONNECTION_LIST' from page #32
# Extracting 'TableType.CONNECTION_LIST' from page #33
# Extracting 'TableType.CONNECTION_LIST' from page #34
# Extracting 'TableType.CONNECTION_LIST' from page #35
# Extracting 'TableType.CONNECTION_LIST' from page #36
# Extracting 'TableType.CONNECTION_LIST' from page #37
# Extracting 'TableType.CONNECTION_LIST' from page #38
# Extracting 'TableType.CONNECTION_LIST' from page #39
# Extracting 'TableType.CONNECTION_LIST' from page #40
#     Connection       Target 1             Target 2 Color Cross-section
# 0                   +A1-XD1:1        =GAA+A1-FC1:1    BK             6
# 1               =GAA+A1-FC1:1         =EA+A1-FB1:1    OG             6
# 2                =EA+A1-FB1:1         =EA+A1-FB3:1    OG             6
# 3               =GAA+A1-FC1:2        =GAA+A1-FC2:1    BK             4
# 4               =GAA+A1-FC2:1    =GAB1+A1-FC1:1/L1    BK             4
# ..         ...            ...                  ...   ...           ...
# 594              +B3.X1-XZ1:9  =K1+B3.X1-KE1:3:2.1    GY          0,75
# 595             +B3.X1-XZ1:10  =K1+B3.X1-KE1:3:2.2    GY          0,75
# 596             +B3.X1-XZ1:11  =K1+B3.X1-KE1:3:2.3    GY          0,75
# 597                 +C2-XD1:1   =S2+C2-PH1:X1:X1.1    GY           1,5
# 598                 +C2-XD1:2   =S2+C2-PH1:X1:X1.2    BU           1,5
#
# [599 rows x 5 columns]
# Extracted 599 connections
# Connection(von="+A1-XD1:1", bis="=GAA+A1-FC1:1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=6)])
# Connection(von="=GAA+A1-FC1:1", bis="=EA+A1-FB1:1", tag="", attributes=[Attribute(name=Color, value=OG), Attribute(name=Cross-section, value=6)])
# Connection(von="=EA+A1-FB1:1", bis="=EA+A1-FB3:1", tag="", attributes=[Attribute(name=Color, value=OG), Attribute(name=Cross-section, value=6)])
# Connection(von="=GAA+A1-FC1:2", bis="=GAA+A1-FC2:1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=4)])
# Connection(von="=GAA+A1-FC2:1", bis="=GAB1+A1-FC1:1/L1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=4)])
# Connection(von="=GAB1+A1-FC1:1/L1", bis="=GAB2+A1-FC1:1/L1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=4)])
# Connection(von="=GAB2+A1-FC1:1/L1", bis="=GL1+A1-FC1:1/L1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=4)])
# Connection(von="=GL1+A1-FC1:1/L1", bis="=GL2+A1-FC1:1/L1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=4)])
# Connection(von="=GL2+A1-FC1:1/L1", bis="=TM1+A1-FC1:1/L1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=4)])
# Connection(von="=TM1+A1-FC1:1/L1", bis="=TM2+A1-FC1:1/L1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=4)])
# Connection(von="=TM2+A1-FC1:1/L1", bis="=GL3+A1-FC1:1/L1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=4)])
# Connection(von="+A1-XD1:2", bis="=GAA+A1-FC1:3", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=6)])
# Connection(von="=GAA+A1-FC1:3", bis="=EA+A1-FB2:1", tag="", attributes=[Attribute(name=Color, value=OG), Attribute(name=Cross-section, value=6)])
# Connection(von="=EA+A1-FB2:1", bis="=EA+A1-FB4:1", tag="", attributes=[Attribute(name=Color, value=OG), Attribute(name=Cross-section, value=6)])
# Connection(von="=GAA+A1-FC1:4", bis="=GAA+A1-FC3:1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=4)])
# Connection(von="=GAA+A1-FC3:1", bis="=GAB1+A1-FC1:3/L2", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=4)])
# Connection(von="=GAB1+A1-FC1:3/L2", bis="=GAB2+A1-FC1:3/L2", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=4)])
# Connection(von="=GAB2+A1-FC1:3/L2", bis="=GL1+A1-FC1:3/L2", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=4)])
# Connection(von="=GL1+A1-FC1:3/L2", bis="=GL2+A1-FC1:3/L2", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=4)])
# Connection(von="=GL2+A1-FC1:3/L2", bis="=TM1+A1-FC1:3/L2", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=4)])
# Connection(von="=TM1+A1-FC1:3/L2", bis="=TM2+A1-FC1:3/L2", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=4)])
# Connection(von="=TM2+A1-FC1:3/L2", bis="=GL3+A1-FC1:3/L2", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=4)])
# Connection(von="+A1-XD1:3", bis="=GAA+A1-FC1:5", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=6)])
# Connection(von="=GAA+A1-FC1:5", bis="=GAA+A1-FC5:1", tag="", attributes=[Attribute(name=Color, value=OG), Attribute(name=Cross-section, value=6)])
# Connection(von="=GAA+A1-FC1:6", bis="=GAA+A1-FC4:1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=4)])
# Connection(von="=GAA+A1-FC4:1", bis="=GAB1+A1-FC1:5/L3", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=4)])
# Connection(von="=GAB1+A1-FC1:5/L3", bis="=GAB2+A1-FC1:5/L3", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=4)])
# Connection(von="=GAB2+A1-FC1:5/L3", bis="=GL1+A1-FC1:5/L3", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=4)])
# Connection(von="=GL1+A1-FC1:5/L3", bis="=GL2+A1-FC1:5/L3", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=4)])
# Connection(von="=GL2+A1-FC1:5/L3", bis="=TM1+A1-FC1:5/L3", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=4)])
# Connection(von="=TM1+A1-FC1:5/L3", bis="=TM2+A1-FC1:5/L3", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=4)])
# Connection(von="=TM2+A1-FC1:5/L3", bis="=GL3+A1-FC1:5/L3", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=4)])
# Connection(von="+A1-XD5:6", bis="=GAA+A1-TA3:k", tag="", attributes=[Attribute(name=Color, value=BN), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A1-XD5:5", bis="=GAA+A1-TA3:l", tag="", attributes=[Attribute(name=Color, value=BN), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A1-XD5:4", bis="=GAA+A1-TA2:k", tag="", attributes=[Attribute(name=Color, value=BN), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A1-XD5:3", bis="=GAA+A1-TA2:l", tag="", attributes=[Attribute(name=Color, value=BN), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A1-XD5:2", bis="=GAA+A1-TA1:k", tag="", attributes=[Attribute(name=Color, value=BN), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A1-XD5:1", bis="=GAA+A1-TA1:l", tag="", attributes=[Attribute(name=Color, value=BN), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A1-WE2:1", bis="+A1-XD1:7", tag="", attributes=[Attribute(name=Color, value=BU), Attribute(name=Cross-section, value=6)])
# Connection(von="+A1-XD5:6", bis="=GAA+A1-PF1:I3:11", tag="", attributes=[Attribute(name=Color, value=BN), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A1-XD5:5", bis="=GAA+A1-PF1:I3:9", tag="", attributes=[Attribute(name=Color, value=BN), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A1-XD5:4", bis="=GAA+A1-PF1:I2:7", tag="", attributes=[Attribute(name=Color, value=BN), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A1-XD5:3", bis="=GAA+A1-PF1:I2:5", tag="", attributes=[Attribute(name=Color, value=BN), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A1-XD5:2", bis="=GAA+A1-PF1:I1:3", tag="", attributes=[Attribute(name=Color, value=BN), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A1-XD5:1", bis="=GAA+A1-PF1:I1:1", tag="", attributes=[Attribute(name=Color, value=BN), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A1-WE1:1", bis="+A1-XD1:8", tag="", attributes=[Attribute(name=Color, value=GNYE), Attribute(name=Cross-section, value=6)])
# Connection(von="=GAA+A1-FC5:2", bis="=GAA+A1-PF1:AUX SUPPLY:20", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A1-WE2:9", bis="=GAA+A1-PF1:AUX SUPPLY:22", tag="", attributes=[Attribute(name=Color, value=BU), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A1-FC2:1", bis="+A1-XD1:4", tag="", attributes=[Attribute(name=Color, value=OG), Attribute(name=Cross-section, value=6)])
# Connection(von="+A1-FC2:1", bis="=GAA+A1-PF1:I3:12", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A1-FC2:2", bis="+A1-XD1:5", tag="", attributes=[Attribute(name=Color, value=OG), Attribute(name=Cross-section, value=6)])
# Connection(von="+A1-FC2:2", bis="=GAA+A1-PF1:I3:14", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A1-FC2:3", bis="+A1-XD1:6", tag="", attributes=[Attribute(name=Color, value=OG), Attribute(name=Cross-section, value=6)])
# Connection(von="+A1-FC2:3", bis="=GAA+A1-PF1:I3:16", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A1-WE2:2", bis="=GAA+A1-PF1:I3:2", tag="", attributes=[Attribute(name=Color, value=BU), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A1-WE1:2", bis="=GAA+A1-PF1:I3:18", tag="", attributes=[Attribute(name=Color, value=GNYE), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=GAA+A1-PF1:x2", bis="=GAA+A1-PF1:RS485:17", tag="", attributes=[])
# Connection(von="=GAA+A1-PF1:x1", bis="=GAA+A1-PF1:RS485:15", tag="", attributes=[])
# Connection(von="=GAA+A1-FC2:2", bis="=GAA+A1-PF2:X1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A1-WE2:8", bis="=GAA+A1-PF2:X2", tag="", attributes=[Attribute(name=Color, value=BU), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=GAA+A1-PF2:X2", bis="=GAA+A1-PF3:X2", tag="", attributes=[Attribute(name=Color, value=BU), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=GAA+A1-PF3:X2", bis="=GAA+A1-PF4:X2", tag="", attributes=[Attribute(name=Color, value=BU), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=GAA+A1-FC3:2", bis="=GAA+A1-PF3:X1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=GAA+A1-FC4:2", bis="=GAA+A1-PF4:X1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A1-XD3:1", bis="=GAB1+A1-FC1:2/T1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A1-XD3:2", bis="=GAB1+A1-FC1:4/T2", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A1-XD3:3", bis="=GAB1+A1-FC1:6/T3", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A1-XD3:6", bis="=GAB2+A1-FC1:2/T1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A1-XD3:7", bis="=GAB2+A1-FC1:4/T2", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A1-XD3:8", bis="=GAB2+A1-FC1:6/T3", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A1-XG1:1", bis="=GAB2+A1-FC1:14", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A1-XG1:2", bis="=GAB2+A1-FC1:13", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A1-XD2:1", bis="=EA+A1-FB1:2", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A1-WE2:4", bis="=EA+A1-FB1:N", tag="", attributes=[Attribute(name=Color, value=BU), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A1-XD2:3", bis="=EA+A1-FB1:N.", tag="", attributes=[Attribute(name=Color, value=BU), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A1-XD2:4", bis="=EA+A1-XD1:L", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A1-XD2:4", bis="=EA+A1-FB2:2", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A1-XD2:5", bis="=EA+A1-XD1:PE", tag="", attributes=[Attribute(name=Color, value=GNYE), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A1-WE2:5", bis="=EA+A1-FB2:N", tag="", attributes=[Attribute(name=Color, value=BU), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A1-XD2:6", bis="=EA+A1-XD1:N", tag="", attributes=[Attribute(name=Color, value=BU), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A1-XD2:6", bis="=EA+A1-FB2:N.", tag="", attributes=[Attribute(name=Color, value=BU), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A1-XD2:7", bis="=EA+A1-FB3:2", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A1-WE2:6", bis="=EA+A1-FB3:N", tag="", attributes=[Attribute(name=Color, value=BU), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A1-XD2:9", bis="=EA+A1-FB3:N.", tag="", attributes=[Attribute(name=Color, value=BU), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A1-XD2:10", bis="=EA+A1-FB4:2", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A1-WE2:7", bis="=EA+A1-FB4:N", tag="", attributes=[Attribute(name=Color, value=BU), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A1-XD2:12", bis="=EA+A1-FB4:N.", tag="", attributes=[Attribute(name=Color, value=BU), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A1-XD4:1", bis="=GL1+A1-QA1:2/T1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=2,5)])
# Connection(von="=GL1+A1-QA1:2/T1", bis="=GL1+A1-QA2:2/T1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=2,5)])
# Connection(von="=GL1+A1-FC1:2/T1", bis="=GL1+A1-QA1:1/L1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=2,5)])
# Connection(von="=GL1+A1-QA1:1/L1", bis="=GL1+A1-QA2:5/L3", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=2,5)])
# Connection(von="+A1-XD4:2", bis="=GL1+A1-QA1:4/T2", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=2,5)])
# Connection(von="=GL1+A1-QA1:4/T2", bis="=GL1+A1-QA2:4/T2", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=2,5)])
# Connection(von="=GL1+A1-FC1:4/T2", bis="=GL1+A1-QA1:3/L2", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=2,5)])
# Connection(von="=GL1+A1-QA1:3/L2", bis="=GL1+A1-QA2:3/L2", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=2,5)])
# Connection(von="+A1-XD4:3", bis="=GL1+A1-QA1:6/T3", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=2,5)])
# Connection(von="=GL1+A1-QA1:6/T3", bis="=GL1+A1-QA2:6/T3", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=2,5)])
# Connection(von="=GL1+A1-FC1:6/T3", bis="=GL1+A1-QA1:5/L3", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=2,5)])
# Connection(von="=GL1+A1-QA1:5/L3", bis="=GL1+A1-QA2:1/L1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=2,5)])
# Connection(von="+A1-XG1:3", bis="=GL1+A1-FC1:14", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A1-XG1:4", bis="=GL1+A1-FC1:13", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="=GL1+A1-QA1:A1", bis="=GL1+A1-QA2:12", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A1-XG1:5", bis="=GL1+A1-QA2:11", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A1-XG1:6", bis="=GL1+A1-QA1:A2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="=GL1+A1-QA1:12", bis="=GL1+A1-QA2:A1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A1-XG1:7", bis="=GL1+A1-QA1:11", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A1-XG1:8", bis="=GL1+A1-QA2:A2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A1-XG1:9", bis="=GL1+A1-QA1:14", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A1-XG1:10", bis="=GL1+A1-QA1:13", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A1-XG1:11", bis="=GL1+A1-QA2:14", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A1-XG1:12", bis="=GL1+A1-QA2:13", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A1-XD4:6", bis="=GL2+A1-QA1:2/T1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=2,5)])
# Connection(von="=GL2+A1-QA1:2/T1", bis="=GL2+A1-QA2:2/T1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=2,5)])
# Connection(von="=GL2+A1-FC1:2/T1", bis="=GL2+A1-QA1:1/L1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=2,5)])
# Connection(von="=GL2+A1-QA1:1/L1", bis="=GL2+A1-QA2:5/L3", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=2,5)])
# Connection(von="+A1-XD4:7", bis="=GL2+A1-QA1:4/T2", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=2,5)])
# Connection(von="=GL2+A1-QA1:4/T2", bis="=GL2+A1-QA2:4/T2", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=2,5)])
# Connection(von="=GL2+A1-FC1:4/T2", bis="=GL2+A1-QA1:3/L2", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=2,5)])
# Connection(von="=GL2+A1-QA1:3/L2", bis="=GL2+A1-QA2:3/L2", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=2,5)])
# Connection(von="+A1-XD4:8", bis="=GL2+A1-QA1:6/T3", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=2,5)])
# Connection(von="=GL2+A1-QA1:6/T3", bis="=GL2+A1-QA2:6/T3", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=2,5)])
# Connection(von="=GL2+A1-FC1:6/T3", bis="=GL2+A1-QA1:5/L3", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=2,5)])
# Connection(von="=GL2+A1-QA1:5/L3", bis="=GL2+A1-QA2:1/L1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=2,5)])
# Connection(von="+A1-XG1:13", bis="=GL2+A1-FC1:14", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A1-XG1:14", bis="=GL2+A1-FC1:13", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="=GL2+A1-QA1:A1", bis="=GL2+A1-QA2:12", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A1-XG1:15", bis="=GL2+A1-QA2:11", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A1-XG1:16", bis="=GL2+A1-QA1:A2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="=GL2+A1-QA1:12", bis="=GL2+A1-QA2:A1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A1-XG1:17", bis="=GL2+A1-QA1:11", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A1-XG1:18", bis="=GL2+A1-QA2:A2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A1-XG1:19", bis="=GL2+A1-QA1:14", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A1-XG1:20", bis="=GL2+A1-QA1:13", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A1-XG1:21", bis="=GL2+A1-QA2:14", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A1-XG1:22", bis="=GL2+A1-QA2:13", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="=TM1+A1-FC1:2/T1", bis="=TM1+A1-TA1:X1:1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=2,5)])
# Connection(von="=TM1+A1-FC1:4/T2", bis="=TM1+A1-TA1:X1:2", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=2,5)])
# Connection(von="=TM1+A1-FC1:6/T3", bis="=TM1+A1-TA1:X1:3", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=2,5)])
# Connection(von="+A1-WE1:4", bis="=TM1+A1-TA1:X1:PE1", tag="", attributes=[Attribute(name=Color, value=GNYE), Attribute(name=Cross-section, value=6)])
# Connection(von="+A1-XG1:23", bis="=TM1+A1-FC1:14", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A1-XG1:24", bis="=TM1+A1-FC1:13", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A1-XG1:25", bis="=TM1+A1-TA1:X12:1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A1-XG1:26", bis="=TM1+A1-TA1:X12:9", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="=TM2+A1-FC1:2/T1", bis="=TM2+A1-TA1:X1:1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=2,5)])
# Connection(von="=TM2+A1-FC1:4/T2", bis="=TM2+A1-TA1:X1:2", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=2,5)])
# Connection(von="=TM2+A1-FC1:6/T3", bis="=TM2+A1-TA1:X1:3", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=2,5)])
# Connection(von="+A1-WE1:5", bis="=TM2+A1-TA1:X1:PE1", tag="", attributes=[Attribute(name=Color, value=GNYE), Attribute(name=Cross-section, value=6)])
# Connection(von="+A1-XG1:27", bis="=TM2+A1-FC1:14", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A1-XG1:28", bis="=TM2+A1-FC1:13", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A1-XG1:29", bis="=TM2+A1-TA1:X12:1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A1-XG1:30", bis="=TM2+A1-TA1:X12:9", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A1-XD4:11", bis="=GL3+A1-QA1:2/T1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=2,5)])
# Connection(von="=GL3+A1-QA1:2/T1", bis="=GL3+A1-QA2:2/T1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=2,5)])
# Connection(von="=GL3+A1-FC1:2/T1", bis="=GL3+A1-QA1:1/L1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=2,5)])
# Connection(von="=GL3+A1-QA1:1/L1", bis="=GL3+A1-QA2:5/L3", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=2,5)])
# Connection(von="+A1-XD4:12", bis="=GL3+A1-QA1:4/T2", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=2,5)])
# Connection(von="=GL3+A1-QA1:4/T2", bis="=GL3+A1-QA2:4/T2", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=2,5)])
# Connection(von="=GL3+A1-FC1:4/T2", bis="=GL3+A1-QA1:3/L2", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=2,5)])
# Connection(von="=GL3+A1-QA1:3/L2", bis="=GL3+A1-QA2:3/L2", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=2,5)])
# Connection(von="+A1-XD4:13", bis="=GL3+A1-QA1:6/T3", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=2,5)])
# Connection(von="=GL3+A1-QA1:6/T3", bis="=GL3+A1-QA2:6/T3", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=2,5)])
# Connection(von="=GL3+A1-FC1:6/T3", bis="=GL3+A1-QA1:5/L3", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=2,5)])
# Connection(von="=GL3+A1-QA1:5/L3", bis="=GL3+A1-QA2:1/L1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=2,5)])
# Connection(von="+A1-XG1:31", bis="=GL3+A1-FC1:14", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A1-XG1:32", bis="=GL3+A1-FC1:13", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="=GL3+A1-QA1:A1", bis="=GL3+A1-QA2:12", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A1-XG1:33", bis="=GL3+A1-QA2:11", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A1-XG1:34", bis="=GL3+A1-QA1:A2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="=GL3+A1-QA1:12", bis="=GL3+A1-QA2:A1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A1-XG1:35", bis="=GL3+A1-QA1:11", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A1-XG1:36", bis="=GL3+A1-QA2:A2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A1-XG1:37", bis="=GL3+A1-QA1:14", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A1-XG1:38", bis="=GL3+A1-QA1:13", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A1-XG1:39", bis="=GL3+A1-QA2:14", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A1-XG1:40", bis="=GL3+A1-QA2:13", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XD2:1", bis="=K1+A2-FC1:1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=K1+A2-FC1:1", bis="=K1+A2-FC2:1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=K1+A2-FC2:1", bis="=K1+A2-FC5:1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=K1+A2-FC5:1", bis="=K1+A2-FC7:1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=K1+A2-FC7:1", bis="=K1+A2-FC9:1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=K1+A2-FC9:1", bis="=K2+A2-FC1:1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=K2+A2-FC1:1", bis="=S1+A2-FC2:1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=S1+A2-FC2:1", bis="=S2+A2-FC1:1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A2-XD2:1", bis="=GAB1+A2-FC1:2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=GAB1+A2-FC1:1", bis="=GAB1+-TB1:OutDC:", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A2-XD1:1", bis="=GAB1+-TB1:InAC:L1/", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A2-XD2:2", bis="=GAB1+A2-PF1:X1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=GAB1+A2-TB1:OutDC", bis="=GAB1+A2-TB1:OutDC", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A2-XD1:2", bis="=GAB1+A2-TB1:InAC:L2", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A2-XD2:3", bis="+A2-XD6:2", tag="", attributes=[Attribute(name=Color, value=BU), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A2-XD2:3", bis="=GAB1+A2-", tag="", attributes=[Attribute(name=Color, value=BU), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A2-XD1:3", bis="=GAB1+A2-", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A2-XD2:4", bis="=GAB1+A2-PF1:X2", tag="", attributes=[Attribute(name=Color, value=BU), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A2-XD2:4", bis="+A2-XD2:5", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=GAB1+A2-TB1:OutDC", bis="=GAB1+A2-TB1:OutDC", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=GAB1+A2-TB1:OutDC", bis="=GAB1+A2-TB1:OutDC", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A2-XD1:5", bis="=GAB1+A2-TB1:InAC:PE", tag="", attributes=[Attribute(name=Color, value=GNYE), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A2-XD4:1", bis="=K1+A2-FC3:1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=F+A2-FC1:1", bis="=K1+A2-FC3:1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=F+A2-FC1:1", bis="=K1+A2-FC4:1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=K1+A2-FC4:1", bis="=K1+A2-FC6:1", tag="", attributes=[Attribute(name=Color, value=BU), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=K1+A2-FC6:1", bis="=K1+A2-FC8:1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=K1+A2-FC8:1", bis="=K1+A2-FC10:1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A2-XD4:1", bis="=GAB2+A2-FC1:2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=GAB2+A2-FC1:1", bis="=GAB2+-TB1:OutDC:", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A2-XD1:6", bis="=GAB2+-TB1:InAC:L1/", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A2-XD4:2", bis="=GAB2+A2-PF1:X1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=GAB2+A2-TB1:OutDC", bis="=GAB2+A2-TB1:OutDC", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A2-XD1:7", bis="=GAB2+A2-TB1:InAC:L2", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A2-XD4:3", bis="=K1+A2-KE1:1:2.3", tag="", attributes=[Attribute(name=Color, value=BU), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=F+A2-KE1:1:2.3", bis="=K1+A2-KE1:1:2.3", tag="", attributes=[Attribute(name=Color, value=BU), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=F+A2-KE1:1:2.3", bis="=K1+A2-KE4:1:2.3", tag="", attributes=[Attribute(name=Color, value=BU), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A2-XD7:5", bis="=K1+A2-KE4:1:2.3", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A2-XD7:5", bis="+A2-XD7:10", tag="", attributes=[Attribute(name=Color, value=BU), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A2-XD7:10", bis="+A2-XD7:15", tag="", attributes=[Attribute(name=Color, value=BU), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A2-XD4:3", bis="=GAB2+A2-", tag="", attributes=[Attribute(name=Color, value=BU), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A2-XD1:8", bis="=GAB2+A2-", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A2-XD4:4", bis="=GAB2+A2-PF1:X2", tag="", attributes=[Attribute(name=Color, value=BU), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A2-XD4:4", bis="+A2-XD4:5", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=GAB2+A2-TB1:OutDC", bis="=GAB2+A2-TB1:OutDC", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=GAB2+A2-TB1:OutDC", bis="=GAB2+A2-TB1:OutDC", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A2-XD1:9", bis="=GAB2+A2-TB1:InAC:PE", tag="", attributes=[Attribute(name=Color, value=GNYE), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A2-XG5:1", bis="=K1+A2-KE1:4:4.1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG1:1", bis="+A2-XG5:1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG1:1", bis="=GAB2+A2-TB1:Signal:14", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG5:2", bis="=K1+A2-KE1:4:4.2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG1:2", bis="+A2-XG5:2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG1:2", bis="=GAB2+A2-TB1:Signal:13", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG5:3", bis="=K1+A2-KE1:4:4.3", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG1:3", bis="+A2-XG5:3", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG5:4", bis="=K1+A2-KE1:4:3.1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG1:4", bis="+A2-XG5:4", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG5:5", bis="=K1+A2-KE1:4:3.2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG1:5", bis="+A2-XG5:5", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG5:6", bis="=K1+A2-KE1:4:3.3", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG1:6", bis="+A2-XG5:6", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XD5:4", bis="=EA+A2-XD1:L", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A2-XD5:5", bis="=EA+A2-XD1:PE", tag="", attributes=[Attribute(name=Color, value=GNYE), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A2-XD5:6", bis="=EA+A2-XD1:N", tag="", attributes=[Attribute(name=Color, value=BU), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+A2-XG2:1", bis="=F+A2-KF1:A1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG2:1", bis="=F+A2-KE4:1:1.1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG2:2", bis="=F+A2-KE4:1:1.2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG2:3", bis="=F+A2-KF1:A2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG2:3", bis="=F+A2-KE4:1:1.3", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG2:4", bis="=F+A2-KE4:1:1.4", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG2:17", bis="=F+A2-KF2:A1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG2:17", bis="=F+A2-KE4:3:5.1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG2:18", bis="=F+A2-KE4:3:5.2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG2:19", bis="=F+A2-KF2:A2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG2:19", bis="=F+A2-KE4:3:5.3", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG2:20", bis="=F+A2-KE4:3:5.4", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG3:49", bis="=F+A2-KE3:4:7.1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG3:49", bis="=F+A2-KF1:44", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG3:50", bis="=F+A2-KE3:4:7.2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG3:50", bis="=F+A2-KF1:43", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG3:51", bis="=F+A2-KE3:4:7.3", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG3:52", bis="=F+A2-KE3:4:7.4", tag="", attributes=[Attribute(name=Color, value=GNYE), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG3:53", bis="=F+A2-KE3:4:8.1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG3:53", bis="=F+A2-KF2:44", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG3:54", bis="=F+A2-KE3:4:8.2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG3:54", bis="=F+A2-KF2:43", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG3:55", bis="=F+A2-KE3:4:8.3", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG3:56", bis="=F+A2-KE3:4:8.4", tag="", attributes=[Attribute(name=Color, value=GNYE), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG2:5", bis="=F+A2-PF1:X1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG2:5", bis="=F+A2-KE4:1:2.1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG2:6", bis="=F+A2-KE4:1:2.2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG2:7", bis="=F+A2-PF1:X2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG2:7", bis="=F+A2-KE4:1:2.3", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG2:8", bis="=F+A2-KE4:1:2.4", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG2:9", bis="=F+A2-PF2:X1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG2:9", bis="=F+A2-KE4:2:3.1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG2:10", bis="=F+A2-KE4:2:3.2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG2:11", bis="=F+A2-PF2:X2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG2:11", bis="=F+A2-KE4:2:3.3", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG2:12", bis="=F+A2-KE4:2:3.4", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG2:13", bis="=F+A2-PF3:X1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG2:13", bis="=F+A2-KE4:2:4.1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG2:14", bis="=F+A2-KE4:2:4.2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG2:15", bis="=F+A2-PF3:X2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG2:15", bis="=F+A2-KE4:2:4.3", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG2:16", bis="=F+A2-KE4:2:4.4", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG3:1", bis="=F+A2-KE3:1:1.1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG3:1", bis="=F+A2-SG1:12", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG3:2", bis="=F+A2-KE3:1:1.2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG3:2", bis="=F+A2-SG1:11", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG3:3", bis="=F+A2-KE3:1:1.3", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG3:4", bis="=F+A2-KE3:1:1.4", tag="", attributes=[Attribute(name=Color, value=GNYE), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG3:5", bis="=F+A2-KE3:1:2.1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG3:5", bis="=F+A2-SG1:24", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG3:6", bis="=F+A2-KE3:1:2.2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG3:6", bis="=F+A2-SG1:23", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG3:7", bis="=F+A2-KE3:1:2.3", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG3:8", bis="=F+A2-KE3:1:2.4", tag="", attributes=[Attribute(name=Color, value=GNYE), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG3:9", bis="=F+A2-KE3:2:3.1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG3:9", bis="+A2-XGA2:1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XGA1:1", bis="+A2-XGA2:1", tag="", attributes=[])
# Connection(von="+A2-XG3:10", bis="=F+A2-KE3:2:3.2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG3:10", bis="+A2-XGA2:2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XGA1:2", bis="+A2-XGA2:2", tag="", attributes=[])
# Connection(von="+A2-XG3:11", bis="=F+A2-KE3:2:3.3", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG3:12", bis="=F+A2-KE3:2:3.4", tag="", attributes=[Attribute(name=Color, value=GNYE), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG3:13", bis="=F+A2-KE3:2:4.1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG3:13", bis="+A2-XGA2:3", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XGA1:3", bis="+A2-XGA2:3", tag="", attributes=[])
# Connection(von="+A2-XG3:14", bis="=F+A2-KE3:2:4.2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG3:14", bis="+A2-XGA2:4", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XGA1:4", bis="+A2-XGA2:4", tag="", attributes=[])
# Connection(von="+A2-XG3:15", bis="=F+A2-KE3:2:4.3", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG3:16", bis="=F+A2-KE3:2:4.4", tag="", attributes=[Attribute(name=Color, value=GNYE), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG3:17", bis="=F+A2-KE3:3:5.1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG3:17", bis="+A2-XG4:1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG3:18", bis="=F+A2-KE3:3:5.2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG3:18", bis="+A2-XG4:2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG3:19", bis="=F+A2-KE3:3:5.3", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG3:20", bis="=F+A2-KE3:3:5.4", tag="", attributes=[Attribute(name=Color, value=GNYE), Attribute(name=Cross-section, value=0,75)])
# ...
# Connection(von="+A2-XG1:40", bis="=K1+A2-KE5:4:8.3", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG5:58", bis="=K1+A2-KE2:2:3.4", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG1:41", bis="+A2-XG5:58", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG5:59", bis="=K1+A2-KE2:2:3.5", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG1:42", bis="+A2-XG5:59", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG5:60", bis="=K1+A2-KE2:2:3.6", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG1:43", bis="=K1+A2-KE5:2:3.1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG1:44", bis="=K1+A2-KE5:2:3.2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG1:45", bis="=K1+A2-KE5:2:3.3", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG1:46", bis="=K1+A2-KE5:2:4.1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG1:47", bis="=K1+A2-KE5:2:4.2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG1:48", bis="=K1+A2-KE5:2:4.3", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG5:61", bis="=K1+A2-KE2:2:4.1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG1:49", bis="+A2-XG5:61", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG5:62", bis="=K1+A2-KE2:2:4.2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG1:50", bis="+A2-XG5:62", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG5:63", bis="=K1+A2-KE2:2:4.3", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG5:64", bis="=K1+A2-KE2:2:4.4", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG1:51", bis="+A2-XG5:64", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG5:65", bis="=K1+A2-KE2:2:4.5", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG1:52", bis="+A2-XG5:65", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+A2-XG5:66", bis="=K1+A2-KE2:2:4.6", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="=MM1+B1-BG1", bis="=MM1+B1-BG1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=MM1+B1-BG1", bis="=MM1+B1-BG1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=MM1+B1-BG1", bis="=MM1+B1-BG1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=MM1+B1-BG2", bis="=MM1+B1-BG2", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=MM1+B1-BG2", bis="=MM1+B1-BG2", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=MM1+B1-BG2", bis="=MM1+B1-BG2", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=K1+B1.X1-KE1:1:1.1", bis="=K1+B1.X1-KE1:1:2.1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+B1.X1-XD1:1", bis="=K1+B1.X1-KE1:1:1.2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+B1.X1-XD1:2", bis="=K1+B1.X1-KE1:1:1.3", tag="", attributes=[Attribute(name=Color, value=BU), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+B1.X1-XD1:3", bis="=K1+B1.X1-KE1:1:1.4", tag="", attributes=[Attribute(name=Color, value=GNYE), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=K1+B1.X1-KE1:1:1.4", bis="=K1+B1.X1-KE1:1:2.4", tag="", attributes=[Attribute(name=Color, value=GNYE), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+B1.X1-XD1:4", bis="=K1+B1.X1-KE1:1:2.2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+B1.X1-XD1:5", bis="=K1+B1.X1-KE1:1:2.3", tag="", attributes=[Attribute(name=Color, value=BU), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+B1.X1-XZ1:6", bis="=K1+B1.X1-KE1:3:1.2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+B1.X1-XZ1:7", bis="=K1+B1.X1-KE1:3:1.1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+B1.X1-XZ1:9", bis="=K1+B1.X1-KE1:3:2.1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+B1.X1-XZ1:10", bis="=K1+B1.X1-KE1:3:2.2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+B1.X1-XZ1:11", bis="=K1+B1.X1-KE1:3:2.3", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="=MM2+B2-BG1", bis="=MM2+B2-BG1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=MM2+B2-BG1", bis="=MM2+B2-BG1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=MM2+B2-BG1", bis="=MM2+B2-BG1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=MM2+B2-BG2", bis="=MM2+B2-BG2", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=MM2+B2-BG2", bis="=MM2+B2-BG2", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=MM2+B2-BG2", bis="=MM2+B2-BG2", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=MM3+B2-BG1", bis="=MM3+B2-BG1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=MM3+B2-BG1", bis="=MM3+B2-BG1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=MM3+B2-BG1", bis="=MM3+B2-BG1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=MM3+B2-BG2", bis="=MM3+B2-BG2", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=MM3+B2-BG2", bis="=MM3+B2-BG2", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=MM3+B2-BG2", bis="=MM3+B2-BG2", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=K1+B2.X1-KE1:1:1.1", bis="=K1+B2.X1-KE1:1:2.1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+B2.X1-XD1:1", bis="=K1+B2.X1-KE1:1:1.2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+B2.X1-XD1:2", bis="=K1+B2.X1-KE1:1:1.3", tag="", attributes=[Attribute(name=Color, value=BU), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+B2.X1-XD1:3", bis="=K1+B2.X1-KE1:1:1.4", tag="", attributes=[Attribute(name=Color, value=GNYE), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=K1+B2.X1-KE1:1:1.4", bis="=K1+B2.X1-KE1:1:2.4", tag="", attributes=[Attribute(name=Color, value=GNYE), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+B2.X1-XD1:4", bis="=K1+B2.X1-KE1:1:2.2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+B2.X1-XD1:5", bis="=K1+B2.X1-KE1:1:2.3", tag="", attributes=[Attribute(name=Color, value=BU), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+B2.X1-XZ1:6", bis="=K1+B2.X1-KE2:1:1.2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+B2.X1-XZ1:7", bis="=K1+B2.X1-KE2:1:1.1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+B2.X1-XZ1:9", bis="=K1+B2.X1-KE2:1:1.4", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+B2.X1-XZ1:10", bis="=K1+B2.X1-KE2:1:1.5", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+B2.X1-XZ1:11", bis="=K1+B2.X1-KE2:1:1.6", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+B2.X1-XZ1:20", bis="=K1+B2.X1-KE1:3:2.1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+B2.X1-XZ1:21", bis="=K1+B2.X1-KE1:3:2.2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+B2.X1-XZ1:22", bis="=K1+B2.X1-KE1:3:2.3", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+B2.X1-XZ1:31", bis="=K1+B2.X1-KE1:4:4.1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+B2.X1-XZ1:32", bis="=K1+B2.X1-KE1:4:4.2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+B2.X1-XZ1:33", bis="=K1+B2.X1-KE1:4:4.3", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="=GQA+B2.Y1-MB1", bis="=GQA+B2.Y1-MB1:x1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=GQA+B2.Y1-MB1", bis="=GQA+B2.Y1-MB1:x2", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=GQA+B2.Y1-S1", bis="=GQA+B2.Y1-S1:13", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=GQA+B2.Y1-S1", bis="=GQA+B2.Y1-S1:14", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=GQA+B2.Y1-S1:13", bis="=GQA+B2.Y1-S1:21", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=GQA+B2.Y1-S1", bis="=GQA+B2.Y1-S1:22", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=K2+B2.Y1-X0:3", bis="=K2+B2.Y1-MB1:x1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=K2+B2.Y1-X0:4", bis="=K2+B2.Y1-MB2:x1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=K2+B2.Y1-X0:9", bis="=K2+B2.Y1-MB1:x1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=K2+B2.Y1-X0:10", bis="=K2+B2.Y1-MB2:x1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=K2+B2.Y1-X0:11", bis="=K2+B2.Y1-MB1:x1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=K2+B2.Y1-X0:12", bis="=K2+B2.Y1-MB2:x1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+B2.Y1-XD1:5", bis="=K2+B2.Y1-XD1:PE", tag="", attributes=[Attribute(name=Color, value=GNYE), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+B2.Y1-XDB1:1:1 female", bis="=K2+B2.Y1-X20:1", tag="", attributes=[])
# Connection(von="+B2.Y1-XDB1:2:2 female", bis="=K2+B2.Y1-X20:2", tag="", attributes=[])
# Connection(von="+B2.Y1-XDB1:3:3 female", bis="=K2+B2.Y1-X20:3", tag="", attributes=[])
# Connection(von="+B2.Y1-XDB1:PE: PE female", bis="=K2+B2.Y1-X20:4", tag="", attributes=[])
# Connection(von="=K2+B2.Y1-X0:1", bis="=K2+B2.Y1-MB1:x1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=K2+B2.Y1-X0:2", bis="=K2+B2.Y1-MB2:x1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=K2+B2.Y1-X0:5", bis="=K2+B2.Y1-MB1:x1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=K2+B2.Y1-X0:6", bis="=K2+B2.Y1-MB2:x1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=K2+B2.Y1-X0:7", bis="=K2+B2.Y1-MB1:x1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=K2+B2.Y1-X0:8", bis="=K2+B2.Y1-MB2:x1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=K1+B3.X1-KE1:1:1.1", bis="=K1+B3.X1-KE1:1:2.1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+B3.X1-XD1:1", bis="=K1+B3.X1-KE1:1:1.2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+B3.X1-XD1:2", bis="=K1+B3.X1-KE1:1:1.3", tag="", attributes=[Attribute(name=Color, value=BU), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+B3.X1-XD1:3", bis="=K1+B3.X1-KE1:1:1.4", tag="", attributes=[Attribute(name=Color, value=GNYE), Attribute(name=Cross-section, value=1,5)])
# Connection(von="=K1+B3.X1-KE1:1:1.4", bis="=K1+B3.X1-KE1:1:2.4", tag="", attributes=[Attribute(name=Color, value=GNYE), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+B3.X1-XD1:4", bis="=K1+B3.X1-KE1:1:2.2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+B3.X1-XD1:5", bis="=K1+B3.X1-KE1:1:2.3", tag="", attributes=[Attribute(name=Color, value=BU), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+B3.X1-XZ1:6", bis="=K1+B3.X1-KE1:3:1.2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+B3.X1-XZ1:7", bis="=K1+B3.X1-KE1:3:1.1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+B3.X1-XZ1:9", bis="=K1+B3.X1-KE1:3:2.1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+B3.X1-XZ1:10", bis="=K1+B3.X1-KE1:3:2.2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+B3.X1-XZ1:11", bis="=K1+B3.X1-KE1:3:2.3", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection(von="+C2-XD1:1", bis="=S2+C2-PH1:X1:X1.1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=1,5)])
# Connection(von="+C2-XD1:2", bis="=S2+C2-PH1:X1:X1.2", tag="", attributes=[Attribute(name=Color, value=BU), Attribute(name=Cross-section, value=1,5)])

# %%
mngr = Manager(configs)
df_connections = extract(doc[29:40], TableType.CONNECTION_LIST)
df_objects = extract(doc[52:55], TableType.DEVICE_TAG_LIST)

display(df_connections)
mngr.read_connections(df_connections)
mngr.read_objects(df_objects)
mngr.print_stats()
# Out:
# Extracting 'TableType.CONNECTION_LIST' from 11 pages...
# Extracting 'TableType.CONNECTION_LIST' from page #30
# Extracting 'TableType.CONNECTION_LIST' from page #31
# Extracting 'TableType.CONNECTION_LIST' from page #32
# Extracting 'TableType.CONNECTION_LIST' from page #33
# Extracting 'TableType.CONNECTION_LIST' from page #34
# Extracting 'TableType.CONNECTION_LIST' from page #35
# Extracting 'TableType.CONNECTION_LIST' from page #36
# Extracting 'TableType.CONNECTION_LIST' from page #37
# Extracting 'TableType.CONNECTION_LIST' from page #38
# Extracting 'TableType.CONNECTION_LIST' from page #39
# Extracting 'TableType.CONNECTION_LIST' from page #40
# Extracting 'TableType.DEVICE_TAG_LIST' from 3 pages...
# Extracting 'TableType.DEVICE_TAG_LIST' from page #53
# Extracting 'TableType.DEVICE_TAG_LIST' from page #54
# Extracting 'TableType.DEVICE_TAG_LIST' from page #55
#     Connection       Target 1             Target 2 Color Cross-section
# 0                   +A1-XD1:1        =GAA+A1-FC1:1    BK             6
# 1               =GAA+A1-FC1:1         =EA+A1-FB1:1    OG             6
# 2                =EA+A1-FB1:1         =EA+A1-FB3:1    OG             6
# 3               =GAA+A1-FC1:2        =GAA+A1-FC2:1    BK             4
# 4               =GAA+A1-FC2:1    =GAB1+A1-FC1:1/L1    BK             4
# ..         ...            ...                  ...   ...           ...
# 594              +B3.X1-XZ1:9  =K1+B3.X1-KE1:3:2.1    GY          0,75
# 595             +B3.X1-XZ1:10  =K1+B3.X1-KE1:3:2.2    GY          0,75
# 596             +B3.X1-XZ1:11  =K1+B3.X1-KE1:3:2.3    GY          0,75
# 597                 +C2-XD1:1   =S2+C2-PH1:X1:X1.1    GY           1,5
# 598                 +C2-XD1:2   =S2+C2-PH1:X1:X1.2    BU           1,5
#
# [599 rows x 5 columns]
# Has 1022 objects
# Object: Object(tag=Tag(tag_str='', attributes=[])
# Object: Object(tag=Tag(tag_str='+A1-XD1:1', attributes=[Attribute(name=link, value=to =GAA+A1-FC1:1 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-FC1:1', attributes=[Attribute(name=link, value=to +A1-XD1:1 through ), Attribute(name=link, value=to =EA+A1-FB1:1 through )])
# Object: Object(tag=Tag(tag_str='=EA+A1-FB1:1', attributes=[Attribute(name=link, value=to =GAA+A1-FC1:1 through ), Attribute(name=link, value=to =EA+A1-FB3:1 through )])
# Object: Object(tag=Tag(tag_str='=EA+A1-FB3:1', attributes=[Attribute(name=link, value=to =EA+A1-FB1:1 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-FC1:2', attributes=[Attribute(name=link, value=to =GAA+A1-FC2:1 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-FC2:1', attributes=[Attribute(name=link, value=to =GAA+A1-FC1:2 through ), Attribute(name=link, value=to =GAB1+A1-FC1:1/L1 through )])
# Object: Object(tag=Tag(tag_str='=GAB1+A1-FC1:1/L1', attributes=[Attribute(name=link, value=to =GAA+A1-FC2:1 through ), Attribute(name=link, value=to =GAB2+A1-FC1:1/L1 through )])
# Object: Object(tag=Tag(tag_str='=GAB2+A1-FC1:1/L1', attributes=[Attribute(name=link, value=to =GAB1+A1-FC1:1/L1 through ), Attribute(name=link, value=to =GL1+A1-FC1:1/L1 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-FC1:1/L1', attributes=[Attribute(name=link, value=to =GAB2+A1-FC1:1/L1 through ), Attribute(name=link, value=to =GL2+A1-FC1:1/L1 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-FC1:1/L1', attributes=[Attribute(name=link, value=to =GL1+A1-FC1:1/L1 through ), Attribute(name=link, value=to =TM1+A1-FC1:1/L1 through )])
# Object: Object(tag=Tag(tag_str='=TM1+A1-FC1:1/L1', attributes=[Attribute(name=link, value=to =GL2+A1-FC1:1/L1 through ), Attribute(name=link, value=to =TM2+A1-FC1:1/L1 through )])
# Object: Object(tag=Tag(tag_str='=TM2+A1-FC1:1/L1', attributes=[Attribute(name=link, value=to =TM1+A1-FC1:1/L1 through ), Attribute(name=link, value=to =GL3+A1-FC1:1/L1 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-FC1:1/L1', attributes=[Attribute(name=link, value=to =TM2+A1-FC1:1/L1 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD1:2', attributes=[Attribute(name=link, value=to =GAA+A1-FC1:3 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-FC1:3', attributes=[Attribute(name=link, value=to +A1-XD1:2 through ), Attribute(name=link, value=to =EA+A1-FB2:1 through )])
# Object: Object(tag=Tag(tag_str='=EA+A1-FB2:1', attributes=[Attribute(name=link, value=to =GAA+A1-FC1:3 through ), Attribute(name=link, value=to =EA+A1-FB4:1 through )])
# Object: Object(tag=Tag(tag_str='=EA+A1-FB4:1', attributes=[Attribute(name=link, value=to =EA+A1-FB2:1 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-FC1:4', attributes=[Attribute(name=link, value=to =GAA+A1-FC3:1 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-FC3:1', attributes=[Attribute(name=link, value=to =GAA+A1-FC1:4 through ), Attribute(name=link, value=to =GAB1+A1-FC1:3/L2 through )])
# Object: Object(tag=Tag(tag_str='=GAB1+A1-FC1:3/L2', attributes=[Attribute(name=link, value=to =GAA+A1-FC3:1 through ), Attribute(name=link, value=to =GAB2+A1-FC1:3/L2 through )])
# Object: Object(tag=Tag(tag_str='=GAB2+A1-FC1:3/L2', attributes=[Attribute(name=link, value=to =GAB1+A1-FC1:3/L2 through ), Attribute(name=link, value=to =GL1+A1-FC1:3/L2 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-FC1:3/L2', attributes=[Attribute(name=link, value=to =GAB2+A1-FC1:3/L2 through ), Attribute(name=link, value=to =GL2+A1-FC1:3/L2 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-FC1:3/L2', attributes=[Attribute(name=link, value=to =GL1+A1-FC1:3/L2 through ), Attribute(name=link, value=to =TM1+A1-FC1:3/L2 through )])
# Object: Object(tag=Tag(tag_str='=TM1+A1-FC1:3/L2', attributes=[Attribute(name=link, value=to =GL2+A1-FC1:3/L2 through ), Attribute(name=link, value=to =TM2+A1-FC1:3/L2 through )])
# Object: Object(tag=Tag(tag_str='=TM2+A1-FC1:3/L2', attributes=[Attribute(name=link, value=to =TM1+A1-FC1:3/L2 through ), Attribute(name=link, value=to =GL3+A1-FC1:3/L2 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-FC1:3/L2', attributes=[Attribute(name=link, value=to =TM2+A1-FC1:3/L2 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD1:3', attributes=[Attribute(name=link, value=to =GAA+A1-FC1:5 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-FC1:5', attributes=[Attribute(name=link, value=to +A1-XD1:3 through ), Attribute(name=link, value=to =GAA+A1-FC5:1 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-FC5:1', attributes=[Attribute(name=link, value=to =GAA+A1-FC1:5 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-FC1:6', attributes=[Attribute(name=link, value=to =GAA+A1-FC4:1 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-FC4:1', attributes=[Attribute(name=link, value=to =GAA+A1-FC1:6 through ), Attribute(name=link, value=to =GAB1+A1-FC1:5/L3 through )])
# Object: Object(tag=Tag(tag_str='=GAB1+A1-FC1:5/L3', attributes=[Attribute(name=link, value=to =GAA+A1-FC4:1 through ), Attribute(name=link, value=to =GAB2+A1-FC1:5/L3 through )])
# Object: Object(tag=Tag(tag_str='=GAB2+A1-FC1:5/L3', attributes=[Attribute(name=link, value=to =GAB1+A1-FC1:5/L3 through ), Attribute(name=link, value=to =GL1+A1-FC1:5/L3 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-FC1:5/L3', attributes=[Attribute(name=link, value=to =GAB2+A1-FC1:5/L3 through ), Attribute(name=link, value=to =GL2+A1-FC1:5/L3 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-FC1:5/L3', attributes=[Attribute(name=link, value=to =GL1+A1-FC1:5/L3 through ), Attribute(name=link, value=to =TM1+A1-FC1:5/L3 through )])
# Object: Object(tag=Tag(tag_str='=TM1+A1-FC1:5/L3', attributes=[Attribute(name=link, value=to =GL2+A1-FC1:5/L3 through ), Attribute(name=link, value=to =TM2+A1-FC1:5/L3 through )])
# Object: Object(tag=Tag(tag_str='=TM2+A1-FC1:5/L3', attributes=[Attribute(name=link, value=to =TM1+A1-FC1:5/L3 through ), Attribute(name=link, value=to =GL3+A1-FC1:5/L3 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-FC1:5/L3', attributes=[Attribute(name=link, value=to =TM2+A1-FC1:5/L3 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD5:6', attributes=[Attribute(name=link, value=to =GAA+A1-TA3:k through ), Attribute(name=link, value=to =GAA+A1-PF1:I3:11 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-TA3:k', attributes=[Attribute(name=link, value=to +A1-XD5:6 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD5:5', attributes=[Attribute(name=link, value=to =GAA+A1-TA3:l through ), Attribute(name=link, value=to =GAA+A1-PF1:I3:9 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-TA3:l', attributes=[Attribute(name=link, value=to +A1-XD5:5 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD5:4', attributes=[Attribute(name=link, value=to =GAA+A1-TA2:k through ), Attribute(name=link, value=to =GAA+A1-PF1:I2:7 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-TA2:k', attributes=[Attribute(name=link, value=to +A1-XD5:4 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD5:3', attributes=[Attribute(name=link, value=to =GAA+A1-TA2:l through ), Attribute(name=link, value=to =GAA+A1-PF1:I2:5 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-TA2:l', attributes=[Attribute(name=link, value=to +A1-XD5:3 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD5:2', attributes=[Attribute(name=link, value=to =GAA+A1-TA1:k through ), Attribute(name=link, value=to =GAA+A1-PF1:I1:3 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-TA1:k', attributes=[Attribute(name=link, value=to +A1-XD5:2 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD5:1', attributes=[Attribute(name=link, value=to =GAA+A1-TA1:l through ), Attribute(name=link, value=to =GAA+A1-PF1:I1:1 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-TA1:l', attributes=[Attribute(name=link, value=to +A1-XD5:1 through )])
# Object: Object(tag=Tag(tag_str='+A1-WE2:1', attributes=[Attribute(name=link, value=to +A1-XD1:7 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD1:7', attributes=[Attribute(name=link, value=to +A1-WE2:1 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-PF1:I3:11', attributes=[Attribute(name=link, value=to +A1-XD5:6 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-PF1:I3:9', attributes=[Attribute(name=link, value=to +A1-XD5:5 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-PF1:I2:7', attributes=[Attribute(name=link, value=to +A1-XD5:4 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-PF1:I2:5', attributes=[Attribute(name=link, value=to +A1-XD5:3 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-PF1:I1:3', attributes=[Attribute(name=link, value=to +A1-XD5:2 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-PF1:I1:1', attributes=[Attribute(name=link, value=to +A1-XD5:1 through )])
# Object: Object(tag=Tag(tag_str='+A1-WE1:1', attributes=[Attribute(name=link, value=to +A1-XD1:8 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD1:8', attributes=[Attribute(name=link, value=to +A1-WE1:1 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-FC5:2', attributes=[Attribute(name=link, value=to =GAA+A1-PF1:AUX SUPPLY:20 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-PF1:AUX SUPPLY:20', attributes=[Attribute(name=link, value=to =GAA+A1-FC5:2 through )])
# Object: Object(tag=Tag(tag_str='+A1-WE2:9', attributes=[Attribute(name=link, value=to =GAA+A1-PF1:AUX SUPPLY:22 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-PF1:AUX SUPPLY:22', attributes=[Attribute(name=link, value=to +A1-WE2:9 through )])
# Object: Object(tag=Tag(tag_str='+A1-FC2:1', attributes=[Attribute(name=link, value=to +A1-XD1:4 through ), Attribute(name=link, value=to =GAA+A1-PF1:I3:12 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD1:4', attributes=[Attribute(name=link, value=to +A1-FC2:1 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-PF1:I3:12', attributes=[Attribute(name=link, value=to +A1-FC2:1 through )])
# Object: Object(tag=Tag(tag_str='+A1-FC2:2', attributes=[Attribute(name=link, value=to +A1-XD1:5 through ), Attribute(name=link, value=to =GAA+A1-PF1:I3:14 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD1:5', attributes=[Attribute(name=link, value=to +A1-FC2:2 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-PF1:I3:14', attributes=[Attribute(name=link, value=to +A1-FC2:2 through )])
# Object: Object(tag=Tag(tag_str='+A1-FC2:3', attributes=[Attribute(name=link, value=to +A1-XD1:6 through ), Attribute(name=link, value=to =GAA+A1-PF1:I3:16 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD1:6', attributes=[Attribute(name=link, value=to +A1-FC2:3 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-PF1:I3:16', attributes=[Attribute(name=link, value=to +A1-FC2:3 through )])
# Object: Object(tag=Tag(tag_str='+A1-WE2:2', attributes=[Attribute(name=link, value=to =GAA+A1-PF1:I3:2 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-PF1:I3:2', attributes=[Attribute(name=link, value=to +A1-WE2:2 through )])
# Object: Object(tag=Tag(tag_str='+A1-WE1:2', attributes=[Attribute(name=link, value=to =GAA+A1-PF1:I3:18 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-PF1:I3:18', attributes=[Attribute(name=link, value=to +A1-WE1:2 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-PF1:x2', attributes=[Attribute(name=link, value=to =GAA+A1-PF1:RS485:17 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-PF1:RS485:17', attributes=[Attribute(name=link, value=to =GAA+A1-PF1:x2 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-PF1:x1', attributes=[Attribute(name=link, value=to =GAA+A1-PF1:RS485:15 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-PF1:RS485:15', attributes=[Attribute(name=link, value=to =GAA+A1-PF1:x1 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-FC2:2', attributes=[Attribute(name=link, value=to =GAA+A1-PF2:X1 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-PF2:X1', attributes=[Attribute(name=link, value=to =GAA+A1-FC2:2 through )])
# Object: Object(tag=Tag(tag_str='+A1-WE2:8', attributes=[Attribute(name=link, value=to =GAA+A1-PF2:X2 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-PF2:X2', attributes=[Attribute(name=link, value=to +A1-WE2:8 through ), Attribute(name=link, value=to =GAA+A1-PF3:X2 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-PF3:X2', attributes=[Attribute(name=link, value=to =GAA+A1-PF2:X2 through ), Attribute(name=link, value=to =GAA+A1-PF4:X2 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-PF4:X2', attributes=[Attribute(name=link, value=to =GAA+A1-PF3:X2 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-FC3:2', attributes=[Attribute(name=link, value=to =GAA+A1-PF3:X1 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-PF3:X1', attributes=[Attribute(name=link, value=to =GAA+A1-FC3:2 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-FC4:2', attributes=[Attribute(name=link, value=to =GAA+A1-PF4:X1 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-PF4:X1', attributes=[Attribute(name=link, value=to =GAA+A1-FC4:2 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD3:1', attributes=[Attribute(name=link, value=to =GAB1+A1-FC1:2/T1 through )])
# Object: Object(tag=Tag(tag_str='=GAB1+A1-FC1:2/T1', attributes=[Attribute(name=link, value=to +A1-XD3:1 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD3:2', attributes=[Attribute(name=link, value=to =GAB1+A1-FC1:4/T2 through )])
# Object: Object(tag=Tag(tag_str='=GAB1+A1-FC1:4/T2', attributes=[Attribute(name=link, value=to +A1-XD3:2 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD3:3', attributes=[Attribute(name=link, value=to =GAB1+A1-FC1:6/T3 through )])
# Object: Object(tag=Tag(tag_str='=GAB1+A1-FC1:6/T3', attributes=[Attribute(name=link, value=to +A1-XD3:3 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD3:6', attributes=[Attribute(name=link, value=to =GAB2+A1-FC1:2/T1 through )])
# Object: Object(tag=Tag(tag_str='=GAB2+A1-FC1:2/T1', attributes=[Attribute(name=link, value=to +A1-XD3:6 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD3:7', attributes=[Attribute(name=link, value=to =GAB2+A1-FC1:4/T2 through )])
# Object: Object(tag=Tag(tag_str='=GAB2+A1-FC1:4/T2', attributes=[Attribute(name=link, value=to +A1-XD3:7 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD3:8', attributes=[Attribute(name=link, value=to =GAB2+A1-FC1:6/T3 through )])
# Object: Object(tag=Tag(tag_str='=GAB2+A1-FC1:6/T3', attributes=[Attribute(name=link, value=to +A1-XD3:8 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:1', attributes=[Attribute(name=link, value=to =GAB2+A1-FC1:14 through )])
# Object: Object(tag=Tag(tag_str='=GAB2+A1-FC1:14', attributes=[Attribute(name=link, value=to +A1-XG1:1 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:2', attributes=[Attribute(name=link, value=to =GAB2+A1-FC1:13 through )])
# Object: Object(tag=Tag(tag_str='=GAB2+A1-FC1:13', attributes=[Attribute(name=link, value=to +A1-XG1:2 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD2:1', attributes=[Attribute(name=link, value=to =EA+A1-FB1:2 through )])
# Object: Object(tag=Tag(tag_str='=EA+A1-FB1:2', attributes=[Attribute(name=link, value=to +A1-XD2:1 through )])
# Object: Object(tag=Tag(tag_str='+A1-WE2:4', attributes=[Attribute(name=link, value=to =EA+A1-FB1:N through )])
# Object: Object(tag=Tag(tag_str='=EA+A1-FB1:N', attributes=[Attribute(name=link, value=to +A1-WE2:4 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD2:3', attributes=[Attribute(name=link, value=to =EA+A1-FB1:N. through )])
# Object: Object(tag=Tag(tag_str='=EA+A1-FB1:N.', attributes=[Attribute(name=link, value=to +A1-XD2:3 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD2:4', attributes=[Attribute(name=link, value=to =EA+A1-XD1:L through ), Attribute(name=link, value=to =EA+A1-FB2:2 through )])
# Object: Object(tag=Tag(tag_str='=EA+A1-XD1:L', attributes=[Attribute(name=link, value=to +A1-XD2:4 through )])
# Object: Object(tag=Tag(tag_str='=EA+A1-FB2:2', attributes=[Attribute(name=link, value=to +A1-XD2:4 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD2:5', attributes=[Attribute(name=link, value=to =EA+A1-XD1:PE through )])
# Object: Object(tag=Tag(tag_str='=EA+A1-XD1:PE', attributes=[Attribute(name=link, value=to +A1-XD2:5 through )])
# Object: Object(tag=Tag(tag_str='+A1-WE2:5', attributes=[Attribute(name=link, value=to =EA+A1-FB2:N through )])
# Object: Object(tag=Tag(tag_str='=EA+A1-FB2:N', attributes=[Attribute(name=link, value=to +A1-WE2:5 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD2:6', attributes=[Attribute(name=link, value=to =EA+A1-XD1:N through ), Attribute(name=link, value=to =EA+A1-FB2:N. through )])
# Object: Object(tag=Tag(tag_str='=EA+A1-XD1:N', attributes=[Attribute(name=link, value=to +A1-XD2:6 through )])
# Object: Object(tag=Tag(tag_str='=EA+A1-FB2:N.', attributes=[Attribute(name=link, value=to +A1-XD2:6 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD2:7', attributes=[Attribute(name=link, value=to =EA+A1-FB3:2 through )])
# Object: Object(tag=Tag(tag_str='=EA+A1-FB3:2', attributes=[Attribute(name=link, value=to +A1-XD2:7 through )])
# Object: Object(tag=Tag(tag_str='+A1-WE2:6', attributes=[Attribute(name=link, value=to =EA+A1-FB3:N through )])
# Object: Object(tag=Tag(tag_str='=EA+A1-FB3:N', attributes=[Attribute(name=link, value=to +A1-WE2:6 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD2:9', attributes=[Attribute(name=link, value=to =EA+A1-FB3:N. through )])
# Object: Object(tag=Tag(tag_str='=EA+A1-FB3:N.', attributes=[Attribute(name=link, value=to +A1-XD2:9 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD2:10', attributes=[Attribute(name=link, value=to =EA+A1-FB4:2 through )])
# Object: Object(tag=Tag(tag_str='=EA+A1-FB4:2', attributes=[Attribute(name=link, value=to +A1-XD2:10 through )])
# Object: Object(tag=Tag(tag_str='+A1-WE2:7', attributes=[Attribute(name=link, value=to =EA+A1-FB4:N through )])
# Object: Object(tag=Tag(tag_str='=EA+A1-FB4:N', attributes=[Attribute(name=link, value=to +A1-WE2:7 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD2:12', attributes=[Attribute(name=link, value=to =EA+A1-FB4:N. through )])
# Object: Object(tag=Tag(tag_str='=EA+A1-FB4:N.', attributes=[Attribute(name=link, value=to +A1-XD2:12 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD4:1', attributes=[Attribute(name=link, value=to =GL1+A1-QA1:2/T1 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-QA1:2/T1', attributes=[Attribute(name=link, value=to +A1-XD4:1 through ), Attribute(name=link, value=to =GL1+A1-QA2:2/T1 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-QA2:2/T1', attributes=[Attribute(name=link, value=to =GL1+A1-QA1:2/T1 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-FC1:2/T1', attributes=[Attribute(name=link, value=to =GL1+A1-QA1:1/L1 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-QA1:1/L1', attributes=[Attribute(name=link, value=to =GL1+A1-FC1:2/T1 through ), Attribute(name=link, value=to =GL1+A1-QA2:5/L3 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-QA2:5/L3', attributes=[Attribute(name=link, value=to =GL1+A1-QA1:1/L1 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD4:2', attributes=[Attribute(name=link, value=to =GL1+A1-QA1:4/T2 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-QA1:4/T2', attributes=[Attribute(name=link, value=to +A1-XD4:2 through ), Attribute(name=link, value=to =GL1+A1-QA2:4/T2 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-QA2:4/T2', attributes=[Attribute(name=link, value=to =GL1+A1-QA1:4/T2 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-FC1:4/T2', attributes=[Attribute(name=link, value=to =GL1+A1-QA1:3/L2 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-QA1:3/L2', attributes=[Attribute(name=link, value=to =GL1+A1-FC1:4/T2 through ), Attribute(name=link, value=to =GL1+A1-QA2:3/L2 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-QA2:3/L2', attributes=[Attribute(name=link, value=to =GL1+A1-QA1:3/L2 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD4:3', attributes=[Attribute(name=link, value=to =GL1+A1-QA1:6/T3 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-QA1:6/T3', attributes=[Attribute(name=link, value=to +A1-XD4:3 through ), Attribute(name=link, value=to =GL1+A1-QA2:6/T3 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-QA2:6/T3', attributes=[Attribute(name=link, value=to =GL1+A1-QA1:6/T3 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-FC1:6/T3', attributes=[Attribute(name=link, value=to =GL1+A1-QA1:5/L3 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-QA1:5/L3', attributes=[Attribute(name=link, value=to =GL1+A1-FC1:6/T3 through ), Attribute(name=link, value=to =GL1+A1-QA2:1/L1 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-QA2:1/L1', attributes=[Attribute(name=link, value=to =GL1+A1-QA1:5/L3 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:3', attributes=[Attribute(name=link, value=to =GL1+A1-FC1:14 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-FC1:14', attributes=[Attribute(name=link, value=to +A1-XG1:3 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:4', attributes=[Attribute(name=link, value=to =GL1+A1-FC1:13 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-FC1:13', attributes=[Attribute(name=link, value=to +A1-XG1:4 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-QA1:A1', attributes=[Attribute(name=link, value=to =GL1+A1-QA2:12 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-QA2:12', attributes=[Attribute(name=link, value=to =GL1+A1-QA1:A1 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:5', attributes=[Attribute(name=link, value=to =GL1+A1-QA2:11 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-QA2:11', attributes=[Attribute(name=link, value=to +A1-XG1:5 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:6', attributes=[Attribute(name=link, value=to =GL1+A1-QA1:A2 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-QA1:A2', attributes=[Attribute(name=link, value=to +A1-XG1:6 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-QA1:12', attributes=[Attribute(name=link, value=to =GL1+A1-QA2:A1 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-QA2:A1', attributes=[Attribute(name=link, value=to =GL1+A1-QA1:12 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:7', attributes=[Attribute(name=link, value=to =GL1+A1-QA1:11 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-QA1:11', attributes=[Attribute(name=link, value=to +A1-XG1:7 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:8', attributes=[Attribute(name=link, value=to =GL1+A1-QA2:A2 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-QA2:A2', attributes=[Attribute(name=link, value=to +A1-XG1:8 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:9', attributes=[Attribute(name=link, value=to =GL1+A1-QA1:14 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-QA1:14', attributes=[Attribute(name=link, value=to +A1-XG1:9 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:10', attributes=[Attribute(name=link, value=to =GL1+A1-QA1:13 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-QA1:13', attributes=[Attribute(name=link, value=to +A1-XG1:10 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:11', attributes=[Attribute(name=link, value=to =GL1+A1-QA2:14 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-QA2:14', attributes=[Attribute(name=link, value=to +A1-XG1:11 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:12', attributes=[Attribute(name=link, value=to =GL1+A1-QA2:13 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-QA2:13', attributes=[Attribute(name=link, value=to +A1-XG1:12 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD4:6', attributes=[Attribute(name=link, value=to =GL2+A1-QA1:2/T1 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-QA1:2/T1', attributes=[Attribute(name=link, value=to +A1-XD4:6 through ), Attribute(name=link, value=to =GL2+A1-QA2:2/T1 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-QA2:2/T1', attributes=[Attribute(name=link, value=to =GL2+A1-QA1:2/T1 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-FC1:2/T1', attributes=[Attribute(name=link, value=to =GL2+A1-QA1:1/L1 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-QA1:1/L1', attributes=[Attribute(name=link, value=to =GL2+A1-FC1:2/T1 through ), Attribute(name=link, value=to =GL2+A1-QA2:5/L3 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-QA2:5/L3', attributes=[Attribute(name=link, value=to =GL2+A1-QA1:1/L1 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD4:7', attributes=[Attribute(name=link, value=to =GL2+A1-QA1:4/T2 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-QA1:4/T2', attributes=[Attribute(name=link, value=to +A1-XD4:7 through ), Attribute(name=link, value=to =GL2+A1-QA2:4/T2 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-QA2:4/T2', attributes=[Attribute(name=link, value=to =GL2+A1-QA1:4/T2 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-FC1:4/T2', attributes=[Attribute(name=link, value=to =GL2+A1-QA1:3/L2 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-QA1:3/L2', attributes=[Attribute(name=link, value=to =GL2+A1-FC1:4/T2 through ), Attribute(name=link, value=to =GL2+A1-QA2:3/L2 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-QA2:3/L2', attributes=[Attribute(name=link, value=to =GL2+A1-QA1:3/L2 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD4:8', attributes=[Attribute(name=link, value=to =GL2+A1-QA1:6/T3 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-QA1:6/T3', attributes=[Attribute(name=link, value=to +A1-XD4:8 through ), Attribute(name=link, value=to =GL2+A1-QA2:6/T3 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-QA2:6/T3', attributes=[Attribute(name=link, value=to =GL2+A1-QA1:6/T3 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-FC1:6/T3', attributes=[Attribute(name=link, value=to =GL2+A1-QA1:5/L3 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-QA1:5/L3', attributes=[Attribute(name=link, value=to =GL2+A1-FC1:6/T3 through ), Attribute(name=link, value=to =GL2+A1-QA2:1/L1 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-QA2:1/L1', attributes=[Attribute(name=link, value=to =GL2+A1-QA1:5/L3 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:13', attributes=[Attribute(name=link, value=to =GL2+A1-FC1:14 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-FC1:14', attributes=[Attribute(name=link, value=to +A1-XG1:13 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:14', attributes=[Attribute(name=link, value=to =GL2+A1-FC1:13 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-FC1:13', attributes=[Attribute(name=link, value=to +A1-XG1:14 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-QA1:A1', attributes=[Attribute(name=link, value=to =GL2+A1-QA2:12 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-QA2:12', attributes=[Attribute(name=link, value=to =GL2+A1-QA1:A1 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:15', attributes=[Attribute(name=link, value=to =GL2+A1-QA2:11 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-QA2:11', attributes=[Attribute(name=link, value=to +A1-XG1:15 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:16', attributes=[Attribute(name=link, value=to =GL2+A1-QA1:A2 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-QA1:A2', attributes=[Attribute(name=link, value=to +A1-XG1:16 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-QA1:12', attributes=[Attribute(name=link, value=to =GL2+A1-QA2:A1 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-QA2:A1', attributes=[Attribute(name=link, value=to =GL2+A1-QA1:12 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:17', attributes=[Attribute(name=link, value=to =GL2+A1-QA1:11 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-QA1:11', attributes=[Attribute(name=link, value=to +A1-XG1:17 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:18', attributes=[Attribute(name=link, value=to =GL2+A1-QA2:A2 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-QA2:A2', attributes=[Attribute(name=link, value=to +A1-XG1:18 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:19', attributes=[Attribute(name=link, value=to =GL2+A1-QA1:14 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-QA1:14', attributes=[Attribute(name=link, value=to +A1-XG1:19 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:20', attributes=[Attribute(name=link, value=to =GL2+A1-QA1:13 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-QA1:13', attributes=[Attribute(name=link, value=to +A1-XG1:20 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:21', attributes=[Attribute(name=link, value=to =GL2+A1-QA2:14 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-QA2:14', attributes=[Attribute(name=link, value=to +A1-XG1:21 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:22', attributes=[Attribute(name=link, value=to =GL2+A1-QA2:13 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-QA2:13', attributes=[Attribute(name=link, value=to +A1-XG1:22 through )])
# Object: Object(tag=Tag(tag_str='=TM1+A1-FC1:2/T1', attributes=[Attribute(name=link, value=to =TM1+A1-TA1:X1:1 through )])
# Object: Object(tag=Tag(tag_str='=TM1+A1-TA1:X1:1', attributes=[Attribute(name=link, value=to =TM1+A1-FC1:2/T1 through )])
# Object: Object(tag=Tag(tag_str='=TM1+A1-FC1:4/T2', attributes=[Attribute(name=link, value=to =TM1+A1-TA1:X1:2 through )])
# Object: Object(tag=Tag(tag_str='=TM1+A1-TA1:X1:2', attributes=[Attribute(name=link, value=to =TM1+A1-FC1:4/T2 through )])
# Object: Object(tag=Tag(tag_str='=TM1+A1-FC1:6/T3', attributes=[Attribute(name=link, value=to =TM1+A1-TA1:X1:3 through )])
# Object: Object(tag=Tag(tag_str='=TM1+A1-TA1:X1:3', attributes=[Attribute(name=link, value=to =TM1+A1-FC1:6/T3 through )])
# Object: Object(tag=Tag(tag_str='+A1-WE1:4', attributes=[Attribute(name=link, value=to =TM1+A1-TA1:X1:PE1 through )])
# Object: Object(tag=Tag(tag_str='=TM1+A1-TA1:X1:PE1', attributes=[Attribute(name=link, value=to +A1-WE1:4 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:23', attributes=[Attribute(name=link, value=to =TM1+A1-FC1:14 through )])
# Object: Object(tag=Tag(tag_str='=TM1+A1-FC1:14', attributes=[Attribute(name=link, value=to +A1-XG1:23 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:24', attributes=[Attribute(name=link, value=to =TM1+A1-FC1:13 through )])
# Object: Object(tag=Tag(tag_str='=TM1+A1-FC1:13', attributes=[Attribute(name=link, value=to +A1-XG1:24 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:25', attributes=[Attribute(name=link, value=to =TM1+A1-TA1:X12:1 through )])
# Object: Object(tag=Tag(tag_str='=TM1+A1-TA1:X12:1', attributes=[Attribute(name=link, value=to +A1-XG1:25 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:26', attributes=[Attribute(name=link, value=to =TM1+A1-TA1:X12:9 through )])
# Object: Object(tag=Tag(tag_str='=TM1+A1-TA1:X12:9', attributes=[Attribute(name=link, value=to +A1-XG1:26 through )])
# Object: Object(tag=Tag(tag_str='=TM2+A1-FC1:2/T1', attributes=[Attribute(name=link, value=to =TM2+A1-TA1:X1:1 through )])
# Object: Object(tag=Tag(tag_str='=TM2+A1-TA1:X1:1', attributes=[Attribute(name=link, value=to =TM2+A1-FC1:2/T1 through )])
# Object: Object(tag=Tag(tag_str='=TM2+A1-FC1:4/T2', attributes=[Attribute(name=link, value=to =TM2+A1-TA1:X1:2 through )])
# Object: Object(tag=Tag(tag_str='=TM2+A1-TA1:X1:2', attributes=[Attribute(name=link, value=to =TM2+A1-FC1:4/T2 through )])
# Object: Object(tag=Tag(tag_str='=TM2+A1-FC1:6/T3', attributes=[Attribute(name=link, value=to =TM2+A1-TA1:X1:3 through )])
# Object: Object(tag=Tag(tag_str='=TM2+A1-TA1:X1:3', attributes=[Attribute(name=link, value=to =TM2+A1-FC1:6/T3 through )])
# Object: Object(tag=Tag(tag_str='+A1-WE1:5', attributes=[Attribute(name=link, value=to =TM2+A1-TA1:X1:PE1 through )])
# Object: Object(tag=Tag(tag_str='=TM2+A1-TA1:X1:PE1', attributes=[Attribute(name=link, value=to +A1-WE1:5 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:27', attributes=[Attribute(name=link, value=to =TM2+A1-FC1:14 through )])
# Object: Object(tag=Tag(tag_str='=TM2+A1-FC1:14', attributes=[Attribute(name=link, value=to +A1-XG1:27 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:28', attributes=[Attribute(name=link, value=to =TM2+A1-FC1:13 through )])
# Object: Object(tag=Tag(tag_str='=TM2+A1-FC1:13', attributes=[Attribute(name=link, value=to +A1-XG1:28 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:29', attributes=[Attribute(name=link, value=to =TM2+A1-TA1:X12:1 through )])
# Object: Object(tag=Tag(tag_str='=TM2+A1-TA1:X12:1', attributes=[Attribute(name=link, value=to +A1-XG1:29 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:30', attributes=[Attribute(name=link, value=to =TM2+A1-TA1:X12:9 through )])
# Object: Object(tag=Tag(tag_str='=TM2+A1-TA1:X12:9', attributes=[Attribute(name=link, value=to +A1-XG1:30 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD4:11', attributes=[Attribute(name=link, value=to =GL3+A1-QA1:2/T1 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-QA1:2/T1', attributes=[Attribute(name=link, value=to +A1-XD4:11 through ), Attribute(name=link, value=to =GL3+A1-QA2:2/T1 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-QA2:2/T1', attributes=[Attribute(name=link, value=to =GL3+A1-QA1:2/T1 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-FC1:2/T1', attributes=[Attribute(name=link, value=to =GL3+A1-QA1:1/L1 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-QA1:1/L1', attributes=[Attribute(name=link, value=to =GL3+A1-FC1:2/T1 through ), Attribute(name=link, value=to =GL3+A1-QA2:5/L3 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-QA2:5/L3', attributes=[Attribute(name=link, value=to =GL3+A1-QA1:1/L1 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD4:12', attributes=[Attribute(name=link, value=to =GL3+A1-QA1:4/T2 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-QA1:4/T2', attributes=[Attribute(name=link, value=to +A1-XD4:12 through ), Attribute(name=link, value=to =GL3+A1-QA2:4/T2 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-QA2:4/T2', attributes=[Attribute(name=link, value=to =GL3+A1-QA1:4/T2 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-FC1:4/T2', attributes=[Attribute(name=link, value=to =GL3+A1-QA1:3/L2 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-QA1:3/L2', attributes=[Attribute(name=link, value=to =GL3+A1-FC1:4/T2 through ), Attribute(name=link, value=to =GL3+A1-QA2:3/L2 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-QA2:3/L2', attributes=[Attribute(name=link, value=to =GL3+A1-QA1:3/L2 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD4:13', attributes=[Attribute(name=link, value=to =GL3+A1-QA1:6/T3 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-QA1:6/T3', attributes=[Attribute(name=link, value=to +A1-XD4:13 through ), Attribute(name=link, value=to =GL3+A1-QA2:6/T3 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-QA2:6/T3', attributes=[Attribute(name=link, value=to =GL3+A1-QA1:6/T3 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-FC1:6/T3', attributes=[Attribute(name=link, value=to =GL3+A1-QA1:5/L3 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-QA1:5/L3', attributes=[Attribute(name=link, value=to =GL3+A1-FC1:6/T3 through ), Attribute(name=link, value=to =GL3+A1-QA2:1/L1 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-QA2:1/L1', attributes=[Attribute(name=link, value=to =GL3+A1-QA1:5/L3 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:31', attributes=[Attribute(name=link, value=to =GL3+A1-FC1:14 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-FC1:14', attributes=[Attribute(name=link, value=to +A1-XG1:31 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:32', attributes=[Attribute(name=link, value=to =GL3+A1-FC1:13 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-FC1:13', attributes=[Attribute(name=link, value=to +A1-XG1:32 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-QA1:A1', attributes=[Attribute(name=link, value=to =GL3+A1-QA2:12 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-QA2:12', attributes=[Attribute(name=link, value=to =GL3+A1-QA1:A1 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:33', attributes=[Attribute(name=link, value=to =GL3+A1-QA2:11 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-QA2:11', attributes=[Attribute(name=link, value=to +A1-XG1:33 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:34', attributes=[Attribute(name=link, value=to =GL3+A1-QA1:A2 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-QA1:A2', attributes=[Attribute(name=link, value=to +A1-XG1:34 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-QA1:12', attributes=[Attribute(name=link, value=to =GL3+A1-QA2:A1 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-QA2:A1', attributes=[Attribute(name=link, value=to =GL3+A1-QA1:12 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:35', attributes=[Attribute(name=link, value=to =GL3+A1-QA1:11 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-QA1:11', attributes=[Attribute(name=link, value=to +A1-XG1:35 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:36', attributes=[Attribute(name=link, value=to =GL3+A1-QA2:A2 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-QA2:A2', attributes=[Attribute(name=link, value=to +A1-XG1:36 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:37', attributes=[Attribute(name=link, value=to =GL3+A1-QA1:14 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-QA1:14', attributes=[Attribute(name=link, value=to +A1-XG1:37 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:38', attributes=[Attribute(name=link, value=to =GL3+A1-QA1:13 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-QA1:13', attributes=[Attribute(name=link, value=to +A1-XG1:38 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:39', attributes=[Attribute(name=link, value=to =GL3+A1-QA2:14 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-QA2:14', attributes=[Attribute(name=link, value=to +A1-XG1:39 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:40', attributes=[Attribute(name=link, value=to =GL3+A1-QA2:13 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-QA2:13', attributes=[Attribute(name=link, value=to +A1-XG1:40 through )])
# Object: Object(tag=Tag(tag_str='+A2-XD2:1', attributes=[Attribute(name=link, value=to =K1+A2-FC1:1 through ), Attribute(name=link, value=to =GAB1+A2-FC1:2 through )])
# Object: Object(tag=Tag(tag_str='=K1+A2-FC1:1', attributes=[Attribute(name=link, value=to +A2-XD2:1 through ), Attribute(name=link, value=to =K1+A2-FC2:1 through )])
# Object: Object(tag=Tag(tag_str='=K1+A2-FC2:1', attributes=[Attribute(name=link, value=to =K1+A2-FC1:1 through ), Attribute(name=link, value=to =K1+A2-FC5:1 through )])
# Object: Object(tag=Tag(tag_str='=K1+A2-FC5:1', attributes=[Attribute(name=link, value=to =K1+A2-FC2:1 through ), Attribute(name=link, value=to =K1+A2-FC7:1 through )])
# Object: Object(tag=Tag(tag_str='=K1+A2-FC7:1', attributes=[Attribute(name=link, value=to =K1+A2-FC5:1 through ), Attribute(name=link, value=to =K1+A2-FC9:1 through )])
# Object: Object(tag=Tag(tag_str='=K1+A2-FC9:1', attributes=[Attribute(name=link, value=to =K1+A2-FC7:1 through ), Attribute(name=link, value=to =K2+A2-FC1:1 through )])
# Object: Object(tag=Tag(tag_str='=K2+A2-FC1:1', attributes=[Attribute(name=link, value=to =K1+A2-FC9:1 through ), Attribute(name=link, value=to =S1+A2-FC2:1 through )])
# Object: Object(tag=Tag(tag_str='=S1+A2-FC2:1', attributes=[Attribute(name=link, value=to =K2+A2-FC1:1 through ), Attribute(name=link, value=to =S2+A2-FC1:1 through )])
# Object: Object(tag=Tag(tag_str='=S2+A2-FC1:1', attributes=[Attribute(name=link, value=to =S1+A2-FC2:1 through )])
# Object: Object(tag=Tag(tag_str='=GAB1+A2-FC1:2', attributes=[Attribute(name=link, value=to +A2-XD2:1 through )])
# Object: Object(tag=Tag(tag_str='=GAB1+A2-FC1:1', attributes=[Attribute(name=link, value=to =GAB1+A2-TB1:OutDC:+ through )])
# Object: Object(tag=Tag(tag_str='=GAB1+A2-TB1:OutDC:+', attributes=[Attribute(name=link, value=to =GAB1+A2-FC1:1 through )])
# Object: Object(tag=Tag(tag_str='+A2-XD1:1', attributes=[Attribute(name=link, value=to =GAB1+A2-TB1:InAC:L1/+ through )])
# Object: Object(tag=Tag(tag_str='=GAB1+A2-TB1:InAC:L1/+', attributes=[Attribute(name=link, value=to +A2-XD1:1 through )])
# Object: Object(tag=Tag(tag_str='+A2-XD2:2', attributes=[Attribute(name=link, value=to =GAB1+A2-PF1:X1 through )])
# Object: Object(tag=Tag(tag_str='=GAB1+A2-PF1:X1', attributes=[Attribute(name=link, value=to +A2-XD2:2 through )])
# Object: Object(tag=Tag(tag_str='=GAB1+A2-TB1:OutDC', attributes=[Attribute(name=link, value=to =GAB1+A2-TB1:OutDC through ), Attribute(name=link, value=to =GAB1+A2-TB1:OutDC through ), Attribute(name=link, value=to =GAB1+A2-TB1:OutDC through ), Attribute(name=link, value=to =GAB1+A2-TB1:OutDC through ), Attribute(name=link, value=to =GAB1+A2-TB1:OutDC through ), Attribute(name=link, value=to =GAB1+A2-TB1:OutDC through )])
# Object: Object(tag=Tag(tag_str='+A2-XD1:2', attributes=[Attribute(name=link, value=to =GAB1+A2-TB1:InAC:L2 through )])
# Object: Object(tag=Tag(tag_str='=GAB1+A2-TB1:InAC:L2', attributes=[Attribute(name=link, value=to +A2-XD1:2 through )])
# Object: Object(tag=Tag(tag_str='+A2-XD2:3', attributes=[Attribute(name=link, value=to +A2-XD6:2 through ), Attribute(name=link, value=to =GAB1+A2-TB1:OutDC:- through )])
# Object: Object(tag=Tag(tag_str='+A2-XD6:2', attributes=[Attribute(name=link, value=to +A2-XD2:3 through ), Attribute(name=link, value=to =K1+A2-KEB1:X1:- through )])
# Object: Object(tag=Tag(tag_str='=GAB1+A2-TB1:OutDC:-', attributes=[Attribute(name=link, value=to +A2-XD2:3 through ), Attribute(name=link, value=to +A2-XD1:3 through )])
# Object: Object(tag=Tag(tag_str='+A2-XD1:3', attributes=[Attribute(name=link, value=to =GAB1+A2-TB1:InAC:L3/- through )])
# Object: Object(tag=Tag(tag_str='+A2-XD2:4', attributes=[Attribute(name=link, value=to =GAB1+A2-PF1:X2 through ), Attribute(name=link, value=to +A2-XD2:5 through )])
# Object: Object(tag=Tag(tag_str='=GAB1+A2-PF1:X2', attributes=[Attribute(name=link, value=to +A2-XD2:4 through )])
# Object: Object(tag=Tag(tag_str='+A2-XD2:5', attributes=[Attribute(name=link, value=to +A2-XD2:4 through )])
# Object: Object(tag=Tag(tag_str='+A2-XD1:5', attributes=[Attribute(name=link, value=to =GAB1+A2-TB1:InAC:PE through )])
# Object: Object(tag=Tag(tag_str='=GAB1+A2-TB1:InAC:PE', attributes=[Attribute(name=link, value=to +A2-XD1:5 through )])
# Object: Object(tag=Tag(tag_str='+A2-XD4:1', attributes=[Attribute(name=link, value=to =K1+A2-FC3:1 through ), Attribute(name=link, value=to =GAB2+A2-FC1:2 through )])
# Object: Object(tag=Tag(tag_str='=K1+A2-FC3:1', attributes=[Attribute(name=link, value=to +A2-XD4:1 through ), Attribute(name=link, value=to =F+A2-FC1:1 through )])
# Object: Object(tag=Tag(tag_str='=F+A2-FC1:1', attributes=[Attribute(name=link, value=to =K1+A2-FC3:1 through ), Attribute(name=link, value=to =K1+A2-FC4:1 through )])
# Object: Object(tag=Tag(tag_str='=K1+A2-FC4:1', attributes=[Attribute(name=link, value=to =F+A2-FC1:1 through ), Attribute(name=link, value=to =K1+A2-FC6:1 through )])
# Object: Object(tag=Tag(tag_str='=K1+A2-FC6:1', attributes=[Attribute(name=link, value=to =K1+A2-FC4:1 through ), Attribute(name=link, value=to =K1+A2-FC8:1 through )])
# Object: Object(tag=Tag(tag_str='=K1+A2-FC8:1', attributes=[Attribute(name=link, value=to =K1+A2-FC6:1 through ), Attribute(name=link, value=to =K1+A2-FC10:1 through )])
# Object: Object(tag=Tag(tag_str='=K1+A2-FC10:1', attributes=[Attribute(name=link, value=to =K1+A2-FC8:1 through )])
# Object: Object(tag=Tag(tag_str='=GAB2+A2-FC1:2', attributes=[Attribute(name=link, value=to +A2-XD4:1 through )])
# Object: Object(tag=Tag(tag_str='=GAB2+A2-FC1:1', attributes=[Attribute(name=link, value=to =GAB2+A2-TB1:OutDC:+ through )])
# Object: Object(tag=Tag(tag_str='=GAB2+A2-TB1:OutDC:+', attributes=[Attribute(name=link, value=to =GAB2+A2-FC1:1 through )])
# Object: Object(tag=Tag(tag_str='+A2-XD1:6', attributes=[Attribute(name=link, value=to =GAB2+A2-TB1:InAC:L1/+ through )])
# Object: Object(tag=Tag(tag_str='=GAB2+A2-TB1:InAC:L1/+', attributes=[Attribute(name=link, value=to +A2-XD1:6 through )])
# Object: Object(tag=Tag(tag_str='+A2-XD4:2', attributes=[Attribute(name=link, value=to =GAB2+A2-PF1:X1 through )])
# Object: Object(tag=Tag(tag_str='=GAB2+A2-PF1:X1', attributes=[Attribute(name=link, value=to +A2-XD4:2 through )])
# Object: Object(tag=Tag(tag_str='=GAB2+A2-TB1:OutDC', attributes=[Attribute(name=link, value=to =GAB2+A2-TB1:OutDC through ), Attribute(name=link, value=to =GAB2+A2-TB1:OutDC through ), Attribute(name=link, value=to =GAB2+A2-TB1:OutDC through ), Attribute(name=link, value=to =GAB2+A2-TB1:OutDC through ), Attribute(name=link, value=to =GAB2+A2-TB1:OutDC through ), Attribute(name=link, value=to =GAB2+A2-TB1:OutDC through )])
# Object: Object(tag=Tag(tag_str='+A2-XD1:7', attributes=[Attribute(name=link, value=to =GAB2+A2-TB1:InAC:L2 through )])
# Object: Object(tag=Tag(tag_str='=GAB2+A2-TB1:InAC:L2', attributes=[Attribute(name=link, value=to +A2-XD1:7 through )])
# Object: Object(tag=Tag(tag_str='+A2-XD4:3', attributes=[Attribute(name=link, value=to =K1+A2-KE1:1:2.3 through ), Attribute(name=link, value=to =GAB2+A2-TB1:OutDC:- through )])
# Object: Object(tag=Tag(tag_str='=K1+A2-KE1:1:2.3', attributes=[Attribute(name=link, value=to +A2-XD4:3 through ), Attribute(name=link, value=to =F+A2-KE1:1:2.3 through )])
# Object: Object(tag=Tag(tag_str='=F+A2-KE1:1:2.3', attributes=[Attribute(name=link, value=to =K1+A2-KE1:1:2.3 through ), Attribute(name=link, value=to =K1+A2-KE4:1:2.3 through )])
# Object: Object(tag=Tag(tag_str='=K1+A2-KE4:1:2.3', attributes=[Attribute(name=link, value=to =F+A2-KE1:1:2.3 through ), Attribute(name=link, value=to +A2-XD7:5 through )])
# Object: Object(tag=Tag(tag_str='+A2-XD7:5', attributes=[Attribute(name=link, value=to =K1+A2-KE4:1:2.3 through ), Attribute(name=link, value=to +A2-XD7:10 through )])
# Object: Object(tag=Tag(tag_str='+A2-XD7:10', attributes=[Attribute(name=link, value=to +A2-XD7:5 through ), Attribute(name=link, value=to +A2-XD7:15 through )])
# Object: Object(tag=Tag(tag_str='+A2-XD7:15', attributes=[Attribute(name=link, value=to +A2-XD7:10 through )])
# Object: Object(tag=Tag(tag_str='=GAB2+A2-TB1:OutDC:-', attributes=[Attribute(name=link, value=to +A2-XD4:3 through ), Attribute(name=link, value=to +A2-XD1:8 through )])
# Object: Object(tag=Tag(tag_str='+A2-XD1:8', attributes=[Attribute(name=link, value=to =GAB2+A2-TB1:InAC:L3/- through )])
# Object: Object(tag=Tag(tag_str='+A2-XD4:4', attributes=[Attribute(name=link, value=to =GAB2+A2-PF1:X2 through ), Attribute(name=link, value=to +A2-XD4:5 through )])
# Object: Object(tag=Tag(tag_str='=GAB2+A2-PF1:X2', attributes=[Attribute(name=link, value=to +A2-XD4:4 through )])
# Object: Object(tag=Tag(tag_str='+A2-XD4:5', attributes=[Attribute(name=link, value=to +A2-XD4:4 through )])
# Object: Object(tag=Tag(tag_str='+A2-XD1:9', attributes=[Attribute(name=link, value=to =GAB2+A2-TB1:InAC:PE through )])
# ...
# Connection: Connection(von="+A2-XG1:45", bis="=K1+A2-KE5:2:3.3", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+A2-XG1:46", bis="=K1+A2-KE5:2:4.1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+A2-XG1:47", bis="=K1+A2-KE5:2:4.2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+A2-XG1:48", bis="=K1+A2-KE5:2:4.3", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+A2-XG5:61", bis="=K1+A2-KE2:2:4.1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+A2-XG1:49", bis="+A2-XG5:61", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+A2-XG5:62", bis="=K1+A2-KE2:2:4.2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+A2-XG1:50", bis="+A2-XG5:62", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+A2-XG5:63", bis="=K1+A2-KE2:2:4.3", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+A2-XG5:64", bis="=K1+A2-KE2:2:4.4", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+A2-XG1:51", bis="+A2-XG5:64", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+A2-XG5:65", bis="=K1+A2-KE2:2:4.5", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+A2-XG1:52", bis="+A2-XG5:65", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+A2-XG5:66", bis="=K1+A2-KE2:2:4.6", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="=MM1+B1-BG1", bis="=MM1+B1-BG1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=MM1+B1-BG1", bis="=MM1+B1-BG1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=MM1+B1-BG1", bis="=MM1+B1-BG1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=MM1+B1-BG2", bis="=MM1+B1-BG2", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=MM1+B1-BG2", bis="=MM1+B1-BG2", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=MM1+B1-BG2", bis="=MM1+B1-BG2", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=K1+B1.X1-KE1:1:1.1", bis="=K1+B1.X1-KE1:1:2.1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="+B1.X1-XD1:1", bis="=K1+B1.X1-KE1:1:1.2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="+B1.X1-XD1:2", bis="=K1+B1.X1-KE1:1:1.3", tag="", attributes=[Attribute(name=Color, value=BU), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="+B1.X1-XD1:3", bis="=K1+B1.X1-KE1:1:1.4", tag="", attributes=[Attribute(name=Color, value=GNYE), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=K1+B1.X1-KE1:1:1.4", bis="=K1+B1.X1-KE1:1:2.4", tag="", attributes=[Attribute(name=Color, value=GNYE), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="+B1.X1-XD1:4", bis="=K1+B1.X1-KE1:1:2.2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="+B1.X1-XD1:5", bis="=K1+B1.X1-KE1:1:2.3", tag="", attributes=[Attribute(name=Color, value=BU), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="+B1.X1-XZ1:6", bis="=K1+B1.X1-KE1:3:1.2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+B1.X1-XZ1:7", bis="=K1+B1.X1-KE1:3:1.1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+B1.X1-XZ1:9", bis="=K1+B1.X1-KE1:3:2.1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+B1.X1-XZ1:10", bis="=K1+B1.X1-KE1:3:2.2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+B1.X1-XZ1:11", bis="=K1+B1.X1-KE1:3:2.3", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="=MM2+B2-BG1", bis="=MM2+B2-BG1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=MM2+B2-BG1", bis="=MM2+B2-BG1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=MM2+B2-BG1", bis="=MM2+B2-BG1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=MM2+B2-BG2", bis="=MM2+B2-BG2", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=MM2+B2-BG2", bis="=MM2+B2-BG2", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=MM2+B2-BG2", bis="=MM2+B2-BG2", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=MM3+B2-BG1", bis="=MM3+B2-BG1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=MM3+B2-BG1", bis="=MM3+B2-BG1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=MM3+B2-BG1", bis="=MM3+B2-BG1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=MM3+B2-BG2", bis="=MM3+B2-BG2", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=MM3+B2-BG2", bis="=MM3+B2-BG2", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=MM3+B2-BG2", bis="=MM3+B2-BG2", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=K1+B2.X1-KE1:1:1.1", bis="=K1+B2.X1-KE1:1:2.1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="+B2.X1-XD1:1", bis="=K1+B2.X1-KE1:1:1.2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="+B2.X1-XD1:2", bis="=K1+B2.X1-KE1:1:1.3", tag="", attributes=[Attribute(name=Color, value=BU), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="+B2.X1-XD1:3", bis="=K1+B2.X1-KE1:1:1.4", tag="", attributes=[Attribute(name=Color, value=GNYE), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=K1+B2.X1-KE1:1:1.4", bis="=K1+B2.X1-KE1:1:2.4", tag="", attributes=[Attribute(name=Color, value=GNYE), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="+B2.X1-XD1:4", bis="=K1+B2.X1-KE1:1:2.2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="+B2.X1-XD1:5", bis="=K1+B2.X1-KE1:1:2.3", tag="", attributes=[Attribute(name=Color, value=BU), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="+B2.X1-XZ1:6", bis="=K1+B2.X1-KE2:1:1.2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+B2.X1-XZ1:7", bis="=K1+B2.X1-KE2:1:1.1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+B2.X1-XZ1:9", bis="=K1+B2.X1-KE2:1:1.4", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+B2.X1-XZ1:10", bis="=K1+B2.X1-KE2:1:1.5", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+B2.X1-XZ1:11", bis="=K1+B2.X1-KE2:1:1.6", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+B2.X1-XZ1:20", bis="=K1+B2.X1-KE1:3:2.1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+B2.X1-XZ1:21", bis="=K1+B2.X1-KE1:3:2.2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+B2.X1-XZ1:22", bis="=K1+B2.X1-KE1:3:2.3", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+B2.X1-XZ1:31", bis="=K1+B2.X1-KE1:4:4.1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+B2.X1-XZ1:32", bis="=K1+B2.X1-KE1:4:4.2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+B2.X1-XZ1:33", bis="=K1+B2.X1-KE1:4:4.3", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="=GQA+B2.Y1-MB1", bis="=GQA+B2.Y1-MB1:x1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=GQA+B2.Y1-MB1", bis="=GQA+B2.Y1-MB1:x2", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=GQA+B2.Y1-S1", bis="=GQA+B2.Y1-S1:13", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=GQA+B2.Y1-S1", bis="=GQA+B2.Y1-S1:14", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=GQA+B2.Y1-S1:13", bis="=GQA+B2.Y1-S1:21", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=GQA+B2.Y1-S1", bis="=GQA+B2.Y1-S1:22", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=K2+B2.Y1-X0:3", bis="=K2+B2.Y1-MB1:x1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=K2+B2.Y1-X0:4", bis="=K2+B2.Y1-MB2:x1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=K2+B2.Y1-X0:9", bis="=K2+B2.Y1-MB1:x1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=K2+B2.Y1-X0:10", bis="=K2+B2.Y1-MB2:x1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=K2+B2.Y1-X0:11", bis="=K2+B2.Y1-MB1:x1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=K2+B2.Y1-X0:12", bis="=K2+B2.Y1-MB2:x1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="+B2.Y1-XD1:5", bis="=K2+B2.Y1-XD1:PE", tag="", attributes=[Attribute(name=Color, value=GNYE), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+B2.Y1-XDB1:1:1 female", bis="=K2+B2.Y1-X20:1", tag="", attributes=[])
# Connection: Connection(von="+B2.Y1-XDB1:2:2 female", bis="=K2+B2.Y1-X20:2", tag="", attributes=[])
# Connection: Connection(von="+B2.Y1-XDB1:3:3 female", bis="=K2+B2.Y1-X20:3", tag="", attributes=[])
# Connection: Connection(von="+B2.Y1-XDB1:PE: PE female", bis="=K2+B2.Y1-X20:4", tag="", attributes=[])
# Connection: Connection(von="=K2+B2.Y1-X0:1", bis="=K2+B2.Y1-MB1:x1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=K2+B2.Y1-X0:2", bis="=K2+B2.Y1-MB2:x1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=K2+B2.Y1-X0:5", bis="=K2+B2.Y1-MB1:x1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=K2+B2.Y1-X0:6", bis="=K2+B2.Y1-MB2:x1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=K2+B2.Y1-X0:7", bis="=K2+B2.Y1-MB1:x1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=K2+B2.Y1-X0:8", bis="=K2+B2.Y1-MB2:x1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=K1+B3.X1-KE1:1:1.1", bis="=K1+B3.X1-KE1:1:2.1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="+B3.X1-XD1:1", bis="=K1+B3.X1-KE1:1:1.2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="+B3.X1-XD1:2", bis="=K1+B3.X1-KE1:1:1.3", tag="", attributes=[Attribute(name=Color, value=BU), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="+B3.X1-XD1:3", bis="=K1+B3.X1-KE1:1:1.4", tag="", attributes=[Attribute(name=Color, value=GNYE), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=K1+B3.X1-KE1:1:1.4", bis="=K1+B3.X1-KE1:1:2.4", tag="", attributes=[Attribute(name=Color, value=GNYE), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="+B3.X1-XD1:4", bis="=K1+B3.X1-KE1:1:2.2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="+B3.X1-XD1:5", bis="=K1+B3.X1-KE1:1:2.3", tag="", attributes=[Attribute(name=Color, value=BU), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="+B3.X1-XZ1:6", bis="=K1+B3.X1-KE1:3:1.2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+B3.X1-XZ1:7", bis="=K1+B3.X1-KE1:3:1.1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+B3.X1-XZ1:9", bis="=K1+B3.X1-KE1:3:2.1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+B3.X1-XZ1:10", bis="=K1+B3.X1-KE1:3:2.2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+B3.X1-XZ1:11", bis="=K1+B3.X1-KE1:3:2.3", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+C2-XD1:1", bis="=S2+C2-PH1:X1:X1.1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="+C2-XD1:2", bis="=S2+C2-PH1:X1:X1.2", tag="", attributes=[Attribute(name=Color, value=BU), Attribute(name=Cross-section, value=1,5)])

# %%
def print_tree(tree, indent=0):
    """
    Recursively print the hierarchical tree of objects.
    """
    for key, value in tree.items():
        if key == "_objects":
            for obj in value:
                name = obj.get_name(mngr.configs)
                if name:  # Skip empty names
                    print("    " * indent + f"<> {name}")
        else:
            print("    " * indent + f"{key}:")
            print_tree(value, indent + 1)


print_tree(mngr.build_tree())
# Out:
# +:
#     A1:
#         -:
#             XD1:1:
#                 <> +A1-XD1:1
#             XD1:2:
#                 <> +A1-XD1:2
#             XD1:3:
#                 <> +A1-XD1:3
#             XD5:6:
#                 <> +A1-XD5:6
#             XD5:5:
#                 <> +A1-XD5:5
#             XD5:4:
#                 <> +A1-XD5:4
#             XD5:3:
#                 <> +A1-XD5:3
#             XD5:2:
#                 <> +A1-XD5:2
#             XD5:1:
#                 <> +A1-XD5:1
#             WE2:1:
#                 <> +A1-WE2:1
#             XD1:7:
#                 <> +A1-XD1:7
#             WE1:1:
#                 <> +A1-WE1:1
#             XD1:8:
#                 <> +A1-XD1:8
#             WE2:9:
#                 <> +A1-WE2:9
#             FC2:1:
#                 <> +A1-FC2:1
#             XD1:4:
#                 <> +A1-XD1:4
#             FC2:2:
#                 <> +A1-FC2:2
#             XD1:5:
#                 <> +A1-XD1:5
#             FC2:3:
#                 <> +A1-FC2:3
#             XD1:6:
#                 <> +A1-XD1:6
#             WE2:2:
#                 <> +A1-WE2:2
#             WE1:2:
#                 <> +A1-WE1:2
#             WE2:8:
#                 <> +A1-WE2:8
#             XD3:1:
#                 <> +A1-XD3:1
#             XD3:2:
#                 <> +A1-XD3:2
#             XD3:3:
#                 <> +A1-XD3:3
#             XD3:6:
#                 <> +A1-XD3:6
#             XD3:7:
#                 <> +A1-XD3:7
#             XD3:8:
#                 <> +A1-XD3:8
#             XG1:1:
#                 <> +A1-XG1:1
#             XG1:2:
#                 <> +A1-XG1:2
#             XD2:1:
#                 <> +A1-XD2:1
#             WE2:4:
#                 <> +A1-WE2:4
#             XD2:3:
#                 <> +A1-XD2:3
#             XD2:4:
#                 <> +A1-XD2:4
#             XD2:5:
#                 <> +A1-XD2:5
#             WE2:5:
#                 <> +A1-WE2:5
#             XD2:6:
#                 <> +A1-XD2:6
#             XD2:7:
#                 <> +A1-XD2:7
#             WE2:6:
#                 <> +A1-WE2:6
#             XD2:9:
#                 <> +A1-XD2:9
#             XD2:10:
#                 <> +A1-XD2:10
#             WE2:7:
#                 <> +A1-WE2:7
#             XD2:12:
#                 <> +A1-XD2:12
#             XD4:1:
#                 <> +A1-XD4:1
#             XD4:2:
#                 <> +A1-XD4:2
#             XD4:3:
#                 <> +A1-XD4:3
#             XG1:3:
#                 <> +A1-XG1:3
#             XG1:4:
#                 <> +A1-XG1:4
#             XG1:5:
#                 <> +A1-XG1:5
#             XG1:6:
#                 <> +A1-XG1:6
#             XG1:7:
#                 <> +A1-XG1:7
#             XG1:8:
#                 <> +A1-XG1:8
#             XG1:9:
#                 <> +A1-XG1:9
#             XG1:10:
#                 <> +A1-XG1:10
#             XG1:11:
#                 <> +A1-XG1:11
#             XG1:12:
#                 <> +A1-XG1:12
#             XD4:6:
#                 <> +A1-XD4:6
#             XD4:7:
#                 <> +A1-XD4:7
#             XD4:8:
#                 <> +A1-XD4:8
#             XG1:13:
#                 <> +A1-XG1:13
#             XG1:14:
#                 <> +A1-XG1:14
#             XG1:15:
#                 <> +A1-XG1:15
#             XG1:16:
#                 <> +A1-XG1:16
#             XG1:17:
#                 <> +A1-XG1:17
#             XG1:18:
#                 <> +A1-XG1:18
#             XG1:19:
#                 <> +A1-XG1:19
#             XG1:20:
#                 <> +A1-XG1:20
#             XG1:21:
#                 <> +A1-XG1:21
#             XG1:22:
#                 <> +A1-XG1:22
#             WE1:4:
#                 <> +A1-WE1:4
#             XG1:23:
#                 <> +A1-XG1:23
#             XG1:24:
#                 <> +A1-XG1:24
#             XG1:25:
#                 <> +A1-XG1:25
#             XG1:26:
#                 <> +A1-XG1:26
#             WE1:5:
#                 <> +A1-WE1:5
#             XG1:27:
#                 <> +A1-XG1:27
#             XG1:28:
#                 <> +A1-XG1:28
#             XG1:29:
#                 <> +A1-XG1:29
#             XG1:30:
#                 <> +A1-XG1:30
#             XD4:11:
#                 <> +A1-XD4:11
#             XD4:12:
#                 <> +A1-XD4:12
#             XD4:13:
#                 <> +A1-XD4:13
#             XG1:31:
#                 <> +A1-XG1:31
#             XG1:32:
#                 <> +A1-XG1:32
#             XG1:33:
#                 <> +A1-XG1:33
#             XG1:34:
#                 <> +A1-XG1:34
#             XG1:35:
#                 <> +A1-XG1:35
#             XG1:36:
#                 <> +A1-XG1:36
#             XG1:37:
#                 <> +A1-XG1:37
#             XG1:38:
#                 <> +A1-XG1:38
#             XG1:39:
#                 <> +A1-XG1:39
#             XG1:40:
#                 <> +A1-XG1:40
#             U3:
#                 <> +A1-U3
#             U4:
#                 <> +A1-U4
#             U5:
#                 <> +A1-U5
#             U6:
#                 <> +A1-U6
#             U7:
#                 <> +A1-U7
#             U8:
#                 <> +A1-U8
#             U9:
#                 <> +A1-U9
#             U10:
#                 <> +A1-U10
#             U11:
#                 <> +A1-U11
#             U12:
#                 <> +A1-U12
#             U13:
#                 <> +A1-U13
#             U14:
#                 <> +A1-U14
#             U15:
#                 <> +A1-U15
#             U16:
#                 <> +A1-U16
#             U17:
#                 <> +A1-U17
#             U18:
#                 <> +A1-U18
#             U19:
#                 <> +A1-U19
#             U20:
#                 <> +A1-U20
#             U21:
#                 <> +A1-U21
#             U22:
#                 <> +A1-U22
#             U23:
#                 <> +A1-U23
#             U24:
#                 <> +A1-U24
#             U25:
#                 <> +A1-U25
#             U26:
#                 <> +A1-U26
#             U27:
#                 <> +A1-U27
#             U28:
#                 <> +A1-U28
#             U29:
#                 <> +A1-U29
#             WD1:
#                 <> +A1-WD1
#             WD2:
#                 <> +A1-WD2
#             WE1:
#                 <> +A1-WE1
#             WE2:
#                 <> +A1-WE2
#     A2:
#         -:
#             XD2:1:
#                 <> +A2-XD2:1
#             XD1:1:
#                 <> +A2-XD1:1
#             XD2:2:
#                 <> +A2-XD2:2
#             XD1:2:
#                 <> +A2-XD1:2
#             XD2:3:
#                 <> +A2-XD2:3
#             XD6:2:
#                 <> +A2-XD6:2
#             XD1:3:
#                 <> +A2-XD1:3
#             XD2:4:
#                 <> +A2-XD2:4
#             XD2:5:
#                 <> +A2-XD2:5
#             XD1:5:
#                 <> +A2-XD1:5
#             XD4:1:
#                 <> +A2-XD4:1
#             XD1:6:
#                 <> +A2-XD1:6
#             XD4:2:
#                 <> +A2-XD4:2
#             XD1:7:
#                 <> +A2-XD1:7
#             XD4:3:
#                 <> +A2-XD4:3
#             XD7:5:
#                 <> +A2-XD7:5
#             XD7:10:
#                 <> +A2-XD7:10
#             XD7:15:
#                 <> +A2-XD7:15
#             XD1:8:
#                 <> +A2-XD1:8
#             XD4:4:
#                 <> +A2-XD4:4
#             XD4:5:
#                 <> +A2-XD4:5
#             XD1:9:
#                 <> +A2-XD1:9
#             XG5:1:
#                 <> +A2-XG5:1
#             XG1:1:
#                 <> +A2-XG1:1
#             XG5:2:
#                 <> +A2-XG5:2
#             XG1:2:
#                 <> +A2-XG1:2
#             XG5:3:
#                 <> +A2-XG5:3
#             XG1:3:
#                 <> +A2-XG1:3
#             XG5:4:
#                 <> +A2-XG5:4
#             XG1:4:
#                 <> +A2-XG1:4
#             XG5:5:
#                 <> +A2-XG5:5
#             XG1:5:
#                 <> +A2-XG1:5
#             XG5:6:
#                 <> +A2-XG5:6
#             XG1:6:
#                 <> +A2-XG1:6
#             XD5:4:
#                 <> +A2-XD5:4
#             XD5:5:
#                 <> +A2-XD5:5
#             XD5:6:
#                 <> +A2-XD5:6
#             XG2:1:
#                 <> +A2-XG2:1
#             XG2:2:
#                 <> +A2-XG2:2
#             XG2:3:
#                 <> +A2-XG2:3
#             XG2:4:
#                 <> +A2-XG2:4
#             XG2:17:
#                 <> +A2-XG2:17
#             XG2:18:
#                 <> +A2-XG2:18
#             XG2:19:
#                 <> +A2-XG2:19
#             XG2:20:
#                 <> +A2-XG2:20
#             XG3:49:
#                 <> +A2-XG3:49
#             XG3:50:
#                 <> +A2-XG3:50
#             XG3:51:
#                 <> +A2-XG3:51
#             XG3:52:
#                 <> +A2-XG3:52
#             XG3:53:
#                 <> +A2-XG3:53
#             XG3:54:
#                 <> +A2-XG3:54
#             XG3:55:
#                 <> +A2-XG3:55
#             XG3:56:
#                 <> +A2-XG3:56
#             XG2:5:
#                 <> +A2-XG2:5
#             XG2:6:
#                 <> +A2-XG2:6
#             XG2:7:
#                 <> +A2-XG2:7
#             XG2:8:
#                 <> +A2-XG2:8
#             XG2:9:
#                 <> +A2-XG2:9
#             XG2:10:
#                 <> +A2-XG2:10
#             XG2:11:
#                 <> +A2-XG2:11
#             XG2:12:
#                 <> +A2-XG2:12
#             XG2:13:
#                 <> +A2-XG2:13
#             XG2:14:
#                 <> +A2-XG2:14
#             XG2:15:
#                 <> +A2-XG2:15
#             XG2:16:
#                 <> +A2-XG2:16
#             XG3:1:
#                 <> +A2-XG3:1
#             XG3:2:
#                 <> +A2-XG3:2
#             XG3:3:
#                 <> +A2-XG3:3
#             XG3:4:
#                 <> +A2-XG3:4
#             XG3:5:
#                 <> +A2-XG3:5
#             XG3:6:
#                 <> +A2-XG3:6
#             XG3:7:
#                 <> +A2-XG3:7
#             XG3:8:
#                 <> +A2-XG3:8
#             XG3:9:
#                 <> +A2-XG3:9
#             XGA2:1:
#                 <> +A2-XGA2:1
#             XGA1:1:
#                 <> +A2-XGA1:1
#             XG3:10:
#                 <> +A2-XG3:10
#             XGA2:2:
#                 <> +A2-XGA2:2
#             XGA1:2:
#                 <> +A2-XGA1:2
#             XG3:11:
#                 <> +A2-XG3:11
#             XG3:12:
#                 <> +A2-XG3:12
#             XG3:13:
#                 <> +A2-XG3:13
#             XGA2:3:
#                 <> +A2-XGA2:3
#             XGA1:3:
#                 <> +A2-XGA1:3
#             XG3:14:
#                 <> +A2-XG3:14
#             XGA2:4:
#                 <> +A2-XGA2:4
#             XGA1:4:
#                 <> +A2-XGA1:4
#             XG3:15:
#                 <> +A2-XG3:15
#             XG3:16:
#                 <> +A2-XG3:16
#             XG3:17:
#                 <> +A2-XG3:17
#             XG4:1:
#                 <> +A2-XG4:1
#             XG3:18:
#                 <> +A2-XG3:18
#             XG4:2:
#                 <> +A2-XG4:2
#             XG3:19:
#                 <> +A2-XG3:19
#             XG3:20:
#                 <> +A2-XG3:20
#             XG3:21:
#                 <> +A2-XG3:21
#             XG4:3:
#                 <> +A2-XG4:3
#             XG3:22:
#                 <> +A2-XG3:22
#             XG4:4:
#                 <> +A2-XG4:4
#             XG3:23:
#                 <> +A2-XG3:23
#             XG3:24:
#                 <> +A2-XG3:24
#             XG3:25:
#                 <> +A2-XG3:25
#             XG4:5:
#                 <> +A2-XG4:5
#             XG3:26:
#                 <> +A2-XG3:26
#             XG4:6:
#                 <> +A2-XG4:6
#             XG3:27:
#                 <> +A2-XG3:27
#             XG3:28:
#                 <> +A2-XG3:28
#             XG3:29:
#                 <> +A2-XG3:29
#             XG4:7:
#                 <> +A2-XG4:7
#             XG3:30:
#                 <> +A2-XG3:30
#             XG4:8:
#                 <> +A2-XG4:8
#             XG3:31:
#                 <> +A2-XG3:31
#             XG3:32:
#                 <> +A2-XG3:32
#             XG3:33:
#                 <> +A2-XG3:33
#             XG4:9:
#                 <> +A2-XG4:9
#             XG3:34:
#                 <> +A2-XG3:34
#             XG4:10:
#                 <> +A2-XG4:10
#             XG3:35:
#                 <> +A2-XG3:35
#             XG3:36:
#                 <> +A2-XG3:36
#             XG3:37:
#                 <> +A2-XG3:37
#             XG4:11:
#                 <> +A2-XG4:11
#             XG3:38:
#                 <> +A2-XG3:38
#             XG4:12:
#                 <> +A2-XG4:12
#             XG3:39:
#                 <> +A2-XG3:39
#             XG3:40:
#                 <> +A2-XG3:40
#             XG3:41:
#                 <> +A2-XG3:41
#             XG4:13:
#                 <> +A2-XG4:13
#             XG3:42:
#                 <> +A2-XG3:42
#             XG4:14:
#                 <> +A2-XG4:14
#             XG3:43:
#                 <> +A2-XG3:43
#             XG3:44:
#                 <> +A2-XG3:44
#             XG3:45:
#                 <> +A2-XG3:45
#             XG4:15:
#                 <> +A2-XG4:15
#             XG3:46:
#                 <> +A2-XG3:46
#             XG4:16:
#                 <> +A2-XG4:16
#             XG3:47:
#                 <> +A2-XG3:47
#             XG3:48:
#                 <> +A2-XG3:48
#             XD6:1:
#                 <> +A2-XD6:1
#             XD6:3:
#                 <> +A2-XD6:3
#             XD7:2:
#                 <> +A2-XD7:2
#             XD7:7:
#                 <> +A2-XD7:7
#             XD7:12:
#                 <> +A2-XD7:12
#             XD7:18:
#                 <> +A2-XD7:18
#             XD7:21:
#                 <> +A2-XD7:21
#             XD6:4:
#                 <> +A2-XD6:4
#             WE1:2:
#                 <> +A2-WE1:2
#             WE1:3:
#                 <> +A2-WE1:3
#             WE1:4:
#                 <> +A2-WE1:4
#             XD7:17:
#                 <> +A2-XD7:17
#             WE1:5:
#                 <> +A2-WE1:5
#             XD7:1:
#                 <> +A2-XD7:1
#             XD7:4:
#                 <> +A2-XD7:4
#             XG5:7:
#                 <> +A2-XG5:7
#             XG5:8:
#                 <> +A2-XG5:8
#             XG5:9:
#                 <> +A2-XG5:9
#             XG5:10:
#                 <> +A2-XG5:10
#             XG5:11:
#                 <> +A2-XG5:11
#             XG5:12:
#                 <> +A2-XG5:12
#             XD7:6:
#                 <> +A2-XD7:6
#             XD7:9:
#                 <> +A2-XD7:9
#             XG5:13:
#                 <> +A2-XG5:13
#             XG5:14:
#                 <> +A2-XG5:14
#             XG5:15:
#                 <> +A2-XG5:15
#             XG5:16:
#                 <> +A2-XG5:16
#             XG5:17:
#                 <> +A2-XG5:17
#             XG5:18:
#                 <> +A2-XG5:18
#             XD7:11:
#                 <> +A2-XD7:11
#             XD7:14:
#                 <> +A2-XD7:14
#             XG5:19:
#                 <> +A2-XG5:19
#             XG5:20:
#                 <> +A2-XG5:20
#             XG5:21:
#                 <> +A2-XG5:21
#             XG5:22:
#                 <> +A2-XG5:22
#             XG5:23:
#                 <> +A2-XG5:23
#             XG5:24:
#                 <> +A2-XG5:24
#             XD7:16:
#                 <> +A2-XD7:16
#             XG5:25:
#                 <> +A2-XG5:25
#             XG5:26:
#                 <> +A2-XG5:26
#             XG5:27:
#                 <> +A2-XG5:27
#             XD7:20:
#                 <> +A2-XD7:20
#             XG5:28:
#                 <> +A2-XG5:28
#             XG1:7:
#                 <> +A2-XG1:7
#             XG5:29:
#                 <> +A2-XG5:29
#             XG1:8:
#                 <> +A2-XG1:8
#             XG5:30:
#                 <> +A2-XG5:30
#             XG1:9:
#                 <> +A2-XG1:9
#             XG1:10:
#                 <> +A2-XG1:10
#             XG1:11:
#                 <> +A2-XG1:11
#             XG1:12:
#                 <> +A2-XG1:12
#             XG1:13:
#                 <> +A2-XG1:13
#             XG1:14:
#                 <> +A2-XG1:14
#             XG5:31:
#                 <> +A2-XG5:31
#             XG1:15:
#                 <> +A2-XG1:15
#             XG5:32:
#                 <> +A2-XG5:32
#             XG1:16:
#                 <> +A2-XG1:16
#             XG5:33:
#                 <> +A2-XG5:33
#             XG5:34:
#                 <> +A2-XG5:34
#             XG1:17:
#                 <> +A2-XG1:17
#             XG5:35:
#                 <> +A2-XG5:35
#             XG1:18:
#                 <> +A2-XG1:18
#             XG5:36:
#                 <> +A2-XG5:36
#             XG5:37:
#                 <> +A2-XG5:37
#             XG1:19:
#                 <> +A2-XG1:19
#             XG5:38:
#                 <> +A2-XG5:38
#             XG1:20:
#                 <> +A2-XG1:20
#             XG5:39:
#                 <> +A2-XG5:39
#             XG1:21:
#                 <> +A2-XG1:21
#             XG1:22:
#                 <> +A2-XG1:22
#             XG1:23:
#                 <> +A2-XG1:23
#             XG1:24:
#                 <> +A2-XG1:24
#             XG1:25:
#                 <> +A2-XG1:25
#             XG1:26:
#                 <> +A2-XG1:26
#             XG5:40:
#                 <> +A2-XG5:40
#             XG1:27:
#                 <> +A2-XG1:27
#             XG5:41:
#                 <> +A2-XG5:41
#             XG1:28:
#                 <> +A2-XG1:28
#             XG5:42:
#                 <> +A2-XG5:42
#             XG5:43:
#                 <> +A2-XG5:43
#             XG1:29:
#                 <> +A2-XG1:29
#             XG5:44:
#                 <> +A2-XG5:44
#             XG1:30:
#                 <> +A2-XG1:30
#             XG5:45:
#                 <> +A2-XG5:45
#             XG5:46:
#                 <> +A2-XG5:46
#             XG1:31:
#                 <> +A2-XG1:31
#             XG5:47:
#                 <> +A2-XG5:47
#             XG1:32:
#                 <> +A2-XG1:32
#             XG5:48:
#                 <> +A2-XG5:48
#             XG5:49:
#                 <> +A2-XG5:49
#             XG5:50:
#                 <> +A2-XG5:50
#             XG5:51:
#                 <> +A2-XG5:51
#             XG1:33:
#                 <> +A2-XG1:33
#             XG1:34:
#                 <> +A2-XG1:34
#             XG1:35:
#                 <> +A2-XG1:35
#             XG5:52:
#                 <> +A2-XG5:52
#             XG1:36:
#                 <> +A2-XG1:36
#             XG5:53:
#                 <> +A2-XG5:53
#             XG1:37:
#                 <> +A2-XG1:37
#             XG5:54:
#                 <> +A2-XG5:54
#             XG5:55:
#                 <> +A2-XG5:55
#             XG5:56:
#                 <> +A2-XG5:56
#             XG5:57:
#                 <> +A2-XG5:57
#             XG1:38:
#                 <> +A2-XG1:38
#             XG1:39:
#                 <> +A2-XG1:39
#             XG1:40:
#                 <> +A2-XG1:40
#             XG5:58:
#                 <> +A2-XG5:58
#             XG1:41:
#                 <> +A2-XG1:41
#             XG5:59:
#                 <> +A2-XG5:59
#             XG1:42:
#                 <> +A2-XG1:42
#             XG5:60:
#                 <> +A2-XG5:60
#             XG1:43:
#                 <> +A2-XG1:43
#             XG1:44:
#                 <> +A2-XG1:44
#             XG1:45:
#                 <> +A2-XG1:45
#             XG1:46:
#                 <> +A2-XG1:46
#             XG1:47:
#                 <> +A2-XG1:47
#             XG1:48:
#                 <> +A2-XG1:48
#             XG5:61:
#                 <> +A2-XG5:61
#             XG1:49:
#                 <> +A2-XG1:49
#             XG5:62:
#                 <> +A2-XG5:62
#             XG1:50:
#                 <> +A2-XG1:50
#             XG5:63:
#                 <> +A2-XG5:63
#             XG5:64:
#                 <> +A2-XG5:64
#             XG1:51:
#                 <> +A2-XG1:51
#             XG5:65:
#                 <> +A2-XG5:65
#             XG1:52:
#                 <> +A2-XG1:52
#             XG5:66:
#                 <> +A2-XG5:66
#     B1.X1:
#         -:
#             XD1:1:
#                 <> +B1.X1-XD1:1
#             XD1:2:
#                 <> +B1.X1-XD1:2
#             XD1:3:
#                 <> +B1.X1-XD1:3
#             XD1:4:
#                 <> +B1.X1-XD1:4
#             XD1:5:
#                 <> +B1.X1-XD1:5
#             XZ1:6:
#                 <> +B1.X1-XZ1:6
#             XZ1:7:
#                 <> +B1.X1-XZ1:7
#             XZ1:9:
#                 <> +B1.X1-XZ1:9
#             XZ1:10:
#                 <> +B1.X1-XZ1:10
#             XZ1:11:
#                 <> +B1.X1-XZ1:11
#     B2.X1:
#         -:
#             XD1:1:
#                 <> +B2.X1-XD1:1
#             XD1:2:
#                 <> +B2.X1-XD1:2
#             XD1:3:
#                 <> +B2.X1-XD1:3
#             XD1:4:
#                 <> +B2.X1-XD1:4
#             XD1:5:
#                 <> +B2.X1-XD1:5
#             XZ1:6:
#                 <> +B2.X1-XZ1:6
#             XZ1:7:
#                 <> +B2.X1-XZ1:7
#             XZ1:9:
#                 <> +B2.X1-XZ1:9
#             XZ1:10:
#                 <> +B2.X1-XZ1:10
#             XZ1:11:
#                 <> +B2.X1-XZ1:11
#             XZ1:20:
#                 <> +B2.X1-XZ1:20
#             XZ1:21:
#                 <> +B2.X1-XZ1:21
#             XZ1:22:
#                 <> +B2.X1-XZ1:22
#             XZ1:31:
#                 <> +B2.X1-XZ1:31
#             XZ1:32:
#                 <> +B2.X1-XZ1:32
#             XZ1:33:
#                 <> +B2.X1-XZ1:33
#     B2.Y1:
#         -:
#             XD1:5:
#                 <> +B2.Y1-XD1:5
#             XDB1:1:1 female:
#                 <> +B2.Y1-XDB1:1:1 female
#             XDB1:2:2 female:
#                 <> +B2.Y1-XDB1:2:2 female
#             XDB1:3:3 female:
#                 <> +B2.Y1-XDB1:3:3 female
#             XDB1:PE: PE female:
#                 <> +B2.Y1-XDB1:PE: PE female
#     B3.X1:
#         -:
#             XD1:1:
#                 <> +B3.X1-XD1:1
#             XD1:2:
#                 <> +B3.X1-XD1:2
#             XD1:3:
#                 <> +B3.X1-XD1:3
#             XD1:4:
#                 <> +B3.X1-XD1:4
#             XD1:5:
#                 <> +B3.X1-XD1:5
#             XZ1:6:
#                 <> +B3.X1-XZ1:6
#             XZ1:7:
#                 <> +B3.X1-XZ1:7
#             XZ1:9:
#                 <> +B3.X1-XZ1:9
#             XZ1:10:
#                 <> +B3.X1-XZ1:10
#             XZ1:11:
#                 <> +B3.X1-XZ1:11
#     C2:
#         -:
#             XD1:1:
#                 <> +C2-XD1:1
#             XD1:2:
#                 <> +C2-XD1:2
# =:
#     GAA:
#         +:
#             A1:
#                 -:
#                     FC1:1:
#                         <> =GAA+A1-FC1:1
#                     FC1:2:
#                         <> =GAA+A1-FC1:2
#                     FC2:1:
#                         <> =GAA+A1-FC2:1
#                     FC1:3:
#                         <> =GAA+A1-FC1:3
#                     FC1:4:
#                         <> =GAA+A1-FC1:4
#                     FC3:1:
#                         <> =GAA+A1-FC3:1
#                     FC1:5:
#                         <> =GAA+A1-FC1:5
#                     FC5:1:
#                         <> =GAA+A1-FC5:1
#                     FC1:6:
#                         <> =GAA+A1-FC1:6
#                     FC4:1:
#                         <> =GAA+A1-FC4:1
#                     TA3:k:
#                         <> =GAA+A1-TA3:k
#                     TA3:l:
#                         <> =GAA+A1-TA3:l
#                     TA2:k:
#                         <> =GAA+A1-TA2:k
#                     TA2:l:
#                         <> =GAA+A1-TA2:l
#                     TA1:k:
#                         <> =GAA+A1-TA1:k
#                     TA1:l:
#                         <> =GAA+A1-TA1:l
#                     PF1:I3:11:
#                         <> =GAA+A1-PF1:I3:11
#                     PF1:I3:9:
#                         <> =GAA+A1-PF1:I3:9
#                     PF1:I2:7:
#                         <> =GAA+A1-PF1:I2:7
#                     PF1:I2:5:
#                         <> =GAA+A1-PF1:I2:5
#                     PF1:I1:3:
#                         <> =GAA+A1-PF1:I1:3
#                     PF1:I1:1:
#                         <> =GAA+A1-PF1:I1:1
#                     FC5:2:
#                         <> =GAA+A1-FC5:2
#                     PF1:AUX SUPPLY:20:
#                         <> =GAA+A1-PF1:AUX SUPPLY:20
#                     PF1:AUX SUPPLY:22:
#                         <> =GAA+A1-PF1:AUX SUPPLY:22
#                     PF1:I3:12:
#                         <> =GAA+A1-PF1:I3:12
#                     PF1:I3:14:
#                         <> =GAA+A1-PF1:I3:14
#                     PF1:I3:16:
#                         <> =GAA+A1-PF1:I3:16
#                     PF1:I3:2:
#                         <> =GAA+A1-PF1:I3:2
#                     PF1:I3:18:
#                         <> =GAA+A1-PF1:I3:18
#                     PF1:x2:
#                         <> =GAA+A1-PF1:x2
#                     PF1:RS485:17:
#                         <> =GAA+A1-PF1:RS485:17
#                     PF1:x1:
#                         <> =GAA+A1-PF1:x1
#                     PF1:RS485:15:
#                         <> =GAA+A1-PF1:RS485:15
#                     FC2:2:
#                         <> =GAA+A1-FC2:2
#                     PF2:X1:
#                         <> =GAA+A1-PF2:X1
#                     PF2:X2:
#                         <> =GAA+A1-PF2:X2
#                     PF3:X2:
#                         <> =GAA+A1-PF3:X2
#                     PF4:X2:
#                         <> =GAA+A1-PF4:X2
#                     FC3:2:
#                         <> =GAA+A1-FC3:2
#                     PF3:X1:
#                         <> =GAA+A1-PF3:X1
#                     FC4:2:
#                         <> =GAA+A1-FC4:2
#                     PF4:X1:
#                         <> =GAA+A1-PF4:X1
#                     FC1:
#                         <> =GAA+A1-FC1
#                     FC2:
#                         <> =GAA+A1-FC2
#                     FC3:
#                         <> =GAA+A1-FC3
#                     FC4:
#                         <> =GAA+A1-FC4
#                     FC5:
#                         <> =GAA+A1-FC5
#                     PF1:
#                         <> =GAA+A1-PF1
#                     PF2:
#                         <> =GAA+A1-PF2
#                     PF3:
#                         <> =GAA+A1-PF3
#                     PF4:
#                         <> =GAA+A1-PF4
#                     TA1:
#                         <> =GAA+A1-TA1
#                     TA2:
#                         <> =GAA+A1-TA2
#                     TA3:
#                         <> =GAA+A1-TA3
#     EA:
#         +:
#             A1:
#                 -:
#                     FB1:1:
#                         <> =EA+A1-FB1:1
#                     FB3:1:
#                         <> =EA+A1-FB3:1
#                     FB2:1:
#                         <> =EA+A1-FB2:1
#                     FB4:1:
#                         <> =EA+A1-FB4:1
#                     FB1:2:
#                         <> =EA+A1-FB1:2
#                     FB1:N:
#                         <> =EA+A1-FB1:N
#                     FB1:N.:
#                         <> =EA+A1-FB1:N.
#                     XD1:L:
#                         <> =EA+A1-XD1:L
#                     FB2:2:
#                         <> =EA+A1-FB2:2
#                     XD1:PE:
#                         <> =EA+A1-XD1:PE
#                     FB2:N:
#                         <> =EA+A1-FB2:N
#                     XD1:N:
#                         <> =EA+A1-XD1:N
#                     FB2:N.:
#                         <> =EA+A1-FB2:N.
#                     FB3:2:
#                         <> =EA+A1-FB3:2
#                     FB3:N:
#                         <> =EA+A1-FB3:N
#                     FB3:N.:
#                         <> =EA+A1-FB3:N.
#                     FB4:2:
#                         <> =EA+A1-FB4:2
#                     FB4:N:
#                         <> =EA+A1-FB4:N
#                     FB4:N.:
#                         <> =EA+A1-FB4:N.
#                     EA1:
#                         <> =EA+A1-EA1
#                     FB1:
#                         <> =EA+A1-FB1
#                     FB2:
#                         <> =EA+A1-FB2
#                     FB3:
#                         <> =EA+A1-FB3
#                     FB4:
#                         <> =EA+A1-FB4
#             A2:
#                 -:
#                     XD1:L:
#                         <> =EA+A2-XD1:L
#                     XD1:PE:
#                         <> =EA+A2-XD1:PE
#                     XD1:N:
#                         <> =EA+A2-XD1:N
#     GAB1:
#         +:
#             A1:
#                 -:
#                     FC1:1/L1:
#                         <> =GAB1+A1-FC1:1/L1
#                     FC1:3/L2:
#                         <> =GAB1+A1-FC1:3/L2
#                     FC1:5/L3:
#                         <> =GAB1+A1-FC1:5/L3
#                     FC1:2/T1:
#                         <> =GAB1+A1-FC1:2/T1
#                     FC1:4/T2:
#                         <> =GAB1+A1-FC1:4/T2
#                     FC1:6/T3:
#                         <> =GAB1+A1-FC1:6/T3
#                     FC1:
#                         <> =GAB1+A1-FC1
#             A2:
#                 -:
#                     FC1:2:
#                         <> =GAB1+A2-FC1:2
#                     FC1:1:
#                         <> =GAB1+A2-FC1:1
#                     PF1:X1:
#                         <> =GAB1+A2-PF1:X1
#                     TB1:OutDC:
#                         <> =GAB1+A2-TB1:OutDC
#                     TB1:InAC:L2:
#                         <> =GAB1+A2-TB1:InAC:L2
#                     :
#                         <> =GAB1+A2-
#                     PF1:X2:
#                         <> =GAB1+A2-PF1:X2
#                     TB1:InAC:PE:
#                         <> =GAB1+A2-TB1:InAC:PE
#             :
#                 -:
#                     TB1:OutDC::
#                         <> =GAB1+-TB1:OutDC:
#                     TB1:InAC:L1/:
#                         <> =GAB1+-TB1:InAC:L1/
#     GAB2:
#         +:
#             A1:
#                 -:
#                     FC1:1/L1:
#                         <> =GAB2+A1-FC1:1/L1
#                     FC1:3/L2:
#                         <> =GAB2+A1-FC1:3/L2
#                     FC1:5/L3:
#                         <> =GAB2+A1-FC1:5/L3
#                     FC1:2/T1:
#                         <> =GAB2+A1-FC1:2/T1
#                     FC1:4/T2:
#                         <> =GAB2+A1-FC1:4/T2
#                     FC1:6/T3:
#                         <> =GAB2+A1-FC1:6/T3
#                     FC1:14:
#                         <> =GAB2+A1-FC1:14
#                     FC1:13:
#                         <> =GAB2+A1-FC1:13
#                     FC1:
#                         <> =GAB2+A1-FC1
#             A2:
#                 -:
#                     FC1:2:
#                         <> =GAB2+A2-FC1:2
#                     FC1:1:
#                         <> =GAB2+A2-FC1:1
#                     PF1:X1:
#                         <> =GAB2+A2-PF1:X1
#                     TB1:OutDC:
#                         <> =GAB2+A2-TB1:OutDC
#                     TB1:InAC:L2:
#                         <> =GAB2+A2-TB1:InAC:L2
#                     :
#                         <> =GAB2+A2-
#                     PF1:X2:
#                         <> =GAB2+A2-PF1:X2
#                     TB1:InAC:PE:
#                         <> =GAB2+A2-TB1:InAC:PE
#                     TB1:Signal:14:
#                         <> =GAB2+A2-TB1:Signal:14
#                     TB1:Signal:13:
#                         <> =GAB2+A2-TB1:Signal:13
#             :
#                 -:
#                     TB1:OutDC::
#                         <> =GAB2+-TB1:OutDC:
#                     TB1:InAC:L1/:
#                         <> =GAB2+-TB1:InAC:L1/
#     GL1:
#         +:
#             A1:
#                 -:
#                     FC1:1/L1:
#                         <> =GL1+A1-FC1:1/L1
#                     FC1:3/L2:
#                         <> =GL1+A1-FC1:3/L2
#                     FC1:5/L3:
#                         <> =GL1+A1-FC1:5/L3
#                     QA1:2/T1:
#                         <> =GL1+A1-QA1:2/T1
#                     QA2:2/T1:
#                         <> =GL1+A1-QA2:2/T1
#                     FC1:2/T1:
#                         <> =GL1+A1-FC1:2/T1
#                     QA1:1/L1:
#                         <> =GL1+A1-QA1:1/L1
#                     QA2:5/L3:
#                         <> =GL1+A1-QA2:5/L3
#                     QA1:4/T2:
#                         <> =GL1+A1-QA1:4/T2
#                     QA2:4/T2:
#                         <> =GL1+A1-QA2:4/T2
#                     FC1:4/T2:
#                         <> =GL1+A1-FC1:4/T2
#                     QA1:3/L2:
#                         <> =GL1+A1-QA1:3/L2
#                     QA2:3/L2:
#                         <> =GL1+A1-QA2:3/L2
#                     QA1:6/T3:
#                         <> =GL1+A1-QA1:6/T3
#                     QA2:6/T3:
#                         <> =GL1+A1-QA2:6/T3
#                     FC1:6/T3:
#                         <> =GL1+A1-FC1:6/T3
#                     QA1:5/L3:
#                         <> =GL1+A1-QA1:5/L3
#                     QA2:1/L1:
#                         <> =GL1+A1-QA2:1/L1
#                     FC1:14:
#                         <> =GL1+A1-FC1:14
#                     FC1:13:
#                         <> =GL1+A1-FC1:13
#                     QA1:A1:
#                         <> =GL1+A1-QA1:A1
#                     QA2:12:
#                         <> =GL1+A1-QA2:12
#                     QA2:11:
#                         <> =GL1+A1-QA2:11
#                     QA1:A2:
#                         <> =GL1+A1-QA1:A2
#                     QA1:12:
#                         <> =GL1+A1-QA1:12
#                     QA2:A1:
#                         <> =GL1+A1-QA2:A1
#                     QA1:11:
#                         <> =GL1+A1-QA1:11
#                     QA2:A2:
#                         <> =GL1+A1-QA2:A2
#                     QA1:14:
#                         <> =GL1+A1-QA1:14
#                     QA1:13:
#                         <> =GL1+A1-QA1:13
#                     QA2:14:
#                         <> =GL1+A1-QA2:14
#                     QA2:13:
#                         <> =GL1+A1-QA2:13
#                     FC1:
#                         <> =GL1+A1-FC1
#                     QA1:
#                         <> =GL1+A1-QA1
#                     QA2:
#                         <> =GL1+A1-QA2
#     GL2:
#         +:
#             A1:
#                 -:
#                     FC1:1/L1:
#                         <> =GL2+A1-FC1:1/L1
#                     FC1:3/L2:
#                         <> =GL2+A1-FC1:3/L2
#                     FC1:5/L3:
#                         <> =GL2+A1-FC1:5/L3
#                     QA1:2/T1:
#                         <> =GL2+A1-QA1:2/T1
#                     QA2:2/T1:
#                         <> =GL2+A1-QA2:2/T1
#                     FC1:2/T1:
#                         <> =GL2+A1-FC1:2/T1
#                     QA1:1/L1:
#                         <> =GL2+A1-QA1:1/L1
#                     QA2:5/L3:
#                         <> =GL2+A1-QA2:5/L3
#                     QA1:4/T2:
#                         <> =GL2+A1-QA1:4/T2
#                     QA2:4/T2:
#                         <> =GL2+A1-QA2:4/T2
#                     FC1:4/T2:
#                         <> =GL2+A1-FC1:4/T2
#                     QA1:3/L2:
#                         <> =GL2+A1-QA1:3/L2
#                     QA2:3/L2:
#                         <> =GL2+A1-QA2:3/L2
#                     QA1:6/T3:
#                         <> =GL2+A1-QA1:6/T3
#                     QA2:6/T3:
#                         <> =GL2+A1-QA2:6/T3
#                     FC1:6/T3:
#                         <> =GL2+A1-FC1:6/T3
#                     QA1:5/L3:
#                         <> =GL2+A1-QA1:5/L3
#                     QA2:1/L1:
#                         <> =GL2+A1-QA2:1/L1
#                     FC1:14:
#                         <> =GL2+A1-FC1:14
#                     FC1:13:
#                         <> =GL2+A1-FC1:13
#                     QA1:A1:
#                         <> =GL2+A1-QA1:A1
#                     QA2:12:
#                         <> =GL2+A1-QA2:12
#                     QA2:11:
#                         <> =GL2+A1-QA2:11
#                     QA1:A2:
#                         <> =GL2+A1-QA1:A2
#                     QA1:12:
#                         <> =GL2+A1-QA1:12
#                     QA2:A1:
#                         <> =GL2+A1-QA2:A1
#                     QA1:11:
#                         <> =GL2+A1-QA1:11
#                     QA2:A2:
#                         <> =GL2+A1-QA2:A2
#                     QA1:14:
#                         <> =GL2+A1-QA1:14
#                     QA1:13:
#                         <> =GL2+A1-QA1:13
#                     QA2:14:
#                         <> =GL2+A1-QA2:14
#                     QA2:13:
#                         <> =GL2+A1-QA2:13
#                     FC1:
#                         <> =GL2+A1-FC1
#                     QA1:
#                         <> =GL2+A1-QA1
#                     QA2:
#                         <> =GL2+A1-QA2
#     TM1:
#         +:
#             A1:
#                 -:
#                     FC1:1/L1:
#                         <> =TM1+A1-FC1:1/L1
#                     FC1:3/L2:
#                         <> =TM1+A1-FC1:3/L2
#                     FC1:5/L3:
#                         <> =TM1+A1-FC1:5/L3
#                     FC1:2/T1:
#                         <> =TM1+A1-FC1:2/T1
#                     TA1:X1:1:
#                         <> =TM1+A1-TA1:X1:1
#                     FC1:4/T2:
#                         <> =TM1+A1-FC1:4/T2
#                     TA1:X1:2:
#                         <> =TM1+A1-TA1:X1:2
#                     FC1:6/T3:
#                         <> =TM1+A1-FC1:6/T3
#                     TA1:X1:3:
#                         <> =TM1+A1-TA1:X1:3
#                     TA1:X1:PE1:
#                         <> =TM1+A1-TA1:X1:PE1
#                     FC1:14:
#                         <> =TM1+A1-FC1:14
#                     FC1:13:
#                         <> =TM1+A1-FC1:13
#                     TA1:X12:1:
#                         <> =TM1+A1-TA1:X12:1
#                     TA1:X12:9:
#                         <> =TM1+A1-TA1:X12:9
#                     FC1:
#                         <> =TM1+A1-FC1
#                     TA1:
#                         <> =TM1+A1-TA1
#             A2:
#                 -:
#                     PF1:X1:
#                         <> =TM1+A2-PF1:X1
#                     PF1:X2:
#                         <> =TM1+A2-PF1:X2
#     TM2:
#         +:
#             A1:
#                 -:
#                     FC1:1/L1:
#                         <> =TM2+A1-FC1:1/L1
#                     FC1:3/L2:
#                         <> =TM2+A1-FC1:3/L2
#                     FC1:5/L3:
#                         <> =TM2+A1-FC1:5/L3
#                     FC1:2/T1:
#                         <> =TM2+A1-FC1:2/T1
#                     TA1:X1:1:
#                         <> =TM2+A1-TA1:X1:1
#                     FC1:4/T2:
#                         <> =TM2+A1-FC1:4/T2
#                     TA1:X1:2:
#                         <> =TM2+A1-TA1:X1:2
#                     FC1:6/T3:
#                         <> =TM2+A1-FC1:6/T3
#                     TA1:X1:3:
#                         <> =TM2+A1-TA1:X1:3
#                     TA1:X1:PE1:
#                         <> =TM2+A1-TA1:X1:PE1
#                     FC1:14:
#                         <> =TM2+A1-FC1:14
#                     FC1:13:
#                         <> =TM2+A1-FC1:13
#                     TA1:X12:1:
#                         <> =TM2+A1-TA1:X12:1
#                     TA1:X12:9:
#                         <> =TM2+A1-TA1:X12:9
#                     FC1:
#                         <> =TM2+A1-FC1
#                     TA1:
#                         <> =TM2+A1-TA1
#             A2:
#                 -:
#                     PF1:X1:
#                         <> =TM2+A2-PF1:X1
#                     PF1:X2:
#                         <> =TM2+A2-PF1:X2
#     GL3:
#         +:
#             A1:
#                 -:
#                     FC1:1/L1:
#                         <> =GL3+A1-FC1:1/L1
#                     FC1:3/L2:
#                         <> =GL3+A1-FC1:3/L2
#                     FC1:5/L3:
#                         <> =GL3+A1-FC1:5/L3
#                     QA1:2/T1:
#                         <> =GL3+A1-QA1:2/T1
#                     QA2:2/T1:
#                         <> =GL3+A1-QA2:2/T1
#                     FC1:2/T1:
#                         <> =GL3+A1-FC1:2/T1
#                     QA1:1/L1:
#                         <> =GL3+A1-QA1:1/L1
#                     QA2:5/L3:
#                         <> =GL3+A1-QA2:5/L3
#                     QA1:4/T2:
#                         <> =GL3+A1-QA1:4/T2
#                     QA2:4/T2:
#                         <> =GL3+A1-QA2:4/T2
#                     FC1:4/T2:
#                         <> =GL3+A1-FC1:4/T2
#                     QA1:3/L2:
#                         <> =GL3+A1-QA1:3/L2
#                     QA2:3/L2:
#                         <> =GL3+A1-QA2:3/L2
#                     QA1:6/T3:
#                         <> =GL3+A1-QA1:6/T3
#                     QA2:6/T3:
#                         <> =GL3+A1-QA2:6/T3
#                     FC1:6/T3:
#                         <> =GL3+A1-FC1:6/T3
#                     QA1:5/L3:
#                         <> =GL3+A1-QA1:5/L3
#                     QA2:1/L1:
#                         <> =GL3+A1-QA2:1/L1
#                     FC1:14:
#                         <> =GL3+A1-FC1:14
#                     FC1:13:
#                         <> =GL3+A1-FC1:13
#                     QA1:A1:
#                         <> =GL3+A1-QA1:A1
#                     QA2:12:
#                         <> =GL3+A1-QA2:12
#                     QA2:11:
#                         <> =GL3+A1-QA2:11
#                     QA1:A2:
#                         <> =GL3+A1-QA1:A2
#                     QA1:12:
#                         <> =GL3+A1-QA1:12
#                     QA2:A1:
#                         <> =GL3+A1-QA2:A1
#                     QA1:11:
#                         <> =GL3+A1-QA1:11
#                     QA2:A2:
#                         <> =GL3+A1-QA2:A2
#                     QA1:14:
#                         <> =GL3+A1-QA1:14
#                     QA1:13:
#                         <> =GL3+A1-QA1:13
#                     QA2:14:
#                         <> =GL3+A1-QA2:14
#                     QA2:13:
#                         <> =GL3+A1-QA2:13
#                     FC1:
#                         <> =GL3+A1-FC1
#                     QA1:
#                         <> =GL3+A1-QA1
#                     QA2:
#                         <> =GL3+A1-QA2
#     K1:
#         +:
#             A2:
#                 -:
#                     FC1:1:
#                         <> =K1+A2-FC1:1
#                     FC2:1:
#                         <> =K1+A2-FC2:1
#                     FC5:1:
#                         <> =K1+A2-FC5:1
#                     FC7:1:
#                         <> =K1+A2-FC7:1
#                     FC9:1:
#                         <> =K1+A2-FC9:1
#                     FC3:1:
#                         <> =K1+A2-FC3:1
#                     FC4:1:
#                         <> =K1+A2-FC4:1
#                     FC6:1:
#                         <> =K1+A2-FC6:1
#                     FC8:1:
#                         <> =K1+A2-FC8:1
#                     FC10:1:
#                         <> =K1+A2-FC10:1
#                     KE1:1:2.3:
#                         <> =K1+A2-KE1:1:2.3
#                     KE4:1:2.3:
#                         <> =K1+A2-KE4:1:2.3
#                     KE1:4:4.1:
#                         <> =K1+A2-KE1:4:4.1
#                     KE1:4:4.2:
#                         <> =K1+A2-KE1:4:4.2
#                     KE1:4:4.3:
#                         <> =K1+A2-KE1:4:4.3
#                     KE1:4:3.1:
#                         <> =K1+A2-KE1:4:3.1
#                     KE1:4:3.2:
#                         <> =K1+A2-KE1:4:3.2
#                     KE1:4:3.3:
#                         <> =K1+A2-KE1:4:3.3
#                     FC1:2:
#                         <> =K1+A2-FC1:2
#                     :
#                         <> =K1+A2-
#                     KE1:1:1.3:
#                         <> =K1+A2-KE1:1:1.3
#                     KEB1:X1:PE:
#                         <> =K1+A2-KEB1:X1:PE
#                     KE1:1:1.1:
#                         <> =K1+A2-KE1:1:1.1
#                     KE1:1:2.1:
#                         <> =K1+A2-KE1:1:2.1
#                     FC2:2:
#                         <> =K1+A2-FC2:2
#                     KE1:1:1.2:
#                         <> =K1+A2-KE1:1:1.2
#                     KE1:1:1.4:
#                         <> =K1+A2-KE1:1:1.4
#                     KE1:1:2.4:
#                         <> =K1+A2-KE1:1:2.4
#                     FC3:2:
#                         <> =K1+A2-FC3:2
#                     KE1:1:2.2:
#                         <> =K1+A2-KE1:1:2.2
#                     KE4:1:2.1:
#                         <> =K1+A2-KE4:1:2.1
#                     FC4:2:
#                         <> =K1+A2-FC4:2
#                     KE4:1:2.4:
#                         <> =K1+A2-KE4:1:2.4
#                     FC5:2:
#                         <> =K1+A2-FC5:2
#                     FC6:2:
#                         <> =K1+A2-FC6:2
#                     KE2:4:7.1:
#                         <> =K1+A2-KE2:4:7.1
#                     FC5:14:
#                         <> =K1+A2-FC5:14
#                     KE2:4:7.2:
#                         <> =K1+A2-KE2:4:7.2
#                     FC5:13:
#                         <> =K1+A2-FC5:13
#                     KE2:4:7.3:
#                         <> =K1+A2-KE2:4:7.3
#                     KE2:3:6.4:
#                         <> =K1+A2-KE2:3:6.4
#                     FC6:14:
#                         <> =K1+A2-FC6:14
#                     KE2:3:6.5:
#                         <> =K1+A2-KE2:3:6.5
#                     FC6:13:
#                         <> =K1+A2-FC6:13
#                     KE2:3:6.6:
#                         <> =K1+A2-KE2:3:6.6
#                     FC7:2:
#                         <> =K1+A2-FC7:2
#                     FC8:2:
#                         <> =K1+A2-FC8:2
#                     KE3:1:1.1:
#                         <> =K1+A2-KE3:1:1.1
#                     FC7:14:
#                         <> =K1+A2-FC7:14
#                     KE3:1:1.2:
#                         <> =K1+A2-KE3:1:1.2
#                     FC7:13:
#                         <> =K1+A2-FC7:13
#                     KE3:1:1.3:
#                         <> =K1+A2-KE3:1:1.3
#                     KE3:1:1.4:
#                         <> =K1+A2-KE3:1:1.4
#                     FC8:14:
#                         <> =K1+A2-FC8:14
#                     KE3:1:1.5:
#                         <> =K1+A2-KE3:1:1.5
#                     FC8:13:
#                         <> =K1+A2-FC8:13
#                     KE3:1:1.6:
#                         <> =K1+A2-KE3:1:1.6
#                     FC9:2:
#                         <> =K1+A2-FC9:2
#                     FC10:2:
#                         <> =K1+A2-FC10:2
#                     KE3:1:2.1:
#                         <> =K1+A2-KE3:1:2.1
#                     FC9:14:
#                         <> =K1+A2-FC9:14
#                     KE3:1:2.2:
#                         <> =K1+A2-KE3:1:2.2
#                     FC9:13:
#                         <> =K1+A2-FC9:13
#                     KE3:1:2.3:
#                         <> =K1+A2-KE3:1:2.3
#                     KE3:1:2.4:
#                         <> =K1+A2-KE3:1:2.4
#                     FC10:14:
#                         <> =K1+A2-FC10:14
#                     KE3:1:2.5:
#                         <> =K1+A2-KE3:1:2.5
#                     FC10:13:
#                         <> =K1+A2-FC10:13
#                     KE3:1:2.6:
#                         <> =K1+A2-KE3:1:2.6
#                     KE2:4:7.4:
#                         <> =K1+A2-KE2:4:7.4
#                     KE2:4:7.5:
#                         <> =K1+A2-KE2:4:7.5
#                     KE2:4:7.6:
#                         <> =K1+A2-KE2:4:7.6
#                     KE2:1:1.4:
#                         <> =K1+A2-KE2:1:1.4
#                     KE2:1:1.5:
#                         <> =K1+A2-KE2:1:1.5
#                     KE2:1:1.6:
#                         <> =K1+A2-KE2:1:1.6
#                     KE5:3:5.1:
#                         <> =K1+A2-KE5:3:5.1
#                     KE5:3:5.2:
#                         <> =K1+A2-KE5:3:5.2
#                     KE5:3:5.3:
#                         <> =K1+A2-KE5:3:5.3
#                     KE5:3:6.1:
#                         <> =K1+A2-KE5:3:6.1
#                     KE5:3:6.2:
#                         <> =K1+A2-KE5:3:6.2
#                     KE5:3:6.3:
#                         <> =K1+A2-KE5:3:6.3
#                     KE2:1:1.1:
#                         <> =K1+A2-KE2:1:1.1
#                     KE2:1:1.2:
#                         <> =K1+A2-KE2:1:1.2
#                     KE2:1:1.3:
#                         <> =K1+A2-KE2:1:1.3
#                     KE2:1:2.1:
#                         <> =K1+A2-KE2:1:2.1
#                     KE2:1:2.2:
#                         <> =K1+A2-KE2:1:2.2
#                     KE2:1:2.3:
#                         <> =K1+A2-KE2:1:2.3
#                     KE2:3:5.1:
#                         <> =K1+A2-KE2:3:5.1
#                     KE2:3:5.2:
#                         <> =K1+A2-KE2:3:5.2
#                     KE2:3:5.3:
#                         <> =K1+A2-KE2:3:5.3
#                     KE5:1:1.1:
#                         <> =K1+A2-KE5:1:1.1
#                     KE5:1:1.2:
#                         <> =K1+A2-KE5:1:1.2
#                     KE5:1:1.3:
#                         <> =K1+A2-KE5:1:1.3
#                     KE5:1:2.1:
#                         <> =K1+A2-KE5:1:2.1
#                     KE5:1:2.2:
#                         <> =K1+A2-KE5:1:2.2
#                     KE5:1:2.3:
#                         <> =K1+A2-KE5:1:2.3
#                     KE2:3:5.4:
#                         <> =K1+A2-KE2:3:5.4
#                     KE2:3:5.5:
#                         <> =K1+A2-KE2:3:5.5
#                     KE2:3:5.6:
#                         <> =K1+A2-KE2:3:5.6
#                     KE2:3:6.1:
# ...
#                     KE2:2:3.4:
#                         <> =K1+A2-KE2:2:3.4
#                     KE2:2:3.5:
#                         <> =K1+A2-KE2:2:3.5
#                     KE2:2:3.6:
#                         <> =K1+A2-KE2:2:3.6
#                     KE5:2:3.1:
#                         <> =K1+A2-KE5:2:3.1
#                     KE5:2:3.2:
#                         <> =K1+A2-KE5:2:3.2
#                     KE5:2:3.3:
#                         <> =K1+A2-KE5:2:3.3
#                     KE5:2:4.1:
#                         <> =K1+A2-KE5:2:4.1
#                     KE5:2:4.2:
#                         <> =K1+A2-KE5:2:4.2
#                     KE5:2:4.3:
#                         <> =K1+A2-KE5:2:4.3
#                     KE2:2:4.1:
#                         <> =K1+A2-KE2:2:4.1
#                     KE2:2:4.2:
#                         <> =K1+A2-KE2:2:4.2
#                     KE2:2:4.3:
#                         <> =K1+A2-KE2:2:4.3
#                     KE2:2:4.4:
#                         <> =K1+A2-KE2:2:4.4
#                     KE2:2:4.5:
#                         <> =K1+A2-KE2:2:4.5
#                     KE2:2:4.6:
#                         <> =K1+A2-KE2:2:4.6
#             :
#                 -:
#                     KEB1:X1::
#                         <> =K1+-KEB1:X1:
#             B1.X1:
#                 -:
#                     KE1:1:1.1:
#                         <> =K1+B1.X1-KE1:1:1.1
#                     KE1:1:2.1:
#                         <> =K1+B1.X1-KE1:1:2.1
#                     KE1:1:1.2:
#                         <> =K1+B1.X1-KE1:1:1.2
#                     KE1:1:1.3:
#                         <> =K1+B1.X1-KE1:1:1.3
#                     KE1:1:1.4:
#                         <> =K1+B1.X1-KE1:1:1.4
#                     KE1:1:2.4:
#                         <> =K1+B1.X1-KE1:1:2.4
#                     KE1:1:2.2:
#                         <> =K1+B1.X1-KE1:1:2.2
#                     KE1:1:2.3:
#                         <> =K1+B1.X1-KE1:1:2.3
#                     KE1:3:1.2:
#                         <> =K1+B1.X1-KE1:3:1.2
#                     KE1:3:1.1:
#                         <> =K1+B1.X1-KE1:3:1.1
#                     KE1:3:2.1:
#                         <> =K1+B1.X1-KE1:3:2.1
#                     KE1:3:2.2:
#                         <> =K1+B1.X1-KE1:3:2.2
#                     KE1:3:2.3:
#                         <> =K1+B1.X1-KE1:3:2.3
#             B2.X1:
#                 -:
#                     KE1:1:1.1:
#                         <> =K1+B2.X1-KE1:1:1.1
#                     KE1:1:2.1:
#                         <> =K1+B2.X1-KE1:1:2.1
#                     KE1:1:1.2:
#                         <> =K1+B2.X1-KE1:1:1.2
#                     KE1:1:1.3:
#                         <> =K1+B2.X1-KE1:1:1.3
#                     KE1:1:1.4:
#                         <> =K1+B2.X1-KE1:1:1.4
#                     KE1:1:2.4:
#                         <> =K1+B2.X1-KE1:1:2.4
#                     KE1:1:2.2:
#                         <> =K1+B2.X1-KE1:1:2.2
#                     KE1:1:2.3:
#                         <> =K1+B2.X1-KE1:1:2.3
#                     KE2:1:1.2:
#                         <> =K1+B2.X1-KE2:1:1.2
#                     KE2:1:1.1:
#                         <> =K1+B2.X1-KE2:1:1.1
#                     KE2:1:1.4:
#                         <> =K1+B2.X1-KE2:1:1.4
#                     KE2:1:1.5:
#                         <> =K1+B2.X1-KE2:1:1.5
#                     KE2:1:1.6:
#                         <> =K1+B2.X1-KE2:1:1.6
#                     KE1:3:2.1:
#                         <> =K1+B2.X1-KE1:3:2.1
#                     KE1:3:2.2:
#                         <> =K1+B2.X1-KE1:3:2.2
#                     KE1:3:2.3:
#                         <> =K1+B2.X1-KE1:3:2.3
#                     KE1:4:4.1:
#                         <> =K1+B2.X1-KE1:4:4.1
#                     KE1:4:4.2:
#                         <> =K1+B2.X1-KE1:4:4.2
#                     KE1:4:4.3:
#                         <> =K1+B2.X1-KE1:4:4.3
#             B3.X1:
#                 -:
#                     KE1:1:1.1:
#                         <> =K1+B3.X1-KE1:1:1.1
#                     KE1:1:2.1:
#                         <> =K1+B3.X1-KE1:1:2.1
#                     KE1:1:1.2:
#                         <> =K1+B3.X1-KE1:1:1.2
#                     KE1:1:1.3:
#                         <> =K1+B3.X1-KE1:1:1.3
#                     KE1:1:1.4:
#                         <> =K1+B3.X1-KE1:1:1.4
#                     KE1:1:2.4:
#                         <> =K1+B3.X1-KE1:1:2.4
#                     KE1:1:2.2:
#                         <> =K1+B3.X1-KE1:1:2.2
#                     KE1:1:2.3:
#                         <> =K1+B3.X1-KE1:1:2.3
#                     KE1:3:1.2:
#                         <> =K1+B3.X1-KE1:3:1.2
#                     KE1:3:1.1:
#                         <> =K1+B3.X1-KE1:3:1.1
#                     KE1:3:2.1:
#                         <> =K1+B3.X1-KE1:3:2.1
#                     KE1:3:2.2:
#                         <> =K1+B3.X1-KE1:3:2.2
#                     KE1:3:2.3:
#                         <> =K1+B3.X1-KE1:3:2.3
#     K2:
#         +:
#             A2:
#                 -:
#                     FC1:1:
#                         <> =K2+A2-FC1:1
#                     FC1:2:
#                         <> =K2+A2-FC1:2
#                     FC1:14:
#                         <> =K2+A2-FC1:14
#                     FC1:13:
#                         <> =K2+A2-FC1:13
#             B2.Y1:
#                 -:
#                     X0:3:
#                         <> =K2+B2.Y1-X0:3
#                     MB1:x1:
#                         <> =K2+B2.Y1-MB1:x1
#                     X0:4:
#                         <> =K2+B2.Y1-X0:4
#                     MB2:x1:
#                         <> =K2+B2.Y1-MB2:x1
#                     X0:9:
#                         <> =K2+B2.Y1-X0:9
#                     X0:10:
#                         <> =K2+B2.Y1-X0:10
#                     X0:11:
#                         <> =K2+B2.Y1-X0:11
#                     X0:12:
#                         <> =K2+B2.Y1-X0:12
#                     XD1:PE:
#                         <> =K2+B2.Y1-XD1:PE
#                     X20:1:
#                         <> =K2+B2.Y1-X20:1
#                     X20:2:
#                         <> =K2+B2.Y1-X20:2
#                     X20:3:
#                         <> =K2+B2.Y1-X20:3
#                     X20:4:
#                         <> =K2+B2.Y1-X20:4
#                     X0:1:
#                         <> =K2+B2.Y1-X0:1
#                     X0:2:
#                         <> =K2+B2.Y1-X0:2
#                     X0:5:
#                         <> =K2+B2.Y1-X0:5
#                     X0:6:
#                         <> =K2+B2.Y1-X0:6
#                     X0:7:
#                         <> =K2+B2.Y1-X0:7
#                     X0:8:
#                         <> =K2+B2.Y1-X0:8
#     S1:
#         +:
#             A2:
#                 -:
#                     FC2:1:
#                         <> =S1+A2-FC2:1
#                     PH1:X1:X1.2:
#                         <> =S1+A2-PH1:X1:X1.2
#                     FC2:2:
#                         <> =S1+A2-FC2:2
#                     PH1:X1:X1.1:
#                         <> =S1+A2-PH1:X1:X1.1
#     S2:
#         +:
#             A2:
#                 -:
#                     FC1:1:
#                         <> =S2+A2-FC1:1
#                     FC1:2:
#                         <> =S2+A2-FC1:2
#             C2:
#                 -:
#                     PH1:X1:X1.1:
#                         <> =S2+C2-PH1:X1:X1.1
#                     PH1:X1:X1.2:
#                         <> =S2+C2-PH1:X1:X1.2
#     F:
#         +:
#             A2:
#                 -:
#                     FC1:1:
#                         <> =F+A2-FC1:1
#                     KE1:1:2.3:
#                         <> =F+A2-KE1:1:2.3
#                     KF1:A1:
#                         <> =F+A2-KF1:A1
#                     KE4:1:1.1:
#                         <> =F+A2-KE4:1:1.1
#                     KE4:1:1.2:
#                         <> =F+A2-KE4:1:1.2
#                     KF1:A2:
#                         <> =F+A2-KF1:A2
#                     KE4:1:1.3:
#                         <> =F+A2-KE4:1:1.3
#                     KE4:1:1.4:
#                         <> =F+A2-KE4:1:1.4
#                     KF2:A1:
#                         <> =F+A2-KF2:A1
#                     KE4:3:5.1:
#                         <> =F+A2-KE4:3:5.1
#                     KE4:3:5.2:
#                         <> =F+A2-KE4:3:5.2
#                     KF2:A2:
#                         <> =F+A2-KF2:A2
#                     KE4:3:5.3:
#                         <> =F+A2-KE4:3:5.3
#                     KE4:3:5.4:
#                         <> =F+A2-KE4:3:5.4
#                     KE3:4:7.1:
#                         <> =F+A2-KE3:4:7.1
#                     KF1:44:
#                         <> =F+A2-KF1:44
#                     KE3:4:7.2:
#                         <> =F+A2-KE3:4:7.2
#                     KF1:43:
#                         <> =F+A2-KF1:43
#                     KE3:4:7.3:
#                         <> =F+A2-KE3:4:7.3
#                     KE3:4:7.4:
#                         <> =F+A2-KE3:4:7.4
#                     KE3:4:8.1:
#                         <> =F+A2-KE3:4:8.1
#                     KF2:44:
#                         <> =F+A2-KF2:44
#                     KE3:4:8.2:
#                         <> =F+A2-KE3:4:8.2
#                     KF2:43:
#                         <> =F+A2-KF2:43
#                     KE3:4:8.3:
#                         <> =F+A2-KE3:4:8.3
#                     KE3:4:8.4:
#                         <> =F+A2-KE3:4:8.4
#                     PF1:X1:
#                         <> =F+A2-PF1:X1
#                     KE4:1:2.1:
#                         <> =F+A2-KE4:1:2.1
#                     KE4:1:2.2:
#                         <> =F+A2-KE4:1:2.2
#                     PF1:X2:
#                         <> =F+A2-PF1:X2
#                     KE4:1:2.3:
#                         <> =F+A2-KE4:1:2.3
#                     KE4:1:2.4:
#                         <> =F+A2-KE4:1:2.4
#                     PF2:X1:
#                         <> =F+A2-PF2:X1
#                     KE4:2:3.1:
#                         <> =F+A2-KE4:2:3.1
#                     KE4:2:3.2:
#                         <> =F+A2-KE4:2:3.2
#                     PF2:X2:
#                         <> =F+A2-PF2:X2
#                     KE4:2:3.3:
#                         <> =F+A2-KE4:2:3.3
#                     KE4:2:3.4:
#                         <> =F+A2-KE4:2:3.4
#                     PF3:X1:
#                         <> =F+A2-PF3:X1
#                     KE4:2:4.1:
#                         <> =F+A2-KE4:2:4.1
#                     KE4:2:4.2:
#                         <> =F+A2-KE4:2:4.2
#                     PF3:X2:
#                         <> =F+A2-PF3:X2
#                     KE4:2:4.3:
#                         <> =F+A2-KE4:2:4.3
#                     KE4:2:4.4:
#                         <> =F+A2-KE4:2:4.4
#                     KE3:1:1.1:
#                         <> =F+A2-KE3:1:1.1
#                     SG1:12:
#                         <> =F+A2-SG1:12
#                     KE3:1:1.2:
#                         <> =F+A2-KE3:1:1.2
#                     SG1:11:
#                         <> =F+A2-SG1:11
#                     KE3:1:1.3:
#                         <> =F+A2-KE3:1:1.3
#                     KE3:1:1.4:
#                         <> =F+A2-KE3:1:1.4
#                     KE3:1:2.1:
#                         <> =F+A2-KE3:1:2.1
#                     SG1:24:
#                         <> =F+A2-SG1:24
#                     KE3:1:2.2:
#                         <> =F+A2-KE3:1:2.2
#                     SG1:23:
#                         <> =F+A2-SG1:23
#                     KE3:1:2.3:
#                         <> =F+A2-KE3:1:2.3
#                     KE3:1:2.4:
#                         <> =F+A2-KE3:1:2.4
#                     KE3:2:3.1:
#                         <> =F+A2-KE3:2:3.1
#                     KE3:2:3.2:
#                         <> =F+A2-KE3:2:3.2
#                     KE3:2:3.3:
#                         <> =F+A2-KE3:2:3.3
#                     KE3:2:3.4:
#                         <> =F+A2-KE3:2:3.4
#                     KE3:2:4.1:
#                         <> =F+A2-KE3:2:4.1
#                     KE3:2:4.2:
#                         <> =F+A2-KE3:2:4.2
#                     KE3:2:4.3:
#                         <> =F+A2-KE3:2:4.3
#                     KE3:2:4.4:
#                         <> =F+A2-KE3:2:4.4
#                     KE3:3:5.1:
#                         <> =F+A2-KE3:3:5.1
#                     KE3:3:5.2:
#                         <> =F+A2-KE3:3:5.2
#                     KE3:3:5.3:
#                         <> =F+A2-KE3:3:5.3
#                     KE3:3:5.4:
#                         <> =F+A2-KE3:3:5.4
#                     KE3:3:6.1:
#                         <> =F+A2-KE3:3:6.1
#                     KE3:3:6.2:
#                         <> =F+A2-KE3:3:6.2
#                     KE3:3:6.3:
#                         <> =F+A2-KE3:3:6.3
#                     KE3:3:6.4:
#                         <> =F+A2-KE3:3:6.4
#                     KE2:1:1.1:
#                         <> =F+A2-KE2:1:1.1
#                     KE2:1:1.2:
#                         <> =F+A2-KE2:1:1.2
#                     KE2:1:1.3:
#                         <> =F+A2-KE2:1:1.3
#                     KE2:1:1.4:
#                         <> =F+A2-KE2:1:1.4
#                     KE2:1:2.1:
#                         <> =F+A2-KE2:1:2.1
#                     KE2:1:2.2:
#                         <> =F+A2-KE2:1:2.2
#                     KE2:1:2.3:
#                         <> =F+A2-KE2:1:2.3
#                     KE2:1:2.4:
#                         <> =F+A2-KE2:1:2.4
#                     KE2:2:3.1:
#                         <> =F+A2-KE2:2:3.1
#                     KE2:2:3.2:
#                         <> =F+A2-KE2:2:3.2
#                     KE2:2:3.3:
#                         <> =F+A2-KE2:2:3.3
#                     KE2:2:3.4:
#                         <> =F+A2-KE2:2:3.4
#                     KE2:2:4.1:
#                         <> =F+A2-KE2:2:4.1
#                     KE2:2:4.2:
#                         <> =F+A2-KE2:2:4.2
#                     KE2:2:4.3:
#                         <> =F+A2-KE2:2:4.3
#                     KE2:2:4.4:
#                         <> =F+A2-KE2:2:4.4
#                     KE2:3:5.1:
#                         <> =F+A2-KE2:3:5.1
#                     KE2:3:5.2:
#                         <> =F+A2-KE2:3:5.2
#                     KE2:3:5.3:
#                         <> =F+A2-KE2:3:5.3
#                     KE2:3:5.4:
#                         <> =F+A2-KE2:3:5.4
#                     KE2:3:6.1:
#                         <> =F+A2-KE2:3:6.1
#                     KE2:3:6.2:
#                         <> =F+A2-KE2:3:6.2
#                     KE2:3:6.3:
#                         <> =F+A2-KE2:3:6.3
#                     KE2:3:6.4:
#                         <> =F+A2-KE2:3:6.4
#                     FC1:2:
#                         <> =F+A2-FC1:2
#                     KE1:1:2.1:
#                         <> =F+A2-KE1:1:2.1
#                     KE1:1:2.4:
#                         <> =F+A2-KE1:1:2.4
#                     KF2:14:
#                         <> =F+A2-KF2:14
#                     KF1:14:
#                         <> =F+A2-KF1:14
#                     KF2:13:
#                         <> =F+A2-KF2:13
#                     KF1:13:
#                         <> =F+A2-KF1:13
#     MM1:
#         +:
#             B1:
#                 -:
#                     BG1:
#                         <> =MM1+B1-BG1
#                     BG2:
#                         <> =MM1+B1-BG2
#     MM2:
#         +:
#             B2:
#                 -:
#                     BG1:
#                         <> =MM2+B2-BG1
#                     BG2:
#                         <> =MM2+B2-BG2
#     MM3:
#         +:
#             B2:
#                 -:
#                     BG1:
#                         <> =MM3+B2-BG1
#                     BG2:
#                         <> =MM3+B2-BG2
#     GQA:
#         +:
#             B2.Y1:
#                 -:
#                     MB1:
#                         <> =GQA+B2.Y1-MB1
#                     MB1:x1:
#                         <> =GQA+B2.Y1-MB1:x1
#                     MB1:x2:
#                         <> =GQA+B2.Y1-MB1:x2
#                     S1:
#                         <> =GQA+B2.Y1-S1
#                     S1:13:
#                         <> =GQA+B2.Y1-S1:13
#                     S1:14:
#                         <> =GQA+B2.Y1-S1:14
#                     S1:21:
#                         <> =GQA+B2.Y1-S1:21
#                     S1:22:
#                         <> =GQA+B2.Y1-S1:22

# %%
import plotly.graph_objects as go
import networkx as nx


def build_graph(objects, connections, configs):
    """
    Build a networkx graph from objects + connections.
    Each object is a node; edges come from connections.
    """
    G = nx.DiGraph()

    # Add object nodes
    for obj in objects:
        node_id = obj.get_name(configs)
        if not node_id:  # Skip empty objects
            continue
        # Create description from attributes
        desc_parts = [f"{attr.name}: {attr.value}" for attr in obj.attributes]
        desc = "<br>".join(desc_parts) if desc_parts else "No attributes"
        G.add_node(node_id, label=node_id, description=desc)

    # Add connection edges
    for conn in connections:
        von_name = conn.von.get_name(configs) if conn.von else None
        bis_name = conn.bis.get_name(configs) if conn.bis else None
        edge_label = conn.tag.tag_str if conn.tag.tag_str else "connection"

        if von_name and bis_name and von_name != bis_name:
            # Create description from connection attributes
            desc_parts = [f"{attr.name}: {attr.value}" for attr in conn.attributes]
            desc = "<br>".join(desc_parts) if desc_parts else edge_label
            G.add_edge(von_name, bis_name, label=edge_label, description=desc)

    return G


def plot_graph(G):
    """
    Plot the graph interactively with Plotly.
    Hover shows node/edge attributes.
    """
    if len(G.nodes()) == 0:
        print("No nodes to display in graph")
        return None

    pos = nx.spring_layout(G, seed=42)

    # Extract edges
    edge_x = []
    edge_y = []
    edge_text = []
    for edge in G.edges(data=True):
        x0, y0 = pos[edge[0]]
        x1, y1 = pos[edge[1]]
        edge_x.extend([x0, x1, None])
        edge_y.extend([y0, y1, None])
        edge_text.append(edge[2].get("description", ""))

    edge_trace = go.Scatter(
        x=edge_x,
        y=edge_y,
        line=dict(width=1, color="#888"),
        hoverinfo="text",
        mode="lines",
    )

    # Extract nodes
    node_x = []
    node_y = []
    node_text = []
    for node, data in G.nodes(data=True):
        x, y = pos[node]
        node_x.append(x)
        node_y.append(y)
        node_text.append(f"{data['label']}<br>{data['description']}")

    node_trace = go.Scatter(
        x=node_x,
        y=node_y,
        mode="markers+text",
        text=[n for n in G.nodes()],
        textposition="top center",
        hoverinfo="text",
        hovertext=node_text,
        marker=dict(showscale=False, color="skyblue", size=20, line_width=2),
    )

    fig = go.Figure(
        data=[edge_trace, node_trace],
        layout=go.Layout(
            title=dict(
                text="Interactive Object Tree with Connections", font=dict(size=16)
            ),
            showlegend=False,
            hovermode="closest",
            margin=dict(b=20, l=5, r=5, t=40),
            xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
            yaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
        ),
    )

    return fig


# Build + plot
G = build_graph(mngr.objects, mngr.connections, mngr.configs)
fig = plot_graph(G)
if fig:
    fig.show()

# %%
df_objects = extract(doc[52:55], TableType.DEVICE_TAG_LIST)
df_connections = extract(doc[29:40], TableType.CONNECTION_LIST)

mngr = Manager(configs)
mngr.read_connections(df_connections)
mngr.read_objects(df_objects)
mngr.print_stats()
# Out:
# Extracting 'TableType.DEVICE_TAG_LIST' from 3 pages...
# Extracting 'TableType.DEVICE_TAG_LIST' from page #53
# Extracting 'TableType.DEVICE_TAG_LIST' from page #54
# Extracting 'TableType.DEVICE_TAG_LIST' from page #55
# Extracting 'TableType.CONNECTION_LIST' from 11 pages...
# Extracting 'TableType.CONNECTION_LIST' from page #30
# Extracting 'TableType.CONNECTION_LIST' from page #31
# Extracting 'TableType.CONNECTION_LIST' from page #32
# Extracting 'TableType.CONNECTION_LIST' from page #33
# Extracting 'TableType.CONNECTION_LIST' from page #34
# Extracting 'TableType.CONNECTION_LIST' from page #35
# Extracting 'TableType.CONNECTION_LIST' from page #36
# Extracting 'TableType.CONNECTION_LIST' from page #37
# Extracting 'TableType.CONNECTION_LIST' from page #38
# Extracting 'TableType.CONNECTION_LIST' from page #39
# Extracting 'TableType.CONNECTION_LIST' from page #40
# Has 1022 objects
# Object: Object(tag=Tag(tag_str='', attributes=[])
# Object: Object(tag=Tag(tag_str='+A1-XD1:1', attributes=[Attribute(name=link, value=to =GAA+A1-FC1:1 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-FC1:1', attributes=[Attribute(name=link, value=to +A1-XD1:1 through ), Attribute(name=link, value=to =EA+A1-FB1:1 through )])
# Object: Object(tag=Tag(tag_str='=EA+A1-FB1:1', attributes=[Attribute(name=link, value=to =GAA+A1-FC1:1 through ), Attribute(name=link, value=to =EA+A1-FB3:1 through )])
# Object: Object(tag=Tag(tag_str='=EA+A1-FB3:1', attributes=[Attribute(name=link, value=to =EA+A1-FB1:1 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-FC1:2', attributes=[Attribute(name=link, value=to =GAA+A1-FC2:1 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-FC2:1', attributes=[Attribute(name=link, value=to =GAA+A1-FC1:2 through ), Attribute(name=link, value=to =GAB1+A1-FC1:1/L1 through )])
# Object: Object(tag=Tag(tag_str='=GAB1+A1-FC1:1/L1', attributes=[Attribute(name=link, value=to =GAA+A1-FC2:1 through ), Attribute(name=link, value=to =GAB2+A1-FC1:1/L1 through )])
# Object: Object(tag=Tag(tag_str='=GAB2+A1-FC1:1/L1', attributes=[Attribute(name=link, value=to =GAB1+A1-FC1:1/L1 through ), Attribute(name=link, value=to =GL1+A1-FC1:1/L1 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-FC1:1/L1', attributes=[Attribute(name=link, value=to =GAB2+A1-FC1:1/L1 through ), Attribute(name=link, value=to =GL2+A1-FC1:1/L1 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-FC1:1/L1', attributes=[Attribute(name=link, value=to =GL1+A1-FC1:1/L1 through ), Attribute(name=link, value=to =TM1+A1-FC1:1/L1 through )])
# Object: Object(tag=Tag(tag_str='=TM1+A1-FC1:1/L1', attributes=[Attribute(name=link, value=to =GL2+A1-FC1:1/L1 through ), Attribute(name=link, value=to =TM2+A1-FC1:1/L1 through )])
# Object: Object(tag=Tag(tag_str='=TM2+A1-FC1:1/L1', attributes=[Attribute(name=link, value=to =TM1+A1-FC1:1/L1 through ), Attribute(name=link, value=to =GL3+A1-FC1:1/L1 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-FC1:1/L1', attributes=[Attribute(name=link, value=to =TM2+A1-FC1:1/L1 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD1:2', attributes=[Attribute(name=link, value=to =GAA+A1-FC1:3 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-FC1:3', attributes=[Attribute(name=link, value=to +A1-XD1:2 through ), Attribute(name=link, value=to =EA+A1-FB2:1 through )])
# Object: Object(tag=Tag(tag_str='=EA+A1-FB2:1', attributes=[Attribute(name=link, value=to =GAA+A1-FC1:3 through ), Attribute(name=link, value=to =EA+A1-FB4:1 through )])
# Object: Object(tag=Tag(tag_str='=EA+A1-FB4:1', attributes=[Attribute(name=link, value=to =EA+A1-FB2:1 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-FC1:4', attributes=[Attribute(name=link, value=to =GAA+A1-FC3:1 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-FC3:1', attributes=[Attribute(name=link, value=to =GAA+A1-FC1:4 through ), Attribute(name=link, value=to =GAB1+A1-FC1:3/L2 through )])
# Object: Object(tag=Tag(tag_str='=GAB1+A1-FC1:3/L2', attributes=[Attribute(name=link, value=to =GAA+A1-FC3:1 through ), Attribute(name=link, value=to =GAB2+A1-FC1:3/L2 through )])
# Object: Object(tag=Tag(tag_str='=GAB2+A1-FC1:3/L2', attributes=[Attribute(name=link, value=to =GAB1+A1-FC1:3/L2 through ), Attribute(name=link, value=to =GL1+A1-FC1:3/L2 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-FC1:3/L2', attributes=[Attribute(name=link, value=to =GAB2+A1-FC1:3/L2 through ), Attribute(name=link, value=to =GL2+A1-FC1:3/L2 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-FC1:3/L2', attributes=[Attribute(name=link, value=to =GL1+A1-FC1:3/L2 through ), Attribute(name=link, value=to =TM1+A1-FC1:3/L2 through )])
# Object: Object(tag=Tag(tag_str='=TM1+A1-FC1:3/L2', attributes=[Attribute(name=link, value=to =GL2+A1-FC1:3/L2 through ), Attribute(name=link, value=to =TM2+A1-FC1:3/L2 through )])
# Object: Object(tag=Tag(tag_str='=TM2+A1-FC1:3/L2', attributes=[Attribute(name=link, value=to =TM1+A1-FC1:3/L2 through ), Attribute(name=link, value=to =GL3+A1-FC1:3/L2 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-FC1:3/L2', attributes=[Attribute(name=link, value=to =TM2+A1-FC1:3/L2 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD1:3', attributes=[Attribute(name=link, value=to =GAA+A1-FC1:5 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-FC1:5', attributes=[Attribute(name=link, value=to +A1-XD1:3 through ), Attribute(name=link, value=to =GAA+A1-FC5:1 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-FC5:1', attributes=[Attribute(name=link, value=to =GAA+A1-FC1:5 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-FC1:6', attributes=[Attribute(name=link, value=to =GAA+A1-FC4:1 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-FC4:1', attributes=[Attribute(name=link, value=to =GAA+A1-FC1:6 through ), Attribute(name=link, value=to =GAB1+A1-FC1:5/L3 through )])
# Object: Object(tag=Tag(tag_str='=GAB1+A1-FC1:5/L3', attributes=[Attribute(name=link, value=to =GAA+A1-FC4:1 through ), Attribute(name=link, value=to =GAB2+A1-FC1:5/L3 through )])
# Object: Object(tag=Tag(tag_str='=GAB2+A1-FC1:5/L3', attributes=[Attribute(name=link, value=to =GAB1+A1-FC1:5/L3 through ), Attribute(name=link, value=to =GL1+A1-FC1:5/L3 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-FC1:5/L3', attributes=[Attribute(name=link, value=to =GAB2+A1-FC1:5/L3 through ), Attribute(name=link, value=to =GL2+A1-FC1:5/L3 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-FC1:5/L3', attributes=[Attribute(name=link, value=to =GL1+A1-FC1:5/L3 through ), Attribute(name=link, value=to =TM1+A1-FC1:5/L3 through )])
# Object: Object(tag=Tag(tag_str='=TM1+A1-FC1:5/L3', attributes=[Attribute(name=link, value=to =GL2+A1-FC1:5/L3 through ), Attribute(name=link, value=to =TM2+A1-FC1:5/L3 through )])
# Object: Object(tag=Tag(tag_str='=TM2+A1-FC1:5/L3', attributes=[Attribute(name=link, value=to =TM1+A1-FC1:5/L3 through ), Attribute(name=link, value=to =GL3+A1-FC1:5/L3 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-FC1:5/L3', attributes=[Attribute(name=link, value=to =TM2+A1-FC1:5/L3 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD5:6', attributes=[Attribute(name=link, value=to =GAA+A1-TA3:k through ), Attribute(name=link, value=to =GAA+A1-PF1:I3:11 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-TA3:k', attributes=[Attribute(name=link, value=to +A1-XD5:6 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD5:5', attributes=[Attribute(name=link, value=to =GAA+A1-TA3:l through ), Attribute(name=link, value=to =GAA+A1-PF1:I3:9 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-TA3:l', attributes=[Attribute(name=link, value=to +A1-XD5:5 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD5:4', attributes=[Attribute(name=link, value=to =GAA+A1-TA2:k through ), Attribute(name=link, value=to =GAA+A1-PF1:I2:7 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-TA2:k', attributes=[Attribute(name=link, value=to +A1-XD5:4 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD5:3', attributes=[Attribute(name=link, value=to =GAA+A1-TA2:l through ), Attribute(name=link, value=to =GAA+A1-PF1:I2:5 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-TA2:l', attributes=[Attribute(name=link, value=to +A1-XD5:3 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD5:2', attributes=[Attribute(name=link, value=to =GAA+A1-TA1:k through ), Attribute(name=link, value=to =GAA+A1-PF1:I1:3 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-TA1:k', attributes=[Attribute(name=link, value=to +A1-XD5:2 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD5:1', attributes=[Attribute(name=link, value=to =GAA+A1-TA1:l through ), Attribute(name=link, value=to =GAA+A1-PF1:I1:1 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-TA1:l', attributes=[Attribute(name=link, value=to +A1-XD5:1 through )])
# Object: Object(tag=Tag(tag_str='+A1-WE2:1', attributes=[Attribute(name=link, value=to +A1-XD1:7 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD1:7', attributes=[Attribute(name=link, value=to +A1-WE2:1 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-PF1:I3:11', attributes=[Attribute(name=link, value=to +A1-XD5:6 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-PF1:I3:9', attributes=[Attribute(name=link, value=to +A1-XD5:5 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-PF1:I2:7', attributes=[Attribute(name=link, value=to +A1-XD5:4 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-PF1:I2:5', attributes=[Attribute(name=link, value=to +A1-XD5:3 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-PF1:I1:3', attributes=[Attribute(name=link, value=to +A1-XD5:2 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-PF1:I1:1', attributes=[Attribute(name=link, value=to +A1-XD5:1 through )])
# Object: Object(tag=Tag(tag_str='+A1-WE1:1', attributes=[Attribute(name=link, value=to +A1-XD1:8 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD1:8', attributes=[Attribute(name=link, value=to +A1-WE1:1 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-FC5:2', attributes=[Attribute(name=link, value=to =GAA+A1-PF1:AUX SUPPLY:20 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-PF1:AUX SUPPLY:20', attributes=[Attribute(name=link, value=to =GAA+A1-FC5:2 through )])
# Object: Object(tag=Tag(tag_str='+A1-WE2:9', attributes=[Attribute(name=link, value=to =GAA+A1-PF1:AUX SUPPLY:22 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-PF1:AUX SUPPLY:22', attributes=[Attribute(name=link, value=to +A1-WE2:9 through )])
# Object: Object(tag=Tag(tag_str='+A1-FC2:1', attributes=[Attribute(name=link, value=to +A1-XD1:4 through ), Attribute(name=link, value=to =GAA+A1-PF1:I3:12 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD1:4', attributes=[Attribute(name=link, value=to +A1-FC2:1 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-PF1:I3:12', attributes=[Attribute(name=link, value=to +A1-FC2:1 through )])
# Object: Object(tag=Tag(tag_str='+A1-FC2:2', attributes=[Attribute(name=link, value=to +A1-XD1:5 through ), Attribute(name=link, value=to =GAA+A1-PF1:I3:14 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD1:5', attributes=[Attribute(name=link, value=to +A1-FC2:2 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-PF1:I3:14', attributes=[Attribute(name=link, value=to +A1-FC2:2 through )])
# Object: Object(tag=Tag(tag_str='+A1-FC2:3', attributes=[Attribute(name=link, value=to +A1-XD1:6 through ), Attribute(name=link, value=to =GAA+A1-PF1:I3:16 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD1:6', attributes=[Attribute(name=link, value=to +A1-FC2:3 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-PF1:I3:16', attributes=[Attribute(name=link, value=to +A1-FC2:3 through )])
# Object: Object(tag=Tag(tag_str='+A1-WE2:2', attributes=[Attribute(name=link, value=to =GAA+A1-PF1:I3:2 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-PF1:I3:2', attributes=[Attribute(name=link, value=to +A1-WE2:2 through )])
# Object: Object(tag=Tag(tag_str='+A1-WE1:2', attributes=[Attribute(name=link, value=to =GAA+A1-PF1:I3:18 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-PF1:I3:18', attributes=[Attribute(name=link, value=to +A1-WE1:2 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-PF1:x2', attributes=[Attribute(name=link, value=to =GAA+A1-PF1:RS485:17 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-PF1:RS485:17', attributes=[Attribute(name=link, value=to =GAA+A1-PF1:x2 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-PF1:x1', attributes=[Attribute(name=link, value=to =GAA+A1-PF1:RS485:15 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-PF1:RS485:15', attributes=[Attribute(name=link, value=to =GAA+A1-PF1:x1 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-FC2:2', attributes=[Attribute(name=link, value=to =GAA+A1-PF2:X1 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-PF2:X1', attributes=[Attribute(name=link, value=to =GAA+A1-FC2:2 through )])
# Object: Object(tag=Tag(tag_str='+A1-WE2:8', attributes=[Attribute(name=link, value=to =GAA+A1-PF2:X2 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-PF2:X2', attributes=[Attribute(name=link, value=to +A1-WE2:8 through ), Attribute(name=link, value=to =GAA+A1-PF3:X2 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-PF3:X2', attributes=[Attribute(name=link, value=to =GAA+A1-PF2:X2 through ), Attribute(name=link, value=to =GAA+A1-PF4:X2 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-PF4:X2', attributes=[Attribute(name=link, value=to =GAA+A1-PF3:X2 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-FC3:2', attributes=[Attribute(name=link, value=to =GAA+A1-PF3:X1 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-PF3:X1', attributes=[Attribute(name=link, value=to =GAA+A1-FC3:2 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-FC4:2', attributes=[Attribute(name=link, value=to =GAA+A1-PF4:X1 through )])
# Object: Object(tag=Tag(tag_str='=GAA+A1-PF4:X1', attributes=[Attribute(name=link, value=to =GAA+A1-FC4:2 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD3:1', attributes=[Attribute(name=link, value=to =GAB1+A1-FC1:2/T1 through )])
# Object: Object(tag=Tag(tag_str='=GAB1+A1-FC1:2/T1', attributes=[Attribute(name=link, value=to +A1-XD3:1 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD3:2', attributes=[Attribute(name=link, value=to =GAB1+A1-FC1:4/T2 through )])
# Object: Object(tag=Tag(tag_str='=GAB1+A1-FC1:4/T2', attributes=[Attribute(name=link, value=to +A1-XD3:2 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD3:3', attributes=[Attribute(name=link, value=to =GAB1+A1-FC1:6/T3 through )])
# Object: Object(tag=Tag(tag_str='=GAB1+A1-FC1:6/T3', attributes=[Attribute(name=link, value=to +A1-XD3:3 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD3:6', attributes=[Attribute(name=link, value=to =GAB2+A1-FC1:2/T1 through )])
# Object: Object(tag=Tag(tag_str='=GAB2+A1-FC1:2/T1', attributes=[Attribute(name=link, value=to +A1-XD3:6 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD3:7', attributes=[Attribute(name=link, value=to =GAB2+A1-FC1:4/T2 through )])
# Object: Object(tag=Tag(tag_str='=GAB2+A1-FC1:4/T2', attributes=[Attribute(name=link, value=to +A1-XD3:7 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD3:8', attributes=[Attribute(name=link, value=to =GAB2+A1-FC1:6/T3 through )])
# Object: Object(tag=Tag(tag_str='=GAB2+A1-FC1:6/T3', attributes=[Attribute(name=link, value=to +A1-XD3:8 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:1', attributes=[Attribute(name=link, value=to =GAB2+A1-FC1:14 through )])
# Object: Object(tag=Tag(tag_str='=GAB2+A1-FC1:14', attributes=[Attribute(name=link, value=to +A1-XG1:1 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:2', attributes=[Attribute(name=link, value=to =GAB2+A1-FC1:13 through )])
# Object: Object(tag=Tag(tag_str='=GAB2+A1-FC1:13', attributes=[Attribute(name=link, value=to +A1-XG1:2 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD2:1', attributes=[Attribute(name=link, value=to =EA+A1-FB1:2 through )])
# Object: Object(tag=Tag(tag_str='=EA+A1-FB1:2', attributes=[Attribute(name=link, value=to +A1-XD2:1 through )])
# Object: Object(tag=Tag(tag_str='+A1-WE2:4', attributes=[Attribute(name=link, value=to =EA+A1-FB1:N through )])
# Object: Object(tag=Tag(tag_str='=EA+A1-FB1:N', attributes=[Attribute(name=link, value=to +A1-WE2:4 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD2:3', attributes=[Attribute(name=link, value=to =EA+A1-FB1:N. through )])
# Object: Object(tag=Tag(tag_str='=EA+A1-FB1:N.', attributes=[Attribute(name=link, value=to +A1-XD2:3 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD2:4', attributes=[Attribute(name=link, value=to =EA+A1-XD1:L through ), Attribute(name=link, value=to =EA+A1-FB2:2 through )])
# Object: Object(tag=Tag(tag_str='=EA+A1-XD1:L', attributes=[Attribute(name=link, value=to +A1-XD2:4 through )])
# Object: Object(tag=Tag(tag_str='=EA+A1-FB2:2', attributes=[Attribute(name=link, value=to +A1-XD2:4 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD2:5', attributes=[Attribute(name=link, value=to =EA+A1-XD1:PE through )])
# Object: Object(tag=Tag(tag_str='=EA+A1-XD1:PE', attributes=[Attribute(name=link, value=to +A1-XD2:5 through )])
# Object: Object(tag=Tag(tag_str='+A1-WE2:5', attributes=[Attribute(name=link, value=to =EA+A1-FB2:N through )])
# Object: Object(tag=Tag(tag_str='=EA+A1-FB2:N', attributes=[Attribute(name=link, value=to +A1-WE2:5 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD2:6', attributes=[Attribute(name=link, value=to =EA+A1-XD1:N through ), Attribute(name=link, value=to =EA+A1-FB2:N. through )])
# Object: Object(tag=Tag(tag_str='=EA+A1-XD1:N', attributes=[Attribute(name=link, value=to +A1-XD2:6 through )])
# Object: Object(tag=Tag(tag_str='=EA+A1-FB2:N.', attributes=[Attribute(name=link, value=to +A1-XD2:6 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD2:7', attributes=[Attribute(name=link, value=to =EA+A1-FB3:2 through )])
# Object: Object(tag=Tag(tag_str='=EA+A1-FB3:2', attributes=[Attribute(name=link, value=to +A1-XD2:7 through )])
# Object: Object(tag=Tag(tag_str='+A1-WE2:6', attributes=[Attribute(name=link, value=to =EA+A1-FB3:N through )])
# Object: Object(tag=Tag(tag_str='=EA+A1-FB3:N', attributes=[Attribute(name=link, value=to +A1-WE2:6 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD2:9', attributes=[Attribute(name=link, value=to =EA+A1-FB3:N. through )])
# Object: Object(tag=Tag(tag_str='=EA+A1-FB3:N.', attributes=[Attribute(name=link, value=to +A1-XD2:9 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD2:10', attributes=[Attribute(name=link, value=to =EA+A1-FB4:2 through )])
# Object: Object(tag=Tag(tag_str='=EA+A1-FB4:2', attributes=[Attribute(name=link, value=to +A1-XD2:10 through )])
# Object: Object(tag=Tag(tag_str='+A1-WE2:7', attributes=[Attribute(name=link, value=to =EA+A1-FB4:N through )])
# Object: Object(tag=Tag(tag_str='=EA+A1-FB4:N', attributes=[Attribute(name=link, value=to +A1-WE2:7 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD2:12', attributes=[Attribute(name=link, value=to =EA+A1-FB4:N. through )])
# Object: Object(tag=Tag(tag_str='=EA+A1-FB4:N.', attributes=[Attribute(name=link, value=to +A1-XD2:12 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD4:1', attributes=[Attribute(name=link, value=to =GL1+A1-QA1:2/T1 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-QA1:2/T1', attributes=[Attribute(name=link, value=to +A1-XD4:1 through ), Attribute(name=link, value=to =GL1+A1-QA2:2/T1 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-QA2:2/T1', attributes=[Attribute(name=link, value=to =GL1+A1-QA1:2/T1 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-FC1:2/T1', attributes=[Attribute(name=link, value=to =GL1+A1-QA1:1/L1 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-QA1:1/L1', attributes=[Attribute(name=link, value=to =GL1+A1-FC1:2/T1 through ), Attribute(name=link, value=to =GL1+A1-QA2:5/L3 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-QA2:5/L3', attributes=[Attribute(name=link, value=to =GL1+A1-QA1:1/L1 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD4:2', attributes=[Attribute(name=link, value=to =GL1+A1-QA1:4/T2 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-QA1:4/T2', attributes=[Attribute(name=link, value=to +A1-XD4:2 through ), Attribute(name=link, value=to =GL1+A1-QA2:4/T2 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-QA2:4/T2', attributes=[Attribute(name=link, value=to =GL1+A1-QA1:4/T2 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-FC1:4/T2', attributes=[Attribute(name=link, value=to =GL1+A1-QA1:3/L2 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-QA1:3/L2', attributes=[Attribute(name=link, value=to =GL1+A1-FC1:4/T2 through ), Attribute(name=link, value=to =GL1+A1-QA2:3/L2 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-QA2:3/L2', attributes=[Attribute(name=link, value=to =GL1+A1-QA1:3/L2 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD4:3', attributes=[Attribute(name=link, value=to =GL1+A1-QA1:6/T3 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-QA1:6/T3', attributes=[Attribute(name=link, value=to +A1-XD4:3 through ), Attribute(name=link, value=to =GL1+A1-QA2:6/T3 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-QA2:6/T3', attributes=[Attribute(name=link, value=to =GL1+A1-QA1:6/T3 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-FC1:6/T3', attributes=[Attribute(name=link, value=to =GL1+A1-QA1:5/L3 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-QA1:5/L3', attributes=[Attribute(name=link, value=to =GL1+A1-FC1:6/T3 through ), Attribute(name=link, value=to =GL1+A1-QA2:1/L1 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-QA2:1/L1', attributes=[Attribute(name=link, value=to =GL1+A1-QA1:5/L3 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:3', attributes=[Attribute(name=link, value=to =GL1+A1-FC1:14 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-FC1:14', attributes=[Attribute(name=link, value=to +A1-XG1:3 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:4', attributes=[Attribute(name=link, value=to =GL1+A1-FC1:13 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-FC1:13', attributes=[Attribute(name=link, value=to +A1-XG1:4 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-QA1:A1', attributes=[Attribute(name=link, value=to =GL1+A1-QA2:12 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-QA2:12', attributes=[Attribute(name=link, value=to =GL1+A1-QA1:A1 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:5', attributes=[Attribute(name=link, value=to =GL1+A1-QA2:11 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-QA2:11', attributes=[Attribute(name=link, value=to +A1-XG1:5 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:6', attributes=[Attribute(name=link, value=to =GL1+A1-QA1:A2 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-QA1:A2', attributes=[Attribute(name=link, value=to +A1-XG1:6 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-QA1:12', attributes=[Attribute(name=link, value=to =GL1+A1-QA2:A1 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-QA2:A1', attributes=[Attribute(name=link, value=to =GL1+A1-QA1:12 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:7', attributes=[Attribute(name=link, value=to =GL1+A1-QA1:11 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-QA1:11', attributes=[Attribute(name=link, value=to +A1-XG1:7 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:8', attributes=[Attribute(name=link, value=to =GL1+A1-QA2:A2 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-QA2:A2', attributes=[Attribute(name=link, value=to +A1-XG1:8 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:9', attributes=[Attribute(name=link, value=to =GL1+A1-QA1:14 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-QA1:14', attributes=[Attribute(name=link, value=to +A1-XG1:9 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:10', attributes=[Attribute(name=link, value=to =GL1+A1-QA1:13 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-QA1:13', attributes=[Attribute(name=link, value=to +A1-XG1:10 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:11', attributes=[Attribute(name=link, value=to =GL1+A1-QA2:14 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-QA2:14', attributes=[Attribute(name=link, value=to +A1-XG1:11 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:12', attributes=[Attribute(name=link, value=to =GL1+A1-QA2:13 through )])
# Object: Object(tag=Tag(tag_str='=GL1+A1-QA2:13', attributes=[Attribute(name=link, value=to +A1-XG1:12 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD4:6', attributes=[Attribute(name=link, value=to =GL2+A1-QA1:2/T1 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-QA1:2/T1', attributes=[Attribute(name=link, value=to +A1-XD4:6 through ), Attribute(name=link, value=to =GL2+A1-QA2:2/T1 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-QA2:2/T1', attributes=[Attribute(name=link, value=to =GL2+A1-QA1:2/T1 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-FC1:2/T1', attributes=[Attribute(name=link, value=to =GL2+A1-QA1:1/L1 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-QA1:1/L1', attributes=[Attribute(name=link, value=to =GL2+A1-FC1:2/T1 through ), Attribute(name=link, value=to =GL2+A1-QA2:5/L3 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-QA2:5/L3', attributes=[Attribute(name=link, value=to =GL2+A1-QA1:1/L1 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD4:7', attributes=[Attribute(name=link, value=to =GL2+A1-QA1:4/T2 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-QA1:4/T2', attributes=[Attribute(name=link, value=to +A1-XD4:7 through ), Attribute(name=link, value=to =GL2+A1-QA2:4/T2 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-QA2:4/T2', attributes=[Attribute(name=link, value=to =GL2+A1-QA1:4/T2 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-FC1:4/T2', attributes=[Attribute(name=link, value=to =GL2+A1-QA1:3/L2 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-QA1:3/L2', attributes=[Attribute(name=link, value=to =GL2+A1-FC1:4/T2 through ), Attribute(name=link, value=to =GL2+A1-QA2:3/L2 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-QA2:3/L2', attributes=[Attribute(name=link, value=to =GL2+A1-QA1:3/L2 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD4:8', attributes=[Attribute(name=link, value=to =GL2+A1-QA1:6/T3 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-QA1:6/T3', attributes=[Attribute(name=link, value=to +A1-XD4:8 through ), Attribute(name=link, value=to =GL2+A1-QA2:6/T3 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-QA2:6/T3', attributes=[Attribute(name=link, value=to =GL2+A1-QA1:6/T3 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-FC1:6/T3', attributes=[Attribute(name=link, value=to =GL2+A1-QA1:5/L3 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-QA1:5/L3', attributes=[Attribute(name=link, value=to =GL2+A1-FC1:6/T3 through ), Attribute(name=link, value=to =GL2+A1-QA2:1/L1 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-QA2:1/L1', attributes=[Attribute(name=link, value=to =GL2+A1-QA1:5/L3 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:13', attributes=[Attribute(name=link, value=to =GL2+A1-FC1:14 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-FC1:14', attributes=[Attribute(name=link, value=to +A1-XG1:13 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:14', attributes=[Attribute(name=link, value=to =GL2+A1-FC1:13 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-FC1:13', attributes=[Attribute(name=link, value=to +A1-XG1:14 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-QA1:A1', attributes=[Attribute(name=link, value=to =GL2+A1-QA2:12 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-QA2:12', attributes=[Attribute(name=link, value=to =GL2+A1-QA1:A1 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:15', attributes=[Attribute(name=link, value=to =GL2+A1-QA2:11 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-QA2:11', attributes=[Attribute(name=link, value=to +A1-XG1:15 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:16', attributes=[Attribute(name=link, value=to =GL2+A1-QA1:A2 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-QA1:A2', attributes=[Attribute(name=link, value=to +A1-XG1:16 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-QA1:12', attributes=[Attribute(name=link, value=to =GL2+A1-QA2:A1 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-QA2:A1', attributes=[Attribute(name=link, value=to =GL2+A1-QA1:12 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:17', attributes=[Attribute(name=link, value=to =GL2+A1-QA1:11 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-QA1:11', attributes=[Attribute(name=link, value=to +A1-XG1:17 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:18', attributes=[Attribute(name=link, value=to =GL2+A1-QA2:A2 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-QA2:A2', attributes=[Attribute(name=link, value=to +A1-XG1:18 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:19', attributes=[Attribute(name=link, value=to =GL2+A1-QA1:14 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-QA1:14', attributes=[Attribute(name=link, value=to +A1-XG1:19 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:20', attributes=[Attribute(name=link, value=to =GL2+A1-QA1:13 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-QA1:13', attributes=[Attribute(name=link, value=to +A1-XG1:20 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:21', attributes=[Attribute(name=link, value=to =GL2+A1-QA2:14 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-QA2:14', attributes=[Attribute(name=link, value=to +A1-XG1:21 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:22', attributes=[Attribute(name=link, value=to =GL2+A1-QA2:13 through )])
# Object: Object(tag=Tag(tag_str='=GL2+A1-QA2:13', attributes=[Attribute(name=link, value=to +A1-XG1:22 through )])
# Object: Object(tag=Tag(tag_str='=TM1+A1-FC1:2/T1', attributes=[Attribute(name=link, value=to =TM1+A1-TA1:X1:1 through )])
# Object: Object(tag=Tag(tag_str='=TM1+A1-TA1:X1:1', attributes=[Attribute(name=link, value=to =TM1+A1-FC1:2/T1 through )])
# Object: Object(tag=Tag(tag_str='=TM1+A1-FC1:4/T2', attributes=[Attribute(name=link, value=to =TM1+A1-TA1:X1:2 through )])
# Object: Object(tag=Tag(tag_str='=TM1+A1-TA1:X1:2', attributes=[Attribute(name=link, value=to =TM1+A1-FC1:4/T2 through )])
# Object: Object(tag=Tag(tag_str='=TM1+A1-FC1:6/T3', attributes=[Attribute(name=link, value=to =TM1+A1-TA1:X1:3 through )])
# Object: Object(tag=Tag(tag_str='=TM1+A1-TA1:X1:3', attributes=[Attribute(name=link, value=to =TM1+A1-FC1:6/T3 through )])
# Object: Object(tag=Tag(tag_str='+A1-WE1:4', attributes=[Attribute(name=link, value=to =TM1+A1-TA1:X1:PE1 through )])
# Object: Object(tag=Tag(tag_str='=TM1+A1-TA1:X1:PE1', attributes=[Attribute(name=link, value=to +A1-WE1:4 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:23', attributes=[Attribute(name=link, value=to =TM1+A1-FC1:14 through )])
# Object: Object(tag=Tag(tag_str='=TM1+A1-FC1:14', attributes=[Attribute(name=link, value=to +A1-XG1:23 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:24', attributes=[Attribute(name=link, value=to =TM1+A1-FC1:13 through )])
# Object: Object(tag=Tag(tag_str='=TM1+A1-FC1:13', attributes=[Attribute(name=link, value=to +A1-XG1:24 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:25', attributes=[Attribute(name=link, value=to =TM1+A1-TA1:X12:1 through )])
# Object: Object(tag=Tag(tag_str='=TM1+A1-TA1:X12:1', attributes=[Attribute(name=link, value=to +A1-XG1:25 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:26', attributes=[Attribute(name=link, value=to =TM1+A1-TA1:X12:9 through )])
# Object: Object(tag=Tag(tag_str='=TM1+A1-TA1:X12:9', attributes=[Attribute(name=link, value=to +A1-XG1:26 through )])
# Object: Object(tag=Tag(tag_str='=TM2+A1-FC1:2/T1', attributes=[Attribute(name=link, value=to =TM2+A1-TA1:X1:1 through )])
# Object: Object(tag=Tag(tag_str='=TM2+A1-TA1:X1:1', attributes=[Attribute(name=link, value=to =TM2+A1-FC1:2/T1 through )])
# Object: Object(tag=Tag(tag_str='=TM2+A1-FC1:4/T2', attributes=[Attribute(name=link, value=to =TM2+A1-TA1:X1:2 through )])
# Object: Object(tag=Tag(tag_str='=TM2+A1-TA1:X1:2', attributes=[Attribute(name=link, value=to =TM2+A1-FC1:4/T2 through )])
# Object: Object(tag=Tag(tag_str='=TM2+A1-FC1:6/T3', attributes=[Attribute(name=link, value=to =TM2+A1-TA1:X1:3 through )])
# Object: Object(tag=Tag(tag_str='=TM2+A1-TA1:X1:3', attributes=[Attribute(name=link, value=to =TM2+A1-FC1:6/T3 through )])
# Object: Object(tag=Tag(tag_str='+A1-WE1:5', attributes=[Attribute(name=link, value=to =TM2+A1-TA1:X1:PE1 through )])
# Object: Object(tag=Tag(tag_str='=TM2+A1-TA1:X1:PE1', attributes=[Attribute(name=link, value=to +A1-WE1:5 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:27', attributes=[Attribute(name=link, value=to =TM2+A1-FC1:14 through )])
# Object: Object(tag=Tag(tag_str='=TM2+A1-FC1:14', attributes=[Attribute(name=link, value=to +A1-XG1:27 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:28', attributes=[Attribute(name=link, value=to =TM2+A1-FC1:13 through )])
# Object: Object(tag=Tag(tag_str='=TM2+A1-FC1:13', attributes=[Attribute(name=link, value=to +A1-XG1:28 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:29', attributes=[Attribute(name=link, value=to =TM2+A1-TA1:X12:1 through )])
# Object: Object(tag=Tag(tag_str='=TM2+A1-TA1:X12:1', attributes=[Attribute(name=link, value=to +A1-XG1:29 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:30', attributes=[Attribute(name=link, value=to =TM2+A1-TA1:X12:9 through )])
# Object: Object(tag=Tag(tag_str='=TM2+A1-TA1:X12:9', attributes=[Attribute(name=link, value=to +A1-XG1:30 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD4:11', attributes=[Attribute(name=link, value=to =GL3+A1-QA1:2/T1 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-QA1:2/T1', attributes=[Attribute(name=link, value=to +A1-XD4:11 through ), Attribute(name=link, value=to =GL3+A1-QA2:2/T1 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-QA2:2/T1', attributes=[Attribute(name=link, value=to =GL3+A1-QA1:2/T1 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-FC1:2/T1', attributes=[Attribute(name=link, value=to =GL3+A1-QA1:1/L1 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-QA1:1/L1', attributes=[Attribute(name=link, value=to =GL3+A1-FC1:2/T1 through ), Attribute(name=link, value=to =GL3+A1-QA2:5/L3 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-QA2:5/L3', attributes=[Attribute(name=link, value=to =GL3+A1-QA1:1/L1 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD4:12', attributes=[Attribute(name=link, value=to =GL3+A1-QA1:4/T2 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-QA1:4/T2', attributes=[Attribute(name=link, value=to +A1-XD4:12 through ), Attribute(name=link, value=to =GL3+A1-QA2:4/T2 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-QA2:4/T2', attributes=[Attribute(name=link, value=to =GL3+A1-QA1:4/T2 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-FC1:4/T2', attributes=[Attribute(name=link, value=to =GL3+A1-QA1:3/L2 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-QA1:3/L2', attributes=[Attribute(name=link, value=to =GL3+A1-FC1:4/T2 through ), Attribute(name=link, value=to =GL3+A1-QA2:3/L2 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-QA2:3/L2', attributes=[Attribute(name=link, value=to =GL3+A1-QA1:3/L2 through )])
# Object: Object(tag=Tag(tag_str='+A1-XD4:13', attributes=[Attribute(name=link, value=to =GL3+A1-QA1:6/T3 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-QA1:6/T3', attributes=[Attribute(name=link, value=to +A1-XD4:13 through ), Attribute(name=link, value=to =GL3+A1-QA2:6/T3 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-QA2:6/T3', attributes=[Attribute(name=link, value=to =GL3+A1-QA1:6/T3 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-FC1:6/T3', attributes=[Attribute(name=link, value=to =GL3+A1-QA1:5/L3 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-QA1:5/L3', attributes=[Attribute(name=link, value=to =GL3+A1-FC1:6/T3 through ), Attribute(name=link, value=to =GL3+A1-QA2:1/L1 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-QA2:1/L1', attributes=[Attribute(name=link, value=to =GL3+A1-QA1:5/L3 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:31', attributes=[Attribute(name=link, value=to =GL3+A1-FC1:14 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-FC1:14', attributes=[Attribute(name=link, value=to +A1-XG1:31 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:32', attributes=[Attribute(name=link, value=to =GL3+A1-FC1:13 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-FC1:13', attributes=[Attribute(name=link, value=to +A1-XG1:32 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-QA1:A1', attributes=[Attribute(name=link, value=to =GL3+A1-QA2:12 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-QA2:12', attributes=[Attribute(name=link, value=to =GL3+A1-QA1:A1 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:33', attributes=[Attribute(name=link, value=to =GL3+A1-QA2:11 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-QA2:11', attributes=[Attribute(name=link, value=to +A1-XG1:33 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:34', attributes=[Attribute(name=link, value=to =GL3+A1-QA1:A2 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-QA1:A2', attributes=[Attribute(name=link, value=to +A1-XG1:34 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-QA1:12', attributes=[Attribute(name=link, value=to =GL3+A1-QA2:A1 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-QA2:A1', attributes=[Attribute(name=link, value=to =GL3+A1-QA1:12 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:35', attributes=[Attribute(name=link, value=to =GL3+A1-QA1:11 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-QA1:11', attributes=[Attribute(name=link, value=to +A1-XG1:35 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:36', attributes=[Attribute(name=link, value=to =GL3+A1-QA2:A2 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-QA2:A2', attributes=[Attribute(name=link, value=to +A1-XG1:36 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:37', attributes=[Attribute(name=link, value=to =GL3+A1-QA1:14 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-QA1:14', attributes=[Attribute(name=link, value=to +A1-XG1:37 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:38', attributes=[Attribute(name=link, value=to =GL3+A1-QA1:13 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-QA1:13', attributes=[Attribute(name=link, value=to +A1-XG1:38 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:39', attributes=[Attribute(name=link, value=to =GL3+A1-QA2:14 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-QA2:14', attributes=[Attribute(name=link, value=to +A1-XG1:39 through )])
# Object: Object(tag=Tag(tag_str='+A1-XG1:40', attributes=[Attribute(name=link, value=to =GL3+A1-QA2:13 through )])
# Object: Object(tag=Tag(tag_str='=GL3+A1-QA2:13', attributes=[Attribute(name=link, value=to +A1-XG1:40 through )])
# Object: Object(tag=Tag(tag_str='+A2-XD2:1', attributes=[Attribute(name=link, value=to =K1+A2-FC1:1 through ), Attribute(name=link, value=to =GAB1+A2-FC1:2 through )])
# Object: Object(tag=Tag(tag_str='=K1+A2-FC1:1', attributes=[Attribute(name=link, value=to +A2-XD2:1 through ), Attribute(name=link, value=to =K1+A2-FC2:1 through )])
# Object: Object(tag=Tag(tag_str='=K1+A2-FC2:1', attributes=[Attribute(name=link, value=to =K1+A2-FC1:1 through ), Attribute(name=link, value=to =K1+A2-FC5:1 through )])
# Object: Object(tag=Tag(tag_str='=K1+A2-FC5:1', attributes=[Attribute(name=link, value=to =K1+A2-FC2:1 through ), Attribute(name=link, value=to =K1+A2-FC7:1 through )])
# Object: Object(tag=Tag(tag_str='=K1+A2-FC7:1', attributes=[Attribute(name=link, value=to =K1+A2-FC5:1 through ), Attribute(name=link, value=to =K1+A2-FC9:1 through )])
# Object: Object(tag=Tag(tag_str='=K1+A2-FC9:1', attributes=[Attribute(name=link, value=to =K1+A2-FC7:1 through ), Attribute(name=link, value=to =K2+A2-FC1:1 through )])
# Object: Object(tag=Tag(tag_str='=K2+A2-FC1:1', attributes=[Attribute(name=link, value=to =K1+A2-FC9:1 through ), Attribute(name=link, value=to =S1+A2-FC2:1 through )])
# Object: Object(tag=Tag(tag_str='=S1+A2-FC2:1', attributes=[Attribute(name=link, value=to =K2+A2-FC1:1 through ), Attribute(name=link, value=to =S2+A2-FC1:1 through )])
# Object: Object(tag=Tag(tag_str='=S2+A2-FC1:1', attributes=[Attribute(name=link, value=to =S1+A2-FC2:1 through )])
# Object: Object(tag=Tag(tag_str='=GAB1+A2-FC1:2', attributes=[Attribute(name=link, value=to +A2-XD2:1 through )])
# Object: Object(tag=Tag(tag_str='=GAB1+A2-FC1:1', attributes=[Attribute(name=link, value=to =GAB1+A2-TB1:OutDC:+ through )])
# Object: Object(tag=Tag(tag_str='=GAB1+A2-TB1:OutDC:+', attributes=[Attribute(name=link, value=to =GAB1+A2-FC1:1 through )])
# Object: Object(tag=Tag(tag_str='+A2-XD1:1', attributes=[Attribute(name=link, value=to =GAB1+A2-TB1:InAC:L1/+ through )])
# Object: Object(tag=Tag(tag_str='=GAB1+A2-TB1:InAC:L1/+', attributes=[Attribute(name=link, value=to +A2-XD1:1 through )])
# Object: Object(tag=Tag(tag_str='+A2-XD2:2', attributes=[Attribute(name=link, value=to =GAB1+A2-PF1:X1 through )])
# Object: Object(tag=Tag(tag_str='=GAB1+A2-PF1:X1', attributes=[Attribute(name=link, value=to +A2-XD2:2 through )])
# Object: Object(tag=Tag(tag_str='=GAB1+A2-TB1:OutDC', attributes=[Attribute(name=link, value=to =GAB1+A2-TB1:OutDC through ), Attribute(name=link, value=to =GAB1+A2-TB1:OutDC through ), Attribute(name=link, value=to =GAB1+A2-TB1:OutDC through ), Attribute(name=link, value=to =GAB1+A2-TB1:OutDC through ), Attribute(name=link, value=to =GAB1+A2-TB1:OutDC through ), Attribute(name=link, value=to =GAB1+A2-TB1:OutDC through )])
# Object: Object(tag=Tag(tag_str='+A2-XD1:2', attributes=[Attribute(name=link, value=to =GAB1+A2-TB1:InAC:L2 through )])
# Object: Object(tag=Tag(tag_str='=GAB1+A2-TB1:InAC:L2', attributes=[Attribute(name=link, value=to +A2-XD1:2 through )])
# Object: Object(tag=Tag(tag_str='+A2-XD2:3', attributes=[Attribute(name=link, value=to +A2-XD6:2 through ), Attribute(name=link, value=to =GAB1+A2-TB1:OutDC:- through )])
# Object: Object(tag=Tag(tag_str='+A2-XD6:2', attributes=[Attribute(name=link, value=to +A2-XD2:3 through ), Attribute(name=link, value=to =K1+A2-KEB1:X1:- through )])
# Object: Object(tag=Tag(tag_str='=GAB1+A2-TB1:OutDC:-', attributes=[Attribute(name=link, value=to +A2-XD2:3 through ), Attribute(name=link, value=to +A2-XD1:3 through )])
# Object: Object(tag=Tag(tag_str='+A2-XD1:3', attributes=[Attribute(name=link, value=to =GAB1+A2-TB1:InAC:L3/- through )])
# Object: Object(tag=Tag(tag_str='+A2-XD2:4', attributes=[Attribute(name=link, value=to =GAB1+A2-PF1:X2 through ), Attribute(name=link, value=to +A2-XD2:5 through )])
# Object: Object(tag=Tag(tag_str='=GAB1+A2-PF1:X2', attributes=[Attribute(name=link, value=to +A2-XD2:4 through )])
# Object: Object(tag=Tag(tag_str='+A2-XD2:5', attributes=[Attribute(name=link, value=to +A2-XD2:4 through )])
# Object: Object(tag=Tag(tag_str='+A2-XD1:5', attributes=[Attribute(name=link, value=to =GAB1+A2-TB1:InAC:PE through )])
# Object: Object(tag=Tag(tag_str='=GAB1+A2-TB1:InAC:PE', attributes=[Attribute(name=link, value=to +A2-XD1:5 through )])
# Object: Object(tag=Tag(tag_str='+A2-XD4:1', attributes=[Attribute(name=link, value=to =K1+A2-FC3:1 through ), Attribute(name=link, value=to =GAB2+A2-FC1:2 through )])
# Object: Object(tag=Tag(tag_str='=K1+A2-FC3:1', attributes=[Attribute(name=link, value=to +A2-XD4:1 through ), Attribute(name=link, value=to =F+A2-FC1:1 through )])
# Object: Object(tag=Tag(tag_str='=F+A2-FC1:1', attributes=[Attribute(name=link, value=to =K1+A2-FC3:1 through ), Attribute(name=link, value=to =K1+A2-FC4:1 through )])
# Object: Object(tag=Tag(tag_str='=K1+A2-FC4:1', attributes=[Attribute(name=link, value=to =F+A2-FC1:1 through ), Attribute(name=link, value=to =K1+A2-FC6:1 through )])
# Object: Object(tag=Tag(tag_str='=K1+A2-FC6:1', attributes=[Attribute(name=link, value=to =K1+A2-FC4:1 through ), Attribute(name=link, value=to =K1+A2-FC8:1 through )])
# Object: Object(tag=Tag(tag_str='=K1+A2-FC8:1', attributes=[Attribute(name=link, value=to =K1+A2-FC6:1 through ), Attribute(name=link, value=to =K1+A2-FC10:1 through )])
# Object: Object(tag=Tag(tag_str='=K1+A2-FC10:1', attributes=[Attribute(name=link, value=to =K1+A2-FC8:1 through )])
# Object: Object(tag=Tag(tag_str='=GAB2+A2-FC1:2', attributes=[Attribute(name=link, value=to +A2-XD4:1 through )])
# Object: Object(tag=Tag(tag_str='=GAB2+A2-FC1:1', attributes=[Attribute(name=link, value=to =GAB2+A2-TB1:OutDC:+ through )])
# Object: Object(tag=Tag(tag_str='=GAB2+A2-TB1:OutDC:+', attributes=[Attribute(name=link, value=to =GAB2+A2-FC1:1 through )])
# Object: Object(tag=Tag(tag_str='+A2-XD1:6', attributes=[Attribute(name=link, value=to =GAB2+A2-TB1:InAC:L1/+ through )])
# Object: Object(tag=Tag(tag_str='=GAB2+A2-TB1:InAC:L1/+', attributes=[Attribute(name=link, value=to +A2-XD1:6 through )])
# Object: Object(tag=Tag(tag_str='+A2-XD4:2', attributes=[Attribute(name=link, value=to =GAB2+A2-PF1:X1 through )])
# Object: Object(tag=Tag(tag_str='=GAB2+A2-PF1:X1', attributes=[Attribute(name=link, value=to +A2-XD4:2 through )])
# Object: Object(tag=Tag(tag_str='=GAB2+A2-TB1:OutDC', attributes=[Attribute(name=link, value=to =GAB2+A2-TB1:OutDC through ), Attribute(name=link, value=to =GAB2+A2-TB1:OutDC through ), Attribute(name=link, value=to =GAB2+A2-TB1:OutDC through ), Attribute(name=link, value=to =GAB2+A2-TB1:OutDC through ), Attribute(name=link, value=to =GAB2+A2-TB1:OutDC through ), Attribute(name=link, value=to =GAB2+A2-TB1:OutDC through )])
# Object: Object(tag=Tag(tag_str='+A2-XD1:7', attributes=[Attribute(name=link, value=to =GAB2+A2-TB1:InAC:L2 through )])
# Object: Object(tag=Tag(tag_str='=GAB2+A2-TB1:InAC:L2', attributes=[Attribute(name=link, value=to +A2-XD1:7 through )])
# Object: Object(tag=Tag(tag_str='+A2-XD4:3', attributes=[Attribute(name=link, value=to =K1+A2-KE1:1:2.3 through ), Attribute(name=link, value=to =GAB2+A2-TB1:OutDC:- through )])
# Object: Object(tag=Tag(tag_str='=K1+A2-KE1:1:2.3', attributes=[Attribute(name=link, value=to +A2-XD4:3 through ), Attribute(name=link, value=to =F+A2-KE1:1:2.3 through )])
# Object: Object(tag=Tag(tag_str='=F+A2-KE1:1:2.3', attributes=[Attribute(name=link, value=to =K1+A2-KE1:1:2.3 through ), Attribute(name=link, value=to =K1+A2-KE4:1:2.3 through )])
# Object: Object(tag=Tag(tag_str='=K1+A2-KE4:1:2.3', attributes=[Attribute(name=link, value=to =F+A2-KE1:1:2.3 through ), Attribute(name=link, value=to +A2-XD7:5 through )])
# Object: Object(tag=Tag(tag_str='+A2-XD7:5', attributes=[Attribute(name=link, value=to =K1+A2-KE4:1:2.3 through ), Attribute(name=link, value=to +A2-XD7:10 through )])
# Object: Object(tag=Tag(tag_str='+A2-XD7:10', attributes=[Attribute(name=link, value=to +A2-XD7:5 through ), Attribute(name=link, value=to +A2-XD7:15 through )])
# Object: Object(tag=Tag(tag_str='+A2-XD7:15', attributes=[Attribute(name=link, value=to +A2-XD7:10 through )])
# Object: Object(tag=Tag(tag_str='=GAB2+A2-TB1:OutDC:-', attributes=[Attribute(name=link, value=to +A2-XD4:3 through ), Attribute(name=link, value=to +A2-XD1:8 through )])
# Object: Object(tag=Tag(tag_str='+A2-XD1:8', attributes=[Attribute(name=link, value=to =GAB2+A2-TB1:InAC:L3/- through )])
# Object: Object(tag=Tag(tag_str='+A2-XD4:4', attributes=[Attribute(name=link, value=to =GAB2+A2-PF1:X2 through ), Attribute(name=link, value=to +A2-XD4:5 through )])
# Object: Object(tag=Tag(tag_str='=GAB2+A2-PF1:X2', attributes=[Attribute(name=link, value=to +A2-XD4:4 through )])
# Object: Object(tag=Tag(tag_str='+A2-XD4:5', attributes=[Attribute(name=link, value=to +A2-XD4:4 through )])
# Object: Object(tag=Tag(tag_str='+A2-XD1:9', attributes=[Attribute(name=link, value=to =GAB2+A2-TB1:InAC:PE through )])
# Object: Object(tag=Tag(tag_str='=GAB2+A2-TB1:InAC:PE', attributes=[Attribute(name=link, value=to +A2-XD1:9 through )])
# Object: Object(tag=Tag(tag_str='+A2-XG5:1', attributes=[Attribute(name=link, value=to =K1+A2-KE1:4:4.1 through ), Attribute(name=link, value=to +A2-XG1:1 through )])
# Object: Object(tag=Tag(tag_str='=K1+A2-KE1:4:4.1', attributes=[Attribute(name=link, value=to +A2-XG5:1 through )])
# Object: Object(tag=Tag(tag_str='+A2-XG1:1', attributes=[Attribute(name=link, value=to +A2-XG5:1 through ), Attribute(name=link, value=to =GAB2+A2-TB1:Signal:14 through )])
# Object: Object(tag=Tag(tag_str='=GAB2+A2-TB1:Signal:14', attributes=[Attribute(name=link, value=to +A2-XG1:1 through )])
# Object: Object(tag=Tag(tag_str='+A2-XG5:2', attributes=[Attribute(name=link, value=to =K1+A2-KE1:4:4.2 through ), Attribute(name=link, value=to +A2-XG1:2 through )])
# Object: Object(tag=Tag(tag_str='=K1+A2-KE1:4:4.2', attributes=[Attribute(name=link, value=to +A2-XG5:2 through )])
# ...
# Connection: Connection(von="+A2-XG1:45", bis="=K1+A2-KE5:2:3.3", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+A2-XG1:46", bis="=K1+A2-KE5:2:4.1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+A2-XG1:47", bis="=K1+A2-KE5:2:4.2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+A2-XG1:48", bis="=K1+A2-KE5:2:4.3", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+A2-XG5:61", bis="=K1+A2-KE2:2:4.1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+A2-XG1:49", bis="+A2-XG5:61", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+A2-XG5:62", bis="=K1+A2-KE2:2:4.2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+A2-XG1:50", bis="+A2-XG5:62", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+A2-XG5:63", bis="=K1+A2-KE2:2:4.3", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+A2-XG5:64", bis="=K1+A2-KE2:2:4.4", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+A2-XG1:51", bis="+A2-XG5:64", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+A2-XG5:65", bis="=K1+A2-KE2:2:4.5", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+A2-XG1:52", bis="+A2-XG5:65", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+A2-XG5:66", bis="=K1+A2-KE2:2:4.6", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="=MM1+B1-BG1", bis="=MM1+B1-BG1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=MM1+B1-BG1", bis="=MM1+B1-BG1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=MM1+B1-BG1", bis="=MM1+B1-BG1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=MM1+B1-BG2", bis="=MM1+B1-BG2", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=MM1+B1-BG2", bis="=MM1+B1-BG2", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=MM1+B1-BG2", bis="=MM1+B1-BG2", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=K1+B1.X1-KE1:1:1.1", bis="=K1+B1.X1-KE1:1:2.1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="+B1.X1-XD1:1", bis="=K1+B1.X1-KE1:1:1.2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="+B1.X1-XD1:2", bis="=K1+B1.X1-KE1:1:1.3", tag="", attributes=[Attribute(name=Color, value=BU), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="+B1.X1-XD1:3", bis="=K1+B1.X1-KE1:1:1.4", tag="", attributes=[Attribute(name=Color, value=GNYE), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=K1+B1.X1-KE1:1:1.4", bis="=K1+B1.X1-KE1:1:2.4", tag="", attributes=[Attribute(name=Color, value=GNYE), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="+B1.X1-XD1:4", bis="=K1+B1.X1-KE1:1:2.2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="+B1.X1-XD1:5", bis="=K1+B1.X1-KE1:1:2.3", tag="", attributes=[Attribute(name=Color, value=BU), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="+B1.X1-XZ1:6", bis="=K1+B1.X1-KE1:3:1.2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+B1.X1-XZ1:7", bis="=K1+B1.X1-KE1:3:1.1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+B1.X1-XZ1:9", bis="=K1+B1.X1-KE1:3:2.1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+B1.X1-XZ1:10", bis="=K1+B1.X1-KE1:3:2.2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+B1.X1-XZ1:11", bis="=K1+B1.X1-KE1:3:2.3", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="=MM2+B2-BG1", bis="=MM2+B2-BG1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=MM2+B2-BG1", bis="=MM2+B2-BG1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=MM2+B2-BG1", bis="=MM2+B2-BG1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=MM2+B2-BG2", bis="=MM2+B2-BG2", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=MM2+B2-BG2", bis="=MM2+B2-BG2", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=MM2+B2-BG2", bis="=MM2+B2-BG2", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=MM3+B2-BG1", bis="=MM3+B2-BG1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=MM3+B2-BG1", bis="=MM3+B2-BG1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=MM3+B2-BG1", bis="=MM3+B2-BG1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=MM3+B2-BG2", bis="=MM3+B2-BG2", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=MM3+B2-BG2", bis="=MM3+B2-BG2", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=MM3+B2-BG2", bis="=MM3+B2-BG2", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=K1+B2.X1-KE1:1:1.1", bis="=K1+B2.X1-KE1:1:2.1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="+B2.X1-XD1:1", bis="=K1+B2.X1-KE1:1:1.2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="+B2.X1-XD1:2", bis="=K1+B2.X1-KE1:1:1.3", tag="", attributes=[Attribute(name=Color, value=BU), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="+B2.X1-XD1:3", bis="=K1+B2.X1-KE1:1:1.4", tag="", attributes=[Attribute(name=Color, value=GNYE), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=K1+B2.X1-KE1:1:1.4", bis="=K1+B2.X1-KE1:1:2.4", tag="", attributes=[Attribute(name=Color, value=GNYE), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="+B2.X1-XD1:4", bis="=K1+B2.X1-KE1:1:2.2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="+B2.X1-XD1:5", bis="=K1+B2.X1-KE1:1:2.3", tag="", attributes=[Attribute(name=Color, value=BU), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="+B2.X1-XZ1:6", bis="=K1+B2.X1-KE2:1:1.2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+B2.X1-XZ1:7", bis="=K1+B2.X1-KE2:1:1.1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+B2.X1-XZ1:9", bis="=K1+B2.X1-KE2:1:1.4", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+B2.X1-XZ1:10", bis="=K1+B2.X1-KE2:1:1.5", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+B2.X1-XZ1:11", bis="=K1+B2.X1-KE2:1:1.6", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+B2.X1-XZ1:20", bis="=K1+B2.X1-KE1:3:2.1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+B2.X1-XZ1:21", bis="=K1+B2.X1-KE1:3:2.2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+B2.X1-XZ1:22", bis="=K1+B2.X1-KE1:3:2.3", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+B2.X1-XZ1:31", bis="=K1+B2.X1-KE1:4:4.1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+B2.X1-XZ1:32", bis="=K1+B2.X1-KE1:4:4.2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+B2.X1-XZ1:33", bis="=K1+B2.X1-KE1:4:4.3", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="=GQA+B2.Y1-MB1", bis="=GQA+B2.Y1-MB1:x1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=GQA+B2.Y1-MB1", bis="=GQA+B2.Y1-MB1:x2", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=GQA+B2.Y1-S1", bis="=GQA+B2.Y1-S1:13", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=GQA+B2.Y1-S1", bis="=GQA+B2.Y1-S1:14", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=GQA+B2.Y1-S1:13", bis="=GQA+B2.Y1-S1:21", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=GQA+B2.Y1-S1", bis="=GQA+B2.Y1-S1:22", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=K2+B2.Y1-X0:3", bis="=K2+B2.Y1-MB1:x1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=K2+B2.Y1-X0:4", bis="=K2+B2.Y1-MB2:x1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=K2+B2.Y1-X0:9", bis="=K2+B2.Y1-MB1:x1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=K2+B2.Y1-X0:10", bis="=K2+B2.Y1-MB2:x1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=K2+B2.Y1-X0:11", bis="=K2+B2.Y1-MB1:x1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=K2+B2.Y1-X0:12", bis="=K2+B2.Y1-MB2:x1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="+B2.Y1-XD1:5", bis="=K2+B2.Y1-XD1:PE", tag="", attributes=[Attribute(name=Color, value=GNYE), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+B2.Y1-XDB1:1:1 female", bis="=K2+B2.Y1-X20:1", tag="", attributes=[])
# Connection: Connection(von="+B2.Y1-XDB1:2:2 female", bis="=K2+B2.Y1-X20:2", tag="", attributes=[])
# Connection: Connection(von="+B2.Y1-XDB1:3:3 female", bis="=K2+B2.Y1-X20:3", tag="", attributes=[])
# Connection: Connection(von="+B2.Y1-XDB1:PE: PE female", bis="=K2+B2.Y1-X20:4", tag="", attributes=[])
# Connection: Connection(von="=K2+B2.Y1-X0:1", bis="=K2+B2.Y1-MB1:x1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=K2+B2.Y1-X0:2", bis="=K2+B2.Y1-MB2:x1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=K2+B2.Y1-X0:5", bis="=K2+B2.Y1-MB1:x1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=K2+B2.Y1-X0:6", bis="=K2+B2.Y1-MB2:x1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=K2+B2.Y1-X0:7", bis="=K2+B2.Y1-MB1:x1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=K2+B2.Y1-X0:8", bis="=K2+B2.Y1-MB2:x1", tag="", attributes=[Attribute(name=Color, value=BK), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=K1+B3.X1-KE1:1:1.1", bis="=K1+B3.X1-KE1:1:2.1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="+B3.X1-XD1:1", bis="=K1+B3.X1-KE1:1:1.2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="+B3.X1-XD1:2", bis="=K1+B3.X1-KE1:1:1.3", tag="", attributes=[Attribute(name=Color, value=BU), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="+B3.X1-XD1:3", bis="=K1+B3.X1-KE1:1:1.4", tag="", attributes=[Attribute(name=Color, value=GNYE), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="=K1+B3.X1-KE1:1:1.4", bis="=K1+B3.X1-KE1:1:2.4", tag="", attributes=[Attribute(name=Color, value=GNYE), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="+B3.X1-XD1:4", bis="=K1+B3.X1-KE1:1:2.2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="+B3.X1-XD1:5", bis="=K1+B3.X1-KE1:1:2.3", tag="", attributes=[Attribute(name=Color, value=BU), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="+B3.X1-XZ1:6", bis="=K1+B3.X1-KE1:3:1.2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+B3.X1-XZ1:7", bis="=K1+B3.X1-KE1:3:1.1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+B3.X1-XZ1:9", bis="=K1+B3.X1-KE1:3:2.1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+B3.X1-XZ1:10", bis="=K1+B3.X1-KE1:3:2.2", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+B3.X1-XZ1:11", bis="=K1+B3.X1-KE1:3:2.3", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=0,75)])
# Connection: Connection(von="+C2-XD1:1", bis="=S2+C2-PH1:X1:X1.1", tag="", attributes=[Attribute(name=Color, value=GY), Attribute(name=Cross-section, value=1,5)])
# Connection: Connection(von="+C2-XD1:2", bis="=S2+C2-PH1:X1:X1.2", tag="", attributes=[Attribute(name=Color, value=BU), Attribute(name=Cross-section, value=1,5)])
